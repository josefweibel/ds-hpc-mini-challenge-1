# %%
import timeit as timeit
import numpy as np
import cProfile
from pstats import SortKey
from rating_producer import publish as publish_ratings
from rating_producer import read_file as read_ratings_file
from rating_producer import producer as rating_message_producer
from movie_data_producer import publish as publish_movies
from movie_data_producer import read_file as read_movies_file
from movie_data_producer import producer as movie_data_message_producer
from mean_rating_producer import producer as mean_rating_producer
from movie_data_sink import processor as movie_data_processor

# %% [markdown]
# # Code Performance Analyse
#
# ## Data Generators

# %%
n = 100
def setup():
	global ratings_file
	ratings_file = read_ratings_file()

def run():
	global ratings_file
	publish_ratings(ratings_file, n)

results = timeit.repeat(run, setup, repeat = 3, number = 10)
print(f'Publishing {n} ratings: mean = {np.min(results)}s +/-{np.std(results)}s')
# Out:
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing message 100
# Publishing 100 ratings: mean = 2.0930403209986252s +/-0.11599918099817182s

# %%
n = 100
def setup():
	global movies_file
	movies_file = read_movies_file()

def run():
	global movies_file
	publish_movies(movies_file, n, wait_time = 0)

results = timeit.repeat(run, setup, repeat = 3, number = 10)
print(f'Publishing {n} movies: mean = {np.min(results)}s +/-{np.std(results)}s')
# Out:
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Publishing 100 movies: mean = 2.7515630680009053s +/-0.02586147209113136s

# %% [markdown]
# ## Data Processors

# %%
with cProfile.Profile() as mean_rating_producer_report:
	mean_rating_producer.run(1000)
# Out:
# Storing rating 3.5833333333333335 for movie 307
# Storing rating 3.642857142857143 for movie 481
# Storing rating 1.3571428571428572 for movie 1091
# Storing rating 4.5 for movie 1257
# Storing rating 4.5 for movie 1449
# Storing rating 2.7857142857142856 for movie 1590
# Storing rating 2.0714285714285716 for movie 1591
# Storing rating 4.5 for movie 2134
# Storing rating 3.8333333333333335 for movie 2478
# Storing rating 3.0833333333333335 for movie 2840
# Storing rating 2.3333333333333335 for movie 2986
# Storing rating 3.9166666666666665 for movie 3020
# Storing rating 4.5 for movie 3424
# Storing rating 3.5833333333333335 for movie 3698
# Storing rating 2.1666666666666665 for movie 3826
# Storing rating 3.5 for movie 3893
# Storing rating 3.2777777777777777 for movie 170
# Storing rating 3.75 for movie 849
# Storing rating 3.25 for movie 1186
# Storing rating 3.0 for movie 1235
# Storing rating 3.3333333333333335 for movie 1244
# Storing rating 4.5 for movie 1296
# Storing rating 3.0833333333333335 for movie 1663
# Storing rating 4.0 for movie 1962
# Storing rating 3.5 for movie 2108
# Storing rating 4.5 for movie 2243
# Storing rating 4.0 for movie 2352
# Storing rating 3.5 for movie 2707
# Storing rating 4.0 for movie 2746
# Storing rating 3.5 for movie 2915
# Storing rating 4.0 for movie 3363
# Storing rating 3.0 for movie 640
# Storing rating 4.0 for movie 828
# Storing rating 3.0 for movie 960
# Storing rating 4.0 for movie 1221
# Storing rating 4.0 for movie 1321
# Storing rating 4.142857142857143 for movie 1645
# Storing rating 3.0 for movie 1825
# Storing rating 2.0 for movie 1985
# Storing rating 3.0 for movie 2024
# Storing rating 4.9375 for movie 2028
# Storing rating 4.0 for movie 3171
# Storing rating 4.214285714285714 for movie 1
# Storing rating 4.0 for movie 2
# Storing rating 2.1666666666666665 for movie 5
# Storing rating 4.5 for movie 6
# Storing rating 4.0 for movie 10
# Storing rating 3.5 for movie 11
# Storing rating 4.0 for movie 16
# Storing rating 2.0 for movie 19
# Storing rating 2.5 for movie 20
# Storing rating 3.0 for movie 23
# Storing rating 4.5 for movie 25
# Storing rating 3.0 for movie 31
# Storing rating 4.357142857142857 for movie 32
# Storing rating 3.5 for movie 34
# Storing rating 3.5 for movie 36
# Storing rating 2.5 for movie 39
# Storing rating 4.5 for movie 41
# Storing rating 1.0 for movie 44
# Storing rating 2.2 for movie 45
# Storing rating 4.714285714285714 for movie 47
# Storing rating 4.714285714285714 for movie 50
# Storing rating 3.0 for movie 61
# Storing rating 3.6 for movie 62
# Storing rating 0.5 for movie 65
# Storing rating 0.5 for movie 66
# Storing rating 3.0 for movie 70
# Storing rating 2.0 for movie 76
# Storing rating 4.0 for movie 85
# Storing rating 4.5 for movie 95
# Storing rating 4.0 for movie 100
# Storing rating 3.0 for movie 104
# Storing rating 4.5 for movie 110
# Storing rating 4.666666666666667 for movie 141
# Storing rating 4.0 for movie 145
# Storing rating 4.0 for movie 150
# Storing rating 4.5 for movie 151
# Storing rating 2.4 for movie 153
# Storing rating 1.1 for movie 158
# Storing rating 2.5 for movie 160
# Storing rating 4.0 for movie 161
# Storing rating 2.8 for movie 163
# Storing rating 4.5 for movie 165
# Storing rating 0.5 for movie 169
# Storing rating 3.25 for movie 170
# Storing rating 3.5 for movie 172
# Storing rating 3.4 for movie 173
# Storing rating 3.5 for movie 175
# Storing rating 4.5 for movie 180
# Storing rating 0.5 for movie 181
# Storing rating 3.0 for movie 185
# Storing rating 2.1 for movie 186
# Storing rating 0.5 for movie 193
# Storing rating 4.5 for movie 198
# Storing rating 3.3333333333333335 for movie 204
# Storing rating 2.4 for movie 216
# Storing rating 4.6 for movie 223
# Storing rating 0.5 for movie 231
# Storing rating 4.5 for movie 253
# Storing rating 3.5714285714285716 for movie 307
# Storing rating 3.625 for movie 481
# Storing rating 1.375 for movie 1091
# Storing rating 4.5 for movie 1257
# Storing rating 4.5 for movie 1449
# Storing rating 2.75 for movie 1590
# Storing rating 2.0 for movie 1591
# Storing rating 4.5 for movie 2134
# Storing rating 3.857142857142857 for movie 2478
# Storing rating 3.0714285714285716 for movie 2840
# Storing rating 2.357142857142857 for movie 2986
# Storing rating 3.9285714285714284 for movie 3020
# Storing rating 4.5 for movie 3424
# Storing rating 3.5714285714285716 for movie 3698
# Storing rating 2.142857142857143 for movie 3826
# Storing rating 3.5 for movie 3893
# Storing rating 3.272727272727273 for movie 170
# Storing rating 3.7142857142857144 for movie 849
# Storing rating 3.2857142857142856 for movie 1186
# Storing rating 3.0 for movie 1235
# Storing rating 3.2857142857142856 for movie 1244
# Storing rating 4.5 for movie 1296
# Storing rating 3.0714285714285716 for movie 1663
# Storing rating 4.0 for movie 1962
# Storing rating 3.5 for movie 2108
# Storing rating 4.5 for movie 2243
# Storing rating 4.0 for movie 2352
# Storing rating 3.5 for movie 2707
# Storing rating 4.0 for movie 2746
# Storing rating 3.5 for movie 2915
# Storing rating 4.0 for movie 3363
# Storing rating 3.0 for movie 640
# Storing rating 4.0 for movie 828
# Storing rating 3.0 for movie 960
# Storing rating 4.0 for movie 1221
# Storing rating 4.0 for movie 1321
# Storing rating 4.125 for movie 1645
# Storing rating 3.0 for movie 1825
# Storing rating 2.0 for movie 1985
# Storing rating 3.0 for movie 2024
# Storing rating 4.944444444444445 for movie 2028
# Storing rating 4.0 for movie 3171
# Storing rating 4.1875 for movie 1
# Storing rating 4.0 for movie 2
# Storing rating 2.142857142857143 for movie 5
# Storing rating 4.5 for movie 6
# Storing rating 4.0 for movie 10
# Storing rating 3.5 for movie 11
# Storing rating 4.0 for movie 16
# Storing rating 2.0 for movie 19
# Storing rating 2.5 for movie 20
# Storing rating 3.0 for movie 23
# Storing rating 4.5 for movie 25
# Storing rating 3.0 for movie 31
# Storing rating 4.375 for movie 32
# Storing rating 3.5 for movie 34
# Storing rating 3.5 for movie 36
# Storing rating 2.5 for movie 39
# Storing rating 4.5 for movie 41
# Storing rating 1.0 for movie 44
# Storing rating 2.1666666666666665 for movie 45
# Storing rating 4.75 for movie 47
# Storing rating 4.6875 for movie 50
# Storing rating 3.0 for movie 61
# Storing rating 3.5833333333333335 for movie 62
# Storing rating 0.5 for movie 65
# Storing rating 0.5 for movie 66
# Storing rating 3.0 for movie 70
# Storing rating 2.0 for movie 76
# Storing rating 4.0 for movie 85
# Storing rating 4.5 for movie 95
# Storing rating 4.0 for movie 100
# Storing rating 3.0 for movie 104
# Storing rating 4.5 for movie 110
# Storing rating 4.642857142857143 for movie 141
# Storing rating 4.0 for movie 145
# Storing rating 4.0 for movie 150
# Storing rating 4.5 for movie 151
# Storing rating 2.3333333333333335 for movie 153
# Storing rating 1.0 for movie 158
# Storing rating 2.5 for movie 160
# Storing rating 4.0 for movie 161
# Storing rating 2.75 for movie 163
# Storing rating 4.5 for movie 165
# Storing rating 0.5 for movie 169
# Storing rating 3.25 for movie 170
# Storing rating 3.5 for movie 172
# Storing rating 3.4166666666666665 for movie 173
# Storing rating 3.5 for movie 175
# Storing rating 4.5 for movie 180
# Storing rating 0.5 for movie 181
# Storing rating 3.0 for movie 185
# Storing rating 2.0833333333333335 for movie 186
# Storing rating 0.5 for movie 193
# Storing rating 4.5 for movie 198
# Storing rating 3.357142857142857 for movie 204
# Storing rating 2.3333333333333335 for movie 216
# Storing rating 4.583333333333333 for movie 223
# Storing rating 0.5 for movie 231
# Storing rating 4.5 for movie 253
# Storing rating 0.5 for movie 255
# Storing rating 2.5 for movie 256
# Storing rating 4.5 for movie 260
# Storing rating 3.5 for movie 267
# Storing rating 4.125 for movie 288
# Storing rating 3.5 for movie 292
# Storing rating 4.25 for movie 293
# Storing rating 4.666666666666667 for movie 296
# Storing rating 1.75 for movie 315
# Storing rating 4.5 for movie 316
# Storing rating 2.0 for movie 317
# Storing rating 4.642857142857143 for movie 318
# Storing rating 1.5 for movie 327
# Storing rating 3.5 for movie 329
# Storing rating 2.0 for movie 332
# Storing rating 1.5 for movie 333
# Storing rating 2.5 for movie 338
# Storing rating 0.5 for movie 339
# Storing rating 3.0 for movie 344
# Storing rating 5.0 for movie 349
# Storing rating 2.25 for movie 350
# Storing rating 3.75 for movie 353
# Storing rating 3.625 for movie 356
# Storing rating 3.5 for movie 361
# Storing rating 4.0 for movie 364
# Storing rating 2.625 for movie 367
# Storing rating 3.5 for movie 368
# Storing rating 2.0 for movie 370
# Storing rating 3.5 for movie 377
# Storing rating 1.5 for movie 379
# Storing rating 3.75 for movie 380
# Storing rating 3.0 for movie 382
# Storing rating 3.0 for movie 405
# Storing rating 1.0 for movie 410
# Storing rating 2.25 for movie 420
# Storing rating 3.0 for movie 423
# Storing rating 2.5 for movie 432
# Storing rating 1.25 for movie 434
# Storing rating 2.0 for movie 435
# Storing rating 3.75 for movie 440
# Storing rating 2.25 for movie 442
# Storing rating 2.5 for movie 454
# Storing rating 2.0 for movie 455
# Storing rating 4.375 for movie 457
# Storing rating 2.5 for movie 466
# Storing rating 4.5 for movie 471
# Storing rating 3.5 for movie 474
# Storing rating 4.125 for movie 480
# Storing rating 3.6666666666666665 for movie 481
# Storing rating 0.5 for movie 485
# Storing rating 4.0 for movie 494
# Storing rating 3.0 for movie 500
# Storing rating 4.5 for movie 514
# Storing rating 3.5 for movie 517
# Storing rating 3.5 for movie 520
# Storing rating 4.0 for movie 524
# Storing rating 4.5 for movie 527
# Storing rating 0.5 for movie 539
# Storing rating 4.375 for movie 541
# Storing rating 0.5 for movie 546
# Storing rating 3.625 for movie 552
# Storing rating 2.5 for movie 586
# Storing rating 2.0 for movie 587
# Storing rating 3.0 for movie 588
# Storing rating 4.5 for movie 589
# Storing rating 4.0 for movie 590
# Storing rating 3.75 for movie 592
# Storing rating 4.166666666666667 for movie 593
# Storing rating 3.125 for movie 595
# Storing rating 3.0 for movie 597
# Storing rating 5.0 for movie 608
# Storing rating 4.0 for movie 610
# Storing rating 3.5 for movie 647
# Storing rating 3.75 for movie 648
# Storing rating 3.5 for movie 653
# Storing rating 3.0 for movie 724
# Storing rating 5.0 for movie 733
# Storing rating 3.5 for movie 736
# Storing rating 4.0 for movie 741
# Storing rating 3.125 for movie 762
# Storing rating 3.875 for movie 778
# Storing rating 3.75 for movie 780
# Storing rating 0.5 for movie 784
# Storing rating 4.0 for movie 785
# Storing rating 4.0 for movie 786
# Storing rating 1.0 for movie 788
# Storing rating 3.0 for movie 798
# Storing rating 4.0 for movie 805
# Storing rating 0.5 for movie 818
# Storing rating 4.0 for movie 832
# Storing rating 2.5 for movie 836
# Storing rating 3.5 for movie 852
# Storing rating 4.1 for movie 858
# Storing rating 3.5 for movie 875
# Storing rating 2.5 for movie 879
# Storing rating 4.25 for movie 919
# Storing rating 4.25 for movie 924
# Storing rating 4.0 for movie 941
# Storing rating 0.5 for movie 1015
# Storing rating 3.5 for movie 1020
# Storing rating 4.5 for movie 1036
# Storing rating 2.0 for movie 1037
# Storing rating 3.875 for movie 1047
# Storing rating 4.0 for movie 1049
# Storing rating 4.5 for movie 1059
# Storing rating 4.125 for movie 1079
# Storing rating 4.0 for movie 1080
# Storing rating 2.5 for movie 1088
# Storing rating 4.625 for movie 1089
# Storing rating 3.875 for movie 1090
# Storing rating 1.3333333333333333 for movie 1091
# Storing rating 4.0 for movie 1092
# Storing rating 2.2 for movie 1094
# Storing rating 3.0 for movie 1100
# Storing rating 4.0 for movie 1101
# Storing rating 3.5 for movie 1126
# Storing rating 4.5 for movie 1127
# Storing rating 4.75 for movie 1136
# Storing rating 5.0 for movie 1196
# Storing rating 4.625 for movie 1198
# Storing rating 3.0 for movie 1200
# Storing rating 1.5 for movie 1203
# Storing rating 2.875 for movie 1207
# Storing rating 4.0 for movie 1208
# Storing rating 4.375 for movie 1210
# Storing rating 2.0 for movie 1214
# Storing rating 4.0 for movie 1215
# Storing rating 0.5 for movie 1220
# Storing rating 5.0 for movie 1222
# Storing rating 3.75 for movie 1240
# Storing rating 5.0 for movie 1242
# Storing rating 3.0 for movie 1259
# Storing rating 2.5 for movie 1265
# Storing rating 4.0 for movie 1270
# Storing rating 3.125 for movie 1274
# Storing rating 5.0 for movie 1275
# Storing rating 4.5 for movie 1291
# Storing rating 3.5 for movie 1320
# Storing rating 4.5 for movie 1339
# Storing rating 3.625 for movie 1356
# Storing rating 4.0 for movie 1370
# Storing rating 4.5 for movie 1372
# Storing rating 4.0 for movie 1374
# Storing rating 3.5 for movie 1375
# Storing rating 3.5 for movie 1376
# Storing rating 2.0 for movie 1377
# Storing rating 3.5 for movie 1385
# Storing rating 1.75 for movie 1391
# Storing rating 2.9 for movie 1393
# Storing rating 5.0 for movie 1396
# Storing rating 0.5 for movie 1405
# Storing rating 2.0 for movie 1407
# Storing rating 5.0 for movie 1425
# Storing rating 1.5 for movie 1445
# Storing rating 5.0 for movie 1466
# Storing rating 2.5 for movie 1476
# Storing rating 2.0 for movie 1485
# Storing rating 3.0 for movie 1500
# Storing rating 1.0 for movie 1515
# Storing rating 3.125 for movie 1517
# Storing rating 3.0 for movie 1518
# Storing rating 5.0 for movie 1527
# Storing rating 2.375 for movie 1544
# Storing rating 3.5 for movie 1552
# Storing rating 1.0 for movie 1562
# Storing rating 4.0 for movie 1580
# Storing rating 4.0 for movie 1584
# Storing rating 3.5 for movie 1586
# Storing rating 2.8333333333333335 for movie 1590
# Storing rating 2.1666666666666665 for movie 1591
# Storing rating 0.5 for movie 1592
# Storing rating 3.5 for movie 1597
# Storing rating 4.0 for movie 1606
# Storing rating 3.5 for movie 1608
# Storing rating 5.0 for movie 1610
# Storing rating 4.5 for movie 1615
# Storing rating 3.5 for movie 1616
# Storing rating 4.875 for movie 1617
# Storing rating 5.0 for movie 1625
# Storing rating 3.5 for movie 1641
# Storing rating 2.0 for movie 1642
# Storing rating 4.166666666666667 for movie 1645
# Storing rating 3.0 for movie 1647
# Storing rating 3.5 for movie 1653
# Storing rating 2.5 for movie 1665
# Storing rating 3.0 for movie 1673
# Storing rating 3.5 for movie 1676
# Storing rating 4.375 for movie 1682
# Storing rating 4.5 for movie 1687
# Storing rating 3.5 for movie 1690
# Storing rating 3.8 for movie 1704
# Storing rating 0.5 for movie 1721
# Storing rating 3.875 for movie 1722
# Storing rating 2.3 for movie 1732
# Storing rating 4.0 for movie 1747
# Storing rating 5.0 for movie 1748
# Storing rating 0.5 for movie 1760
# Storing rating 4.0 for movie 1769
# Storing rating 3.0 for movie 1779
# Storing rating 3.0 for movie 1784
# Storing rating 4.0 for movie 1792
# Storing rating 4.5 for movie 1805
# Storing rating 4.5 for movie 1810
# Storing rating 3.5 for movie 1831
# Storing rating 3.375 for movie 1876
# Storing rating 3.0 for movie 1882
# Storing rating 2.5 for movie 1884
# Storing rating 4.5 for movie 1892
# Storing rating 3.0 for movie 1909
# Storing rating 3.875 for movie 1917
# Storing rating 4.0 for movie 1918
# Storing rating 2.0 for movie 1921
# Storing rating 3.5 for movie 1923
# Storing rating 3.0 for movie 1961
# Storing rating 4.0 for movie 1967
# Storing rating 0.5 for movie 1968
# Storing rating 4.5 for movie 2000
# Storing rating 3.75 for movie 2001
# Storing rating 4.0 for movie 2002
# Storing rating 2.5 for movie 2003
# Storing rating 2.5 for movie 2004
# Storing rating 4.0 for movie 2006
# Storing rating 4.0 for movie 2011
# Storing rating 3.0 for movie 2012
# Storing rating 3.0 for movie 2021
# Storing rating 4.95 for movie 2028
# Storing rating 1.5 for movie 2036
# Storing rating 3.5 for movie 2046
# Storing rating 1.5 for movie 2053
# Storing rating 2.5 for movie 2054
# Storing rating 4.0 for movie 2058
# Storing rating 2.0 for movie 2081
# Storing rating 3.0 for movie 2082
# Storing rating 2.0 for movie 2094
# Storing rating 2.875 for movie 2100
# Storing rating 4.0 for movie 2105
# Storing rating 4.5 for movie 2115
# Storing rating 3.5 for movie 2126
# Storing rating 2.0 for movie 2133
# Storing rating 4.75 for movie 2140
# Storing rating 4.0 for movie 2150
# Storing rating 0.5 for movie 2152
# Storing rating 1.5 for movie 2153
# Storing rating 3.5 for movie 2161
# Storing rating 4.5 for movie 2167
# Storing rating 3.0 for movie 2174
# Storing rating 5.0 for movie 2193
# Storing rating 5.0 for movie 2194
# Storing rating 5.0 for movie 2231
# Storing rating 4.0 for movie 2268
# Storing rating 4.0 for movie 2273
# Storing rating 5.0 for movie 2278
# Storing rating 3.5 for movie 2291
# Storing rating 3.6666666666666665 for movie 2294
# Storing rating 1.5 for movie 2296
# Storing rating 3.5 for movie 2302
# Storing rating 4.0 for movie 2311
# Storing rating 4.0 for movie 2334
# Storing rating 3.0 for movie 2335
# Storing rating 3.8333333333333335 for movie 2353
# Storing rating 4.0 for movie 2355
# Storing rating 2.5 for movie 2378
# Storing rating 3.0 for movie 2379
# Storing rating 0.5 for movie 2381
# Storing rating 4.5 for movie 2391
# Storing rating 3.5 for movie 2393
# Storing rating 4.0 for movie 2405
# Storing rating 4.0 for movie 2406
# Storing rating 3.0 for movie 2407
# Storing rating 2.5 for movie 2424
# Storing rating 4.0 for movie 2433
# Storing rating 0.5 for movie 2450
# Storing rating 3.5 for movie 2468
# Storing rating 3.0 for movie 2470
# Storing rating 2.0 for movie 2471
# Storing rating 3.75 for movie 2478
# Storing rating 4.0 for movie 2490
# Storing rating 4.0 for movie 2501
# Storing rating 4.3 for movie 2502
# Storing rating 4.0 for movie 2505
# Storing rating 4.0 for movie 2539
# Storing rating 3.5 for movie 2541
# Storing rating 4.5 for movie 2542
# Storing rating 3.0 for movie 2549
# Storing rating 4.5 for movie 2571
# Storing rating 3.5 for movie 2600
# Storing rating 4.0 for movie 2605
# Storing rating 3.5 for movie 2616
# Storing rating 4.0 for movie 2617
# Storing rating 2.5 for movie 2628
# Storing rating 3.5 for movie 2640
# Storing rating 3.0 for movie 2641
# Storing rating 4.5 for movie 2672
# Storing rating 3.5 for movie 2683
# Storing rating 4.0 for movie 2688
# Storing rating 0.5 for movie 2700
# Storing rating 2.5 for movie 2701
# Storing rating 4.0 for movie 2706
# Storing rating 0.5 for movie 2710
# Storing rating 1.0 for movie 2712
# Storing rating 3.6666666666666665 for movie 2716
# Storing rating 3.0 for movie 2717
# Storing rating 3.5 for movie 2718
# Storing rating 1.5 for movie 2720
# Storing rating 3.0 for movie 2722
# Storing rating 4.0 for movie 2723
# Storing rating 5.0 for movie 2762
# Storing rating 4.5 for movie 2763
# Storing rating 4.5 for movie 2764
# Storing rating 2.5 for movie 2770
# Storing rating 3.8333333333333335 for movie 2791
# Storing rating 3.5 for movie 2792
# Storing rating 3.5 for movie 2794
# Storing rating 1.5 for movie 2797
# Storing rating 3.5 for movie 2803
# Storing rating 2.5 for movie 2805
# Storing rating 3.0 for movie 2808
# Storing rating 2.5 for movie 2816
# Storing rating 3.125 for movie 2840
# Storing rating 4.4 for movie 2858
# Storing rating 3.5 for movie 2860
# Storing rating 3.0 for movie 2881
# Storing rating 4.0 for movie 2889
# Storing rating 4.0 for movie 2890
# Storing rating 4.0 for movie 2916
# Storing rating 4.0 for movie 2918
# Storing rating 4.0 for movie 2947
# Storing rating 4.5 for movie 2948
# Storing rating 4.5 for movie 2949
# Storing rating 0.5 for movie 2953
# Storing rating 4.75 for movie 2959
# Storing rating 3.0 for movie 2985
# Storing rating 2.25 for movie 2986
# Storing rating 4.0 for movie 2987
# Storing rating 4.0 for movie 2989
# Storing rating 3.5 for movie 2990
# Storing rating 4.5 for movie 2991
# Storing rating 4.0 for movie 2993
# Storing rating 4.0 for movie 2997
# Storing rating 4.5 for movie 3000
# Storing rating 3.875 for movie 3020
# Storing rating 5.0 for movie 3033
# Storing rating 3.5 for movie 3039
# Storing rating 4.333333333333333 for movie 3052
# Storing rating 3.0 for movie 3063
# Storing rating 3.6666666666666665 for movie 3082
# Storing rating 3.5 for movie 3087
# Storing rating 3.6666666666666665 for movie 3107
# Storing rating 3.5 for movie 3113
# Storing rating 3.3333333333333335 for movie 3114
# Storing rating 3.5 for movie 3146
# Storing rating 3.5 for movie 3156
# Storing rating 3.8333333333333335 for movie 3173
# Storing rating 3.5 for movie 3190
# Storing rating 4.0 for movie 3208
# Storing rating 1.5 for movie 3247
# Storing rating 0.5 for movie 3248
# Storing rating 3.0 for movie 3249
# Storing rating 4.0 for movie 3250
# Storing rating 4.5 for movie 3252
# Storing rating 2.6666666666666665 for movie 3253
# Storing rating 2.0 for movie 3254
# Storing rating 4.0 for movie 3255
# Storing rating 5.0 for movie 3256
# Storing rating 2.0 for movie 3263
# Storing rating 3.5 for movie 3264
# Storing rating 0.5 for movie 3268
# Storing rating 4.5 for movie 3275
# Storing rating 4.5 for movie 3298
# Storing rating 3.5 for movie 3300
# Storing rating 4.5 for movie 3301
# Storing rating 3.0 for movie 3316
# Storing rating 3.5 for movie 3354
# Storing rating 3.0 for movie 3388
# Storing rating 4.0 for movie 3448
# Storing rating 4.0 for movie 3452
# Storing rating 4.0 for movie 3479
# Storing rating 2.5 for movie 3481
# Storing rating 4.0 for movie 3489
# Storing rating 4.0 for movie 3513
# Storing rating 4.5 for movie 3527
# Storing rating 4.0 for movie 3552
# Storing rating 4.0 for movie 3555
# Storing rating 4.666666666666667 for movie 3578
# Storing rating 1.0 for movie 3593
# Storing rating 1.5 for movie 3608
# Storing rating 4.0 for movie 3617
# Storing rating 2.8333333333333335 for movie 3623
# Storing rating 4.5 for movie 3635
# Storing rating 4.0 for movie 3638
# Storing rating 3.5 for movie 3639
# Storing rating 3.5 for movie 3697
# Storing rating 3.625 for movie 3698
# Storing rating 4.0 for movie 3702
# Storing rating 4.333333333333333 for movie 3703
# Storing rating 3.0 for movie 3704
# Storing rating 4.5 for movie 3717
# Storing rating 4.5 for movie 3740
# Storing rating 4.5 for movie 3745
# Storing rating 4.0 for movie 3751
# Storing rating 4.0 for movie 3753
# Storing rating 3.5 for movie 3755
# Storing rating 4.0 for movie 3763
# Storing rating 4.166666666666667 for movie 3793
# Storing rating 4.0 for movie 3809
# Storing rating 2.5 for movie 3825
# Storing rating 2.25 for movie 3826
# Storing rating 2.5 for movie 3827
# Storing rating 3.0 for movie 3835
# Storing rating 4.0 for movie 3841
# Storing rating 3.5 for movie 3868
# Storing rating 3.0 for movie 3869
# Storing rating 3.5 for movie 3879
# Storing rating 3.0 for movie 3889
# Storing rating 3.5 for movie 3916
# Storing rating 4.0 for movie 3948
# Storing rating 4.5 for movie 3952
# Storing rating 3.1666666666666665 for movie 3977
# Storing rating 3.5 for movie 3980
# Storing rating 2.0 for movie 3981
# Storing rating 4.5 for movie 3984
# Storing rating 0.5 for movie 3990
# Storing rating 4.5 for movie 3994
# Storing rating 4.5 for movie 3996
# Storing rating 2.0 for movie 3997
# Storing rating 3.5 for movie 4005
# Storing rating 4.5 for movie 4011
# Storing rating 0.5 for movie 4015
# Storing rating 2.5 for movie 4018
# Storing rating 3.5 for movie 4019
# Storing rating 0.5 for movie 4022
# Storing rating 0.5 for movie 4025
# Storing rating 5.0 for movie 4034
# Storing rating 4.0 for movie 4052
# Storing rating 3.5 for movie 4084
# Storing rating 4.0 for movie 4085
# Storing rating 2.0 for movie 4104
# Storing rating 2.5 for movie 4121
# Storing rating 3.5 for movie 4148
# Storing rating 3.0 for movie 4167
# Storing rating 4.0 for movie 4207
# Storing rating 2.0 for movie 4214
# Storing rating 4.0 for movie 4223
# Storing rating 4.75 for movie 4226
# Storing rating 0.5 for movie 4232
# Storing rating 4.0 for movie 4238
# Storing rating 3.5 for movie 4239
# Storing rating 0.5 for movie 4246
# Storing rating 5.0 for movie 4262
# Storing rating 4.0 for movie 4270
# Storing rating 4.833333333333333 for movie 4306
# Storing rating 0.5 for movie 4308
# Storing rating 3.0 for movie 4321
# Storing rating 3.0 for movie 4343
# Storing rating 4.0 for movie 4344
# Storing rating 4.0 for movie 4351
# Storing rating 3.5 for movie 4367
# Storing rating 3.0 for movie 4396
# Storing rating 3.5 for movie 4446
# Storing rating 4.5 for movie 4448
# Storing rating 3.0 for movie 4483
# Storing rating 2.5 for movie 4487
# Storing rating 2.0 for movie 4544
# Storing rating 3.0 for movie 4545
# Storing rating 1.0 for movie 4571
# Storing rating 2.0 for movie 4621
# Storing rating 3.1666666666666665 for movie 4638
# Storing rating 3.0 for movie 4643
# Storing rating 2.0 for movie 4678
# Storing rating 2.0 for movie 4679
# Storing rating 4.0 for movie 4701
# Storing rating 4.0 for movie 4718
# Storing rating 3.5 for movie 4719
# Storing rating 3.5 for movie 4721
# Storing rating 4.0 for movie 4734
# Storing rating 4.0 for movie 4776
# Storing rating 4.5 for movie 4844
# Storing rating 4.5 for movie 4874
# Storing rating 4.5 for movie 4878
# Storing rating 4.625 for movie 4886
# Storing rating 4.0 for movie 4889
# Storing rating 3.5 for movie 4890
# Storing rating 3.0 for movie 4896
# Storing rating 5.0 for movie 4901
# Storing rating 4.5 for movie 4958
# Storing rating 4.166666666666667 for movie 4963
# Storing rating 4.0 for movie 4975
# Storing rating 0.5 for movie 4979
# Storing rating 1.0 for movie 4980
# Storing rating 2.5 for movie 4992
# Storing rating 3.3333333333333335 for movie 4993
# Storing rating 4.0 for movie 4995
# Storing rating 5.0 for movie 5010
# Storing rating 4.0 for movie 5049
# Storing rating 5.0 for movie 5064
# Storing rating 4.5 for movie 5069
# Storing rating 3.5 for movie 5107
# Storing rating 4.333333333333333 for movie 5110
# Storing rating 4.5 for movie 5152
# Storing rating 3.6666666666666665 for movie 5218
# Storing rating 4.0 for movie 5219
# Storing rating 4.0 for movie 5254
# Storing rating 3.5 for movie 5283
# Storing rating 3.5 for movie 5299
# Storing rating 4.5 for movie 5349
# Storing rating 3.0 for movie 5378
# Storing rating 5.0 for movie 5388
# Storing rating 3.0 for movie 5400
# Storing rating 5.0 for movie 5418
# Storing rating 2.5 for movie 5438
# Storing rating 4.5 for movie 5445
# Storing rating 3.5 for movie 5459
# Storing rating 3.5 for movie 5463
# Storing rating 5.0 for movie 5464
# Storing rating 3.0 for movie 5481
# Storing rating 4.0 for movie 5502
# Storing rating 0.5 for movie 5504
# Storing rating 3.5 for movie 5507
# Storing rating 3.0 for movie 5541
# Storing rating 3.5 for movie 5563
# Storing rating 3.0 for movie 5665
# Storing rating 4.0 for movie 5679
# Storing rating 4.5 for movie 5782
# Storing rating 3.0 for movie 5816
# Storing rating 4.0 for movie 5872
# Storing rating 2.0 for movie 5876
# Storing rating 3.5 for movie 5882
# Storing rating 5.0 for movie 5903
# Storing rating 3.5 for movie 5944
# Storing rating 1.0 for movie 5945
# Storing rating 4.166666666666667 for movie 5952
# Storing rating 3.0 for movie 5954
# Storing rating 3.5 for movie 5956
# Storing rating 4.0 for movie 5959
# Storing rating 4.0 for movie 5989
# Storing rating 3.5 for movie 5999
# Storing rating 2.5 for movie 6003
# Storing rating 4.666666666666667 for movie 6016
# Storing rating 4.5 for movie 6059
# Storing rating 4.5 for movie 6104
# Storing rating 4.0 for movie 6188
# Storing rating 4.0 for movie 6213
# Storing rating 3.0 for movie 6264
# Storing rating 4.0 for movie 6281
# Storing rating 5.0 for movie 6283
# Storing rating 4.0 for movie 6294
# Storing rating 4.166666666666667 for movie 6322
# Storing rating 4.5 for movie 6333
# Storing rating 2.0 for movie 6365
# Storing rating 3.5 for movie 6373
# Storing rating 4.5 for movie 6377
# Storing rating 4.0 for movie 6378
# Storing rating 2.0 for movie 6383
# Storing rating 3.5 for movie 6534
# Storing rating 0.5 for movie 6535
# Storing rating 4.0 for movie 6537
# Storing rating 5.0 for movie 6539
# Storing rating 2.0 for movie 6541
# Storing rating 3.0 for movie 6548
# Storing rating 3.5 for movie 6550
# Storing rating 3.5 for movie 6564
# Storing rating 4.0 for movie 6586
# Storing rating 4.0 for movie 6595
# Storing rating 3.0 for movie 6659
# Storing rating 4.0 for movie 6679
# Storing rating 4.5 for movie 6708
# Storing rating 4.0 for movie 6754
# Storing rating 4.0 for movie 6764
# Storing rating 0.5 for movie 6794
# Storing rating 4.0 for movie 6807
# Storing rating 3.5 for movie 6857
# Storing rating 4.5 for movie 6874
# Storing rating 4.0 for movie 6879
# Storing rating 3.0 for movie 6934
# Storing rating 3.5 for movie 6947
# Storing rating 3.0 for movie 6966
# Storing rating 4.5 for movie 6979
# Storing rating 0.5 for movie 7004
# Storing rating 3.5 for movie 7102
# Storing rating 5.0 for movie 7143
# Storing rating 5.0 for movie 7147
# Storing rating 4.0 for movie 7153
# Storing rating 4.5 for movie 7346
# Storing rating 4.5 for movie 7348
# Storing rating 4.75 for movie 7361
# Storing rating 0.5 for movie 7369
# Storing rating 4.0 for movie 7373
# Storing rating 4.5 for movie 7438
# Storing rating 1.0 for movie 7444
# Storing rating 3.5 for movie 7454
# Storing rating 4.5 for movie 7458
# Storing rating 3.5 for movie 7481
# Storing rating 4.5 for movie 7569
# Storing rating 4.0 for movie 7573
# Storing rating 4.5 for movie 7649
# Storing rating 4.0 for movie 7704
# Storing rating 4.0 for movie 7810
# Storing rating 4.0 for movie 7811
# Storing rating 4.0 for movie 7812
# Storing rating 4.5 for movie 7841
# Storing rating 5.0 for movie 7842
# Storing rating 5.0 for movie 8132
# Storing rating 4.0 for movie 8169
# Storing rating 5.0 for movie 8360
# Storing rating 3.5 for movie 8361
# Storing rating 5.0 for movie 8371
# Storing rating 0.5 for movie 8376
# Storing rating 3.5 for movie 8464
# Storing rating 4.5 for movie 8528
# Storing rating 4.0 for movie 8622
# Storing rating 4.0 for movie 8633
# Storing rating 5.0 for movie 8636
# Storing rating 1.0 for movie 8641
# Storing rating 4.0 for movie 8644
# Storing rating 5.0 for movie 8665
# Storing rating 4.0 for movie 8781
# Storing rating 3.5 for movie 8798
# Storing rating 4.0 for movie 8807
# Storing rating 4.0 for movie 8810
# Storing rating 4.0 for movie 8861
# Storing rating 5.0 for movie 8874
# Storing rating 0.5 for movie 8912
# Storing rating 5.0 for movie 8914
# Storing rating 4.0 for movie 8919
# Storing rating 5.0 for movie 8961
# Storing rating 4.0 for movie 8972
# Storing rating 4.5 for movie 8982
# Storing rating 4.0 for movie 8985
# Storing rating 3.0 for movie 9005
# Storing rating 3.5 for movie 26819
# Storing rating 1.5 for movie 26870
# Storing rating 5.0 for movie 27773
# Storing rating 5.0 for movie 27846
# Storing rating 4.5 for movie 27905
# Storing rating 5.0 for movie 31184
# Storing rating 4.0 for movie 31696
# Storing rating 4.5 for movie 31804
# Storing rating 5.0 for movie 31878
# Storing rating 3.5 for movie 32302
# Storing rating 4.833333333333333 for movie 32587
# Storing rating 4.0 for movie 33004
# Storing rating 4.5 for movie 33437
# Storing rating 3.5 for movie 33493
# Storing rating 4.0 for movie 33646
# Storing rating 4.5 for movie 33679
# Storing rating 4.666666666666667 for movie 33794
# Storing rating 4.0 for movie 33834
# Storing rating 5.0 for movie 34162
# Storing rating 4.5 for movie 34319
# Storing rating 4.5 for movie 36529
# Storing rating 2.0 for movie 37380
# Storing rating 4.0 for movie 37733
# Storing rating 4.333333333333333 for movie 38061
# Storing rating 0.5 for movie 39231
# Storing rating 0.5 for movie 39435
# Storing rating 4.0 for movie 40278
# Storing rating 4.0 for movie 40614
# Storing rating 0.5 for movie 42721
# Storing rating 4.5 for movie 42738
# Storing rating 0.5 for movie 43558
# Storing rating 0.5 for movie 43679
# Storing rating 0.5 for movie 43708
# Storing rating 4.5 for movie 43936
# Storing rating 5.0 for movie 44191
# Storing rating 0.5 for movie 44193
# Storing rating 5.0 for movie 44199
# Storing rating 0.5 for movie 44399
# Storing rating 0.5 for movie 44759
# Storing rating 4.5 for movie 48774
# Storing rating 4.5 for movie 51662
# Storing rating 4.0 for movie 51935
# Storing rating 4.5 for movie 52950
# Storing rating 4.0 for movie 53000
# Storing rating 3.5 for movie 53972
# Storing rating 3.5625 for movie 307
# Storing rating 4.5 for movie 53996
# Storing rating 4.666666666666667 for movie 54286
# Storing rating 4.333333333333333 for movie 55765
# Storing rating 4.666666666666667 for movie 56367
# Storing rating 4.666666666666667 for movie 47
# Storing rating 4.722222222222222 for movie 50
# Storing rating 4.1 for movie 293
# Storing rating 4.714285714285714 for movie 296
# Storing rating 4.6875 for movie 318
# Storing rating 4.5 for movie 527
# Storing rating 3.0 for movie 728
# Storing rating 4.1 for movie 778
# Storing rating 4.166666666666667 for movie 858
# Storing rating 4.5 for movie 1147
# Storing rating 3.125 for movie 1186
# Storing rating 4.375 for movie 1193
# Storing rating 5.0 for movie 1213
# Storing rating 5.0 for movie 1222
# Storing rating 4.8 for movie 1617
# Storing rating 2.75 for movie 1732
# Storing rating 3.5 for movie 2060
# Storing rating 4.5 for movie 2329
# Storing rating 3.0 for movie 2485
# Storing rating 4.25 for movie 2502
# Storing rating 4.5 for movie 2858
# Storing rating 4.7 for movie 2959
# Storing rating 3.75 for movie 3173
# Storing rating 4.0 for movie 3178
# Storing rating 4.0 for movie 3949
# Storing rating 4.5 for movie 4011
# Storing rating 4.8 for movie 4226
# Storing rating 4.666666666666667 for movie 4973
# Storing rating 3.65 for movie 481
# Storing rating 4.25 for movie 5110
# Storing rating 4.5 for movie 5137
# Storing rating 1.35 for movie 1091
# Storing rating 3.5 for movie 5528
# Storing rating 4.5 for movie 1257
# Storing rating 4.5 for movie 1449
# Storing rating 3.2 for movie 5954
# Storing rating 2.8 for movie 1590
# Storing rating 5.0 for movie 5995
# Storing rating 2.1 for movie 1591
# Storing rating 4.75 for movie 6016
# Storing rating 4.0 for movie 6322
# Storing rating 4.5 for movie 2134
# Storing rating 4.8 for movie 7361
# Storing rating 4.5 for movie 8784
# Storing rating 3.7777777777777777 for movie 2478
# Storing rating 4.0 for movie 8873
# Storing rating 3.111111111111111 for movie 2840
# Storing rating 4.0 for movie 8949
# Storing rating 2.2777777777777777 for movie 2986
# Storing rating 4.5 for movie 8950
# Storing rating 3.888888888888889 for movie 3020
# Storing rating 4.0 for movie 27831
# Storing rating 4.5 for movie 3424
# Storing rating 4.0 for movie 30749
# Storing rating 3.611111111111111 for movie 3698
# Storing rating 4.0 for movie 30820
# Storing rating 2.2222222222222223 for movie 3826
# Storing rating 4.0 for movie 31410
# Storing rating 3.5 for movie 3893
# Storing rating 4.75 for movie 32587
# Storing rating 4.5 for movie 33794
# Storing rating 3.269230769230769 for movie 170
# Storing rating 4.25 for movie 38061
# Storing rating 3.6875 for movie 849
# Storing rating 4.0 for movie 40278
# Storing rating 3.1666666666666665 for movie 1186
# Storing rating 5.0 for movie 44195
# Storing rating 3.0 for movie 1235
# Storing rating 3.25 for movie 1244
# Storing rating 4.5 for movie 1296
# Storing rating 3.0625 for movie 1663
# Storing rating 4.0 for movie 44204
# Storing rating 4.0 for movie 1962
# Storing rating 3.5 for movie 46578
# Storing rating 3.5 for movie 2108
# Storing rating 5.0 for movie 46976
# Storing rating 4.0 for movie 48394
# Storing rating 4.5 for movie 48516
# Storing rating 4.5 for movie 2243
# Storing rating 4.0 for movie 48696
# Storing rating 4.0 for movie 2352
# Storing rating 3.5 for movie 2707
# Storing rating 4.5 for movie 48774
# Storing rating 4.0 for movie 2746
# Storing rating 4.0 for movie 48780
# Storing rating 4.0 for movie 49272
# Storing rating 3.5 for movie 2915
# Storing rating 4.0 for movie 49530
# Storing rating 4.0 for movie 3363
# Storing rating 4.5 for movie 50068
# Storing rating 3.0 for movie 640
# Storing rating 4.0 for movie 51255
# Storing rating 4.0 for movie 828
# Storing rating 4.5 for movie 52952
# Storing rating 4.5 for movie 54286
# Storing rating 3.0 for movie 960
# Storing rating 4.0 for movie 54503
# Storing rating 4.0 for movie 1221
# Storing rating 4.0 for movie 1321
# Storing rating 4.5 for movie 54997
# Storing rating 4.0 for movie 55118
# Storing rating 4.15 for movie 1645
# Storing rating 5.0 for movie 55247
# Storing rating 3.0 for movie 1825
# Storing rating 4.0 for movie 55290
# Storing rating 4.25 for movie 55765
# Storing rating 2.0 for movie 1985
# Storing rating 4.5 for movie 55820
# Storing rating 3.0 for movie 2024
# Storing rating 4.75 for movie 56367
# Storing rating 4.954545454545454 for movie 2028
# Storing rating 4.5 for movie 56782
# Storing rating 4.0 for movie 10
# Storing rating 4.0 for movie 3171
# Storing rating 4.166666666666667 for movie 1
# Storing rating 4.0 for movie 21
# Storing rating 4.0 for movie 2
# Storing rating 2.125 for movie 5
# Storing rating 4.5 for movie 6
# Storing rating 4.444444444444445 for movie 32
# Storing rating 4.0 for movie 10

# %%
mean_rating_producer_report.print_stats(sort = SortKey.TIME)
# Out:
#          2235875 function calls (2211762 primitive calls) in 13.240 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      4203    2.400    0.001    2.400    0.001 {method 'acquire' of '_thread.lock' objects}
#      4000    1.874    0.000    1.874    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      1000    1.772    0.002    1.772    0.002 {pandas._libs.writers.write_csv_rows}
#      4002    0.777    0.000    0.777    0.000 {method 'sendall' of '_socket.socket' objects}
#      1000    0.698    0.001    0.700    0.001 {built-in method io.open}
#      1000    0.415    0.000    0.415    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#      1003    0.137    0.000    0.148    0.000 {built-in method posix.stat}
# 288102/281102    0.134    0.000    0.264    0.000 {built-in method builtins.isinstance}
#      9190    0.106    0.000    0.391    0.000 fetcher.py:455(_unpack_message_set)
#        25    0.102    0.004    0.102    0.004 {method 'poll' of 'select.epoll' objects}
#      3000    0.101    0.000    0.103    0.000 default.py:36(murmur2)
#         1    0.100    0.100    0.100    0.100 {built-in method time.sleep}
#      3000    0.094    0.000    0.131    0.000 missing.py:268(_isna_array)
#      1000    0.091    0.000   12.045    0.012 mean_rating_producer.py:16(on_message)
#      2000    0.090    0.000    0.090    0.000 {built-in method posix.urandom}
#      2000    0.084    0.000    0.956    0.000 blocks.py:2279(to_native_types)
#      3000    0.076    0.000    1.481    0.000 kafka.py:538(send)
#      1000    0.070    0.000    0.083    0.000 {method 'get_slice' of 'pandas._libs.internals.BlockManager' objects}
# 188586/173576    0.063    0.000    0.083    0.000 {built-in method builtins.len}
#      9189    0.062    0.000    0.084    0.000 legacy_records.py:135(__init__)
#      3000    0.060    0.000    0.437    0.000 record_accumulator.py:200(append)
#      1000    0.057    0.000    4.603    0.005 csvs.py:296(_save_body)
#      2000    0.051    0.000    1.410    0.001 base.py:1527(_format_native_types)
#      2000    0.050    0.000    0.050    0.000 {built-in method _socket.gethostname}
#      2000    0.049    0.000    0.051    0.000 {built-in method numpy.array}
#      2000    0.044    0.000    0.064    0.000 cast.py:1932(np_can_hold_element)
#      3000    0.038    0.000    1.241    0.000 managers.py:297(apply)
#      3000    0.038    0.000    0.038    0.000 {method 'SerializeToString' of 'google.protobuf.pyext._message.CMessage' objects}
#     43000    0.037    0.000    0.050    0.000 generic.py:40(_check)
#      3000    0.037    0.000    0.068    0.000 legacy_records.py:391(_encode_msg)
#     43000    0.037    0.000    0.088    0.000 generic.py:45(_instancecheck)
#      1000    0.036    0.000    0.525    0.001 message_service.py:84(__report_consumption)
#      1000    0.036    0.000    4.524    0.005 csvs.py:306(_save_chunk)
#      2997    0.035    0.000    0.035    0.000 threading.py:236(__init__)
#      1000    0.035    0.000    0.682    0.001 message_service.py:34(__report_publication)
#      2000    0.035    0.000    0.052    0.000 numerictypes.py:573(_can_coerce_all)
#      3000    0.034    0.000    0.129    0.000 legacy_records.py:352(append)
#      1000    0.034    0.000    0.227    0.000 managers.py:1066(fast_xs)
#      1000    0.033    0.000    0.033    0.000 {method 'fill' of 'numpy.ndarray' objects}
#     10000    0.032    0.000    0.084    0.000 config.py:117(_get_single_key)
#         1    0.032    0.032   13.255   13.255 message_service.py:68(run)
#      9189    0.032    0.000    0.046    0.000 legacy_records.py:218(_read_key_value)
#      2000    0.031    0.000    0.645    0.000 indexing.py:1659(_setitem_with_indexer)
#      1000    0.030    0.000    1.104    0.001 common.py:646(get_handle)
#      3000    0.029    0.000    0.206    0.000 record_accumulator.py:57(try_append)
#      2000    0.029    0.000    0.036    0.000 uuid.py:138(__init__)
#     18378    0.029    0.000    0.094    0.000 legacy_records.py:235(__iter__)
# 2000/1000    0.029    0.000    6.553    0.007 _decorators.py:170(wrapper)
#      6000    0.028    0.000    0.245    0.000 missing.py:191(_isna)
#      1000    0.027    0.000    0.369    0.000 generic.py:3909(xs)
#      4000    0.026    0.000    0.028    0.000 base.py:5292(__contains__)
#      2000    0.026    0.000    0.121    0.000 managers.py:1169(iset)
#      2000    0.025    0.000    0.121    0.000 indexing.py:673(_get_setitem_indexer)
#     10000    0.025    0.000    0.032    0.000 config.py:598(_get_root)
#      9190    0.025    0.000    0.034    0.000 memory_records.py:68(_cache_next)
#      2000    0.024    0.000    0.834    0.000 indexing.py:807(__setitem__)
#      2000    0.023    0.000    0.034    0.000 generic.py:5849(__finalize__)
#      1000    0.023    0.000    0.060    0.000 csvs.py:223(encoded_labels)
#     11000    0.022    0.000    0.050    0.000 indexing.py:2652(check_deprecated_indexers)
#     54028    0.022    0.000    0.023    0.000 {built-in method builtins.getattr}
#      9190    0.022    0.000    0.146    0.000 memory_records.py:96(next_batch)
#      2000    0.022    0.000    0.505    0.000 indexing.py:1958(_setitem_single_column)
#      2000    0.022    0.000    0.028    0.000 generic.py:260(__init__)
#        59    0.022    0.000    0.022    0.000 socket.py:545(send)
#     20000    0.022    0.000    0.022    0.000 config.py:612(_get_deprecated_option)
#      3000    0.022    0.000    0.184    0.000 kafka.py:716(_partition)
#      8000    0.021    0.000    0.037    0.000 base.py:3756(get_loc)
#      2000    0.021    0.000    0.143    0.000 blocks.py:940(setitem)
#      3000    0.021    0.000    0.075    0.000 blocks.py:2169(new_block)
#     10000    0.020    0.000    0.136    0.000 config.py:135(_get_option)
#      9000    0.020    0.000    0.028    0.000 generic.py:565(_get_axis)
#      2000    0.020    0.000    0.029    0.000 managers.py:1117(iget)
#      2000    0.020    0.000    0.645    0.000 indexing.py:1060(__getitem__)
#     36757    0.020    0.000    0.020    0.000 {built-in method _struct.unpack_from}
#      4002    0.020    0.000    0.798    0.000 client_async.py:929(wakeup)
#      1000    0.020    0.000    6.543    0.007 generic.py:3537(to_csv)
#      1000    0.020    0.000    0.154    0.000 generic.py:4098(_slice)
#      4000    0.019    0.000    0.058    0.000 managers.py:1129(iget_values)
#      1000    0.019    0.000    0.019    0.000 {built-in method pandas._libs.missing.isnaobj}
#      8000    0.019    0.000    0.019    0.000 blocks.py:826(iget)
#      2000    0.019    0.000    0.559    0.000 indexing.py:1800(_setitem_with_indexer_split_path)
#      1000    0.019    0.000    6.408    0.006 format.py:1139(to_csv)
#      3000    0.019    0.000    0.040    0.000 kafka.py:664(_wait_on_metadata)
#     12000    0.018    0.000    0.018    0.000 {pandas._libs.lib.is_list_like}
#      1000    0.018    0.000    1.360    0.001 numeric.py:283(_format_native_types)
#      2000    0.018    0.000    0.437    0.000 managers.py:1354(column_setitem)
#      3000    0.018    0.000    0.074    0.000 series.py:967(__getitem__)
#      1000    0.018    0.000    0.123    0.000 cast.py:1590(find_common_type)
#      1000    0.018    0.000    3.909    0.004 message_service.py:24(publish)
#      4000    0.017    0.000    0.148    0.000 generic.py:5893(__getattr__)
#      6001    0.017    0.000    0.019    0.000 cluster.py:106(partitions_for_topic)
#      1000    0.017    0.000    2.470    0.002 record_accumulator.py:520(await_flush_completion)
#      2997    0.017    0.000    0.070    0.000 future.py:11(__init__)
#      2000    0.017    0.000    0.054    0.000 iostream.py:518(write)
#      1000    0.016    0.000    0.090    0.000 format.py:566(__init__)
#      1000    0.016    0.000    0.129    0.000 common.py:281(_get_filepath_or_buffer)
#      4000    0.016    0.000    0.036    0.000 generic.py:5909(__setattr__)
#      3000    0.016    0.000    0.034    0.000 cluster.py:119(available_partitions_for_topic)
#      6000    0.015    0.000    0.023    0.000 legacy_records.py:486(record_size)
#      1000    0.015    0.000    6.262    0.006 csvs.py:236(save)
#      2000    0.015    0.000    0.141    0.000 uuid.py:713(uuid4)
#      6000    0.015    0.000    0.016    0.000 construction.py:462(ensure_wrapped_if_datetimelike)
#      2997    0.015    0.000    0.086    0.000 record_accumulator.py:39(__init__)
#      3000    0.015    0.000    0.033    0.000 future.py:32(__init__)
#      2000    0.014    0.000    0.033    0.000 blocks.py:207(_standardize_fill_value)
#      1000    0.014    0.000    0.419    0.000 indexing.py:1277(_getitem_axis)
#     14000    0.014    0.000    0.014    0.000 numerictypes.py:582(<listcomp>)
#      2997    0.014    0.000    0.020    0.000 memory_records.py:118(__init__)
#      1000    0.014    0.000    0.028    0.000 common.py:530(infer_compression)
#      1036    0.014    0.000    2.420    0.002 threading.py:288(wait)
# 3000/2000    0.014    0.000    0.015    0.000 {built-in method numpy.asarray}
#      2000    0.014    0.000    0.014    0.000 uuid.py:279(__str__)
#      9189    0.014    0.000    0.020    0.000 legacy_records.py:198(_read_header)
#     11829    0.014    0.000    0.022    0.000 __init__.py:1455(debug)
#      8000    0.014    0.000    0.014    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#     12002    0.013    0.000    0.020    0.000 base.py:927(__len__)
#      2000    0.013    0.000    0.055    0.000 managers.py:1325(_iset_single)
#      4000    0.013    0.000    0.042    0.000 indexing.py:1334(_convert_to_indexer)
#      1000    0.013    0.000    0.186    0.000 indexing.py:1630(_get_slice_axis)
#      3000    0.013    0.000    0.039    0.000 kafka.py:529(_estimate_size_in_bytes)
#      6000    0.013    0.000    0.026    0.000 common.py:1592(_is_dtype_type)
#      4000    0.013    0.000    0.015    0.000 record_accumulator.py:24(increment)
#      9000    0.013    0.000    0.013    0.000 {built-in method _struct.pack_into}
#      3000    0.012    0.000    0.017    0.000 csvs.py:168(_number_format)
#      3000    0.012    0.000    0.015    0.000 blocks.py:2117(get_block_type)
#      2000    0.012    0.000    0.030    0.000 common.py:1148(_is_binary_mode)
#      5000    0.012    0.000    0.038    0.000 common.py:163(is_object_dtype)
#      2000    0.012    0.000    0.022    0.000 base.py:5342(__getitem__)
#      5000    0.012    0.000    0.012    0.000 managers.py:1868(__init__)
#     17210    0.012    0.000    0.012    0.000 {built-in method __new__ of type object at 0x5597022d9540}
#      2000    0.012    0.000    1.023    0.001 blocks.py:539(to_native_types)
#     10000    0.012    0.000    0.148    0.000 config.py:263(__call__)
#      8002    0.012    0.000    0.012    0.000 {built-in method _abc._abc_instancecheck}
#      2000    0.012    0.000    0.012    0.000 {built-in method numpy.empty}
#      3001    0.012    0.000    0.030    0.000 base.py:54(shape)
#      3000    0.012    0.000    0.020    0.000 blocks.py:2088(maybe_coerce_values)
#      1000    0.011    0.000    0.017    0.000 pathlib.py:56(parse_parts)
#      6000    0.011    0.000    0.106    0.000 managers.py:2397(_using_copy_on_write)
#      1000    0.011    0.000    0.016    0.000 common.py:193(is_sparse)
#      2997    0.011    0.000    0.014    0.000 buffer.py:38(allocate)
#      2000    0.011    0.000    0.018    0.000 indexing.py:771(_ensure_listlike_indexer)
#      3000    0.011    0.000    0.018    0.000 blocks.py:2183(check_ndim)
#      3000    0.011    0.000    0.043    0.000 common.py:96(is_bool_indexer)
#      3000    0.011    0.000    0.115    0.000 default.py:15(__call__)
#      1000    0.011    0.000    0.125    0.000 csvs.py:50(__init__)
#     10000    0.011    0.000    0.025    0.000 config.py:651(_warn_if_deprecated)
#      2000    0.010    0.000    0.221    0.000 managers.py:375(setitem)
#     15022    0.010    0.000    0.017    0.000 {built-in method builtins.issubclass}
#      6008    0.010    0.000    0.010    0.000 future.py:12(__init__)
#      1001    0.010    0.000    0.021    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#      3000    0.010    0.000    0.042    0.000 series.py:1075(_get_value)
#      6000    0.010    0.000    0.026    0.000 {built-in method builtins.all}
#      4000    0.010    0.000    0.015    0.000 blocks.py:2247(extend_blocks)
#      1000    0.009    0.000    0.009    0.000 {built-in method _csv.writer}
#      2997    0.009    0.000    0.048    0.000 threading.py:545(__init__)
#      2997    0.009    0.000    0.013    0.000 record_accumulator.py:580(add)
#      1789    0.009    0.000    2.435    0.001 threading.py:589(wait)
#      6000    0.009    0.000    0.044    0.000 {built-in method builtins.any}
#      1000    0.009    0.000    0.009    0.000 getlimits.py:647(__init__)
#     23860    0.009    0.000    0.009    0.000 {method '__exit__' of '_thread.lock' objects}
#      4000    0.009    0.000    0.010    0.000 record_accumulator.py:29(decrement)
#     11000    0.009    0.000    0.009    0.000 generic.py:551(_get_axis_number)
#      1000    0.009    0.000    0.029    0.000 parse.py:372(urlparse)
#     11853    0.009    0.000    0.009    0.000 __init__.py:1724(isEnabledFor)
#      2000    0.009    0.000    0.026    0.000 typing.py:993(__instancecheck__)
#      3077    0.009    0.000    0.012    0.000 six.py:592(iteritems)
#      1000    0.009    0.000    0.014    0.000 parse.py:437(urlsplit)
#     17000    0.009    0.000    0.009    0.000 {pandas._libs.lib.is_scalar}
#      2000    0.009    0.000    0.014    0.000 base.py:692(_simple_new)
#     10000    0.008    0.000    0.008    0.000 config.py:580(_select_options)
#      9189    0.008    0.000    0.008    0.000 legacy_records.py:289(__init__)
#      4000    0.008    0.000    0.807    0.000 sender.py:331(wakeup)
#      3000    0.008    0.000    0.012    0.000 posixpath.py:228(expanduser)
#      1000    0.008    0.000    0.423    0.000 common.py:113(close)
#      2000    0.008    0.000    0.017    0.000 common.py:1279(is_bool_dtype)
#     11000    0.008    0.000    0.008    0.000 {method 'split' of 'str' objects}
#      1000    0.008    0.000    2.619    0.003 kafka.py:624(flush)
#      3000    0.008    0.000    0.008    0.000 common.py:538(is_string_or_object_np_dtype)
#      5000    0.008    0.000    0.046    0.000 base.py:2583(is_object)
#      2000    0.008    0.000    0.059    0.000 indexing.py:893(_convert_tuple)
#      3000    0.008    0.000    0.020    0.000 base.py:5972(_get_values_for_loc)
#      1000    0.008    0.000    0.203    0.000 common.py:587(check_parent_directory)
#     19434    0.008    0.000    0.008    0.000 {method 'append' of 'list' objects}
#      1000    0.007    0.000    0.061    0.000 {built-in method builtins.print}
#      9000    0.007    0.000    0.010    0.000 common.py:352(apply_if_callable)
#      8002    0.007    0.000    0.019    0.000 abc.py:117(__instancecheck__)
#      9003    0.007    0.000    0.019    0.000 base.py:56(<genexpr>)
#      3000    0.007    0.000    0.007    0.000 {built-in method builtins.sorted}
#      3000    0.007    0.000    0.051    0.000 base.py:5401(_can_hold_identifiers_and_holds_name)
#      3000    0.007    0.000    0.007    0.000 {built-in method binascii.crc32}
#     10000    0.007    0.000    0.014    0.000 config.py:639(_translate_key)
#      2000    0.007    0.000    0.042    0.000 indexing.py:706(_maybe_mask_setitem_value)
#      1000    0.007    0.000    4.706    0.005 csvs.py:263(_save)
#      1001    0.007    0.000    0.628    0.001 group.py:1114(_message_generator_v2)
#      2000    0.007    0.000    0.011    0.000 managers.py:1892(from_blocks)
#      3000    0.007    0.000    0.020    0.000 legacy_records.py:503(estimate_size_in_bytes)
#      2000    0.007    0.000    0.048    0.000 indexing.py:897(<listcomp>)
#      9189    0.007    0.000    0.007    0.000 legacy_records.py:149(timestamp_type)
#      2000    0.007    0.000    0.055    0.000 blocks.py:222(make_block)
#      9189    0.007    0.000    0.007    0.000 {method 'unpack_from' of '_struct.Struct' objects}
#      3000    0.007    0.000    0.017    0.000 csvs.py:140(has_mi_columns)
#      3000    0.007    0.000    0.007    0.000 base.py:6620(_validate_indexer)
#      1000    0.007    0.000    0.021    0.000 frame.py:608(__init__)
#      1000    0.007    0.000    0.096    0.000 csvs.py:144(_initialize_columns)
#      3000    0.006    0.000    0.006    0.000 cluster.py:131(<listcomp>)
#      3000    0.006    0.000    0.007    0.000 managers.py:2038(internal_values)
#      2000    0.006    0.000    0.014    0.000 blocks.py:2263(ensure_block_shape)
#     27567    0.006    0.000    0.006    0.000 legacy_records.py:319(value)
#      2997    0.006    0.000    0.006    0.000 legacy_records.py:346(__init__)
#      1000    0.006    0.000    0.030    0.000 pathlib.py:589(_from_parts)
#      8000    0.006    0.000    0.027    0.000 managers.py:170(blknos)
#      6000    0.006    0.000    0.252    0.000 missing.py:108(isna)
#     27567    0.006    0.000    0.006    0.000 legacy_records.py:313(key)
#      6000    0.006    0.000    0.007    0.000 indexing.py:2657(<genexpr>)
#      2000    0.006    0.000    0.020    0.000 utils.py:295(length_of_indexer)
#      1000    0.006    0.000    0.081    0.000 csvs.py:268(_save_header)
#     16000    0.006    0.000    0.006    0.000 {pandas._libs.lib.is_integer}
#      3000    0.006    0.000    0.018    0.000 common.py:165(_expand_user)
#      1000    0.006    0.000    0.048    0.000 series.py:343(__init__)
#      3000    0.006    0.000    0.135    0.000 memory_records.py:137(append)
#      2000    0.006    0.000    0.006    0.000 blocks.py:842(set_inplace)
#      1000    0.006    0.000    0.009    0.000 pathlib.py:621(__str__)
#      2000    0.006    0.000    0.028    0.000 common.py:225(stringify_path)
#      3000    0.006    0.000    0.006    0.000 kafka.py:521(_max_usable_produce_magic)
#      6000    0.006    0.000    0.009    0.000 indexing.py:812(<genexpr>)
#      2000    0.006    0.000    0.006    0.000 flags.py:49(__init__)
#      1000    0.006    0.000    0.006    0.000 {method 'ParseFromString' of 'google.protobuf.pyext._message.CMessage' objects}
#      2000    0.006    0.000    0.017    0.000 typing.py:1154(__subclasscheck__)
#      6000    0.006    0.000    0.006    0.000 common.py:147(classes)
#      3007    0.006    0.000    0.008    0.000 future.py:48(add_callback)
#      8000    0.006    0.000    0.006    0.000 managers.py:186(blklocs)
#     14345    0.006    0.000    0.006    0.000 {built-in method time.time}
#      1000    0.006    0.000    0.006    0.000 mean_rating_producer.py:9(<lambda>)
#      1789    0.006    0.000    2.441    0.001 future.py:26(wait)
#      1000    0.006    0.000    0.015    0.000 csvs.py:208(write_cols)
#      2000    0.006    0.000    0.006    0.000 flags.py:85(allows_duplicate_labels)
#      1000    0.005    0.000    0.060    0.000 numerictypes.py:597(find_common_type)
#      1000    0.005    0.000    0.005    0.000 {method 'match' of 're.Pattern' objects}
#      2000    0.005    0.000    0.019    0.000 csvs.py:200(_has_aliases)
#     18378    0.005    0.000    0.005    0.000 fetcher.py:506(_deserialize)
#      1000    0.005    0.000    0.013    0.000 base.py:5394(_getitem_slice)
#      5000    0.005    0.000    0.016    0.000 inference.py:189(is_array_like)
#      1000    0.005    0.000    0.005    0.000 {method 'writerow' of '_csv.writer' objects}
#      7000    0.005    0.000    0.008    0.000 common.py:1421(is_1d_only_ea_dtype)
#      1000    0.005    0.000    0.005    0.000 managers.py:1085(<listcomp>)
#      7000    0.005    0.000    0.014    0.000 utils.py:67(is_list_like_indexer)
#      1000    0.005    0.000    0.023    0.000 pathlib.py:569(_parse_args)
#      3000    0.005    0.000    0.005    0.000 legacy_records.py:521(__init__)
#      2000    0.005    0.000    0.010    0.000 iostream.py:429(_is_master_process)
#      3000    0.005    0.000    0.012    0.000 util.py:131(calc_crc32)
#      1000    0.005    0.000    0.014    0.000 csvs.py:121(_get_index_label_from_obj)
#      6000    0.005    0.000    0.005    0.000 legacy_records.py:495(record_overhead)
#      6118    0.005    0.000    0.005    0.000 {built-in method builtins.max}
#      8005    0.005    0.000    0.005    0.000 {built-in method builtins.hasattr}
#      3000    0.005    0.000    0.005    0.000 {method 'pack_into' of '_struct.Struct' objects}
#      1000    0.005    0.000    0.008    0.000 series.py:612(name)
#      3000    0.005    0.000    0.015    0.000 legacy_records.py:479(size_in_bytes)
#      1000    0.005    0.000    0.005    0.000 {pandas._libs.lib.dtypes_all_equal}
#      2000    0.005    0.000    0.005    0.000 parse.py:114(_coerce_args)
#      6000    0.005    0.000    0.008    0.000 common.py:149(<lambda>)
#     18378    0.005    0.000    0.005    0.000 {method 'tobytes' of 'memoryview' objects}
#      4000    0.005    0.000    0.005    0.000 frame.py:856(axes)
#      1000    0.005    0.000    1.063    0.001 managers.py:495(to_native_types)
#      1000    0.005    0.000    0.011    0.000 common.py:1247(is_float_dtype)
#      1000    0.005    0.000    0.012    0.000 base.py:4203(_validate_positional_slice)
#      2000    0.005    0.000    0.005    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      3000    0.005    0.000    0.005    0.000 sender.py:173(add_topic)
#      1000    0.005    0.000    0.017    0.000 generic.py:5964(_protect_consolidate)
#      1000    0.005    0.000    0.024    0.000 missing.py:309(_isna_string_dtype)
#      1000    0.005    0.000    0.156    0.000 pathlib.py:1300(is_dir)
#      2000    0.005    0.000    0.017    0.000 missing.py:695(is_valid_na_for_dtype)
#      1000    0.004    0.000    0.044    0.000 base.py:2813(_isnan)
#      3000    0.004    0.000    0.004    0.000 indexing.py:279(loc)
#      2000    0.004    0.000    0.004    0.000 {built-in method posix.getpid}
#      1000    0.004    0.000    0.194    0.000 indexing.py:1593(_getitem_axis)
#      3007    0.004    0.000    0.005    0.000 future.py:57(add_errback)
#      2000    0.004    0.000    0.004    0.000 {built-in method pandas._libs.missing.checknull}
#      1000    0.004    0.000    0.033    0.000 common.py:137(is_url)
#      3000    0.004    0.000    0.008    0.000 memory_records.py:176(is_full)
#      2000    0.004    0.000    0.009    0.000 generic.py:4115(_set_is_copy)
#      1000    0.004    0.000    0.005    0.000 group.py:1217(_set_consumer_timeout)
#      2000    0.004    0.000    0.005    0.000 frame.py:4261(_clear_item_cache)
#      1000    0.004    0.000    0.427    0.000 common.py:133(__exit__)
#      9189    0.004    0.000    0.004    0.000 legacy_records.py:163(compression_type)
#     13000    0.004    0.000    0.004    0.000 {built-in method builtins.callable}
#      1000    0.004    0.000    0.034    0.000 pathlib.py:957(__new__)
#      1000    0.004    0.000    0.638    0.001 group.py:1195(next_v2)
#      6000    0.004    0.000    0.005    0.000 indexing.py:811(<genexpr>)
#      2000    0.004    0.000    0.007    0.000 utils.py:128(check_setitem_lengths)
#      3000    0.004    0.000    0.004    0.000 indexing.py:140(iloc)
#      3000    0.004    0.000    0.011    0.000 series.py:709(_values)
#      1000    0.004    0.000    0.012    0.000 series.py:662(name)
#      5000    0.004    0.000    0.004    0.000 generic.py:665(ndim)
#      4040    0.004    0.000    0.004    0.000 {built-in method _thread.allocate_lock}
#      1000    0.004    0.000    0.005    0.000 managers.py:1051(from_blocks)
#      1004    0.004    0.000    0.005    0.000 subscription_state.py:362(is_fetchable)
#      1000    0.004    0.000    0.013    0.000 csvs.py:179(data_index)
#      1000    0.004    0.000    0.642    0.001 group.py:1184(__next__)
#      1000    0.004    0.000    0.008    0.000 csvs.py:193(nlevels)
#      6000    0.003    0.000    0.004    0.000 indexing.py:2668(<genexpr>)
#      1000    0.003    0.000    0.011    0.000 generic.py:5982(f)
#      1000    0.003    0.000    0.005    0.000 csvs.py:130(_get_index_label_flat)
#      1001    0.003    0.000    0.004    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#      1000    0.003    0.000    0.126    0.000 base.py:210(interleaved_dtype)
#      2003    0.003    0.000    0.003    0.000 {built-in method from_bytes}
#      1000    0.003    0.000    0.021    0.000 generic.py:5978(_consolidate_inplace)
#      9001    0.003    0.000    0.003    0.000 {method 'endswith' of 'str' objects}
#      1000    0.003    0.000    0.006    0.000 pathlib.py:865(parent)
#      1000    0.003    0.000    0.003    0.000 typing.py:306(inner)
#         1    0.003    0.003    0.395    0.395 fetcher.py:781(_parse_fetched_data)
#      1000    0.003    0.000    0.005    0.000 managers.py:511(is_view)
#      2000    0.003    0.000    0.004    0.000 indexing.py:2181(_ensure_iterable_column_indexer)
#      2000    0.003    0.000    0.005    0.000 common.py:1155(needs_i8_conversion)
#      1000    0.003    0.000    0.372    0.000 indexing.py:1259(_get_label)
#      3000    0.003    0.000    0.004    0.000 legacy_records.py:472(size)
# 2004/2001    0.003    0.000    0.003    0.000 {built-in method _abc._abc_subclasscheck}
#      3000    0.003    0.000    0.003    0.000 {method 'extend' of 'bytearray' objects}
#      1000    0.003    0.000    0.047    0.000 base.py:2838(isna)
# 2004/2001    0.003    0.000    0.006    0.000 abc.py:121(__subclasscheck__)
#      2000    0.003    0.000    0.017    0.000 construction.py:400(extract_array)
#      5090    0.003    0.000    0.003    0.000 {built-in method builtins.hash}
#      2000    0.003    0.000    0.022    0.000 frame.py:3735(_get_column_array)
#      2000    0.003    0.000    0.005    0.000 common.py:1745(<genexpr>)
#      1000    0.003    0.000    0.003    0.000 record_accumulator.py:588(all)
#      1000    0.003    0.000    0.004    0.000 common.py:320(is_datetime64_dtype)
#      1000    0.003    0.000    0.031    0.000 format.py:481(get_adjustment)
#      3000    0.003    0.000    0.006    0.000 generic.py:641(_info_axis)
#      1000    0.003    0.000    0.009    0.000 common.py:269(is_fsspec_url)
#      1000    0.003    0.000    0.003    0.000 {built-in method _codecs.lookup}
#      6000    0.003    0.000    0.003    0.000 kafka.py:709(_serialize)
#      2000    0.003    0.000    0.003    0.000 base.py:872(_reset_identity)
#      1000    0.003    0.000    0.004    0.000 generic.py:571(_get_block_manager_axis)
#      3000    0.003    0.000    0.003    0.000 kafka.py:651(_ensure_valid_record_size)
#      2000    0.003    0.000    0.007    0.000 cast.py:1629(<genexpr>)
#      9000    0.003    0.000    0.003    0.000 {method 'lower' of 'str' objects}
#      2000    0.003    0.000    0.003    0.000 blocks.py:324(should_store)
#      3000    0.003    0.000    0.020    0.000 cast.py:1636(<genexpr>)
#      2000    0.003    0.000    0.005    0.000 cast.py:920(_maybe_infer_dtype_type)
#      9189    0.003    0.000    0.003    0.000 legacy_records.py:329(checksum)
#      9189    0.003    0.000    0.003    0.000 legacy_records.py:297(offset)
#      9189    0.003    0.000    0.003    0.000 legacy_records.py:301(timestamp)
#      2000    0.003    0.000    0.004    0.000 base.py:933(__array__)
#      1000    0.003    0.000    0.003    0.000 <string>:2(__init__)
#      1810    0.003    0.000    0.004    0.000 threading.py:264(__enter__)
#      2000    0.003    0.000    0.008    0.000 frame.py:1497(__len__)
#      2000    0.003    0.000    0.003    0.000 indexing.py:900(_validate_key_length)
#      7002    0.003    0.000    0.003    0.000 typing.py:1737(cast)
#      1000    0.003    0.000    0.041    0.000 csvs.py:312(<listcomp>)
#      1000    0.003    0.000    0.003    0.000 getlimits.py:658(min)
#      1000    0.003    0.000    0.003    0.000 codecs.py:186(__init__)
#      2000    0.003    0.000    0.003    0.000 generic.py:333(attrs)
#      2000    0.003    0.000    0.003    0.000 csvs.py:108(index)
#      1001    0.003    0.000    0.003    0.000 base.py:2283(_can_hold_na)
#      1000    0.003    0.000    0.150    0.000 pathlib.py:1092(stat)
#      3000    0.003    0.000    0.003    0.000 csvs.py:92(na_rep)
#      3000    0.003    0.000    0.003    0.000 cast.py:1620(<genexpr>)
#      3000    0.002    0.000    0.002    0.000 csvs.py:104(header)
#      1000    0.002    0.000    0.004    0.000 managers.py:666(consolidate)
#      1000    0.002    0.000    0.003    0.000 common.py:1103(_maybe_memory_map)
#      1000    0.002    0.000    0.003    0.000 pathlib.py:608(_format_parsed_parts)
#      8000    0.002    0.000    0.002    0.000 base.py:6607(_maybe_cast_indexer)
#      5254    0.002    0.000    0.002    0.000 {method '__exit__' of '_thread.RLock' objects}
#      1105    0.002    0.000    0.002    0.000 {built-in method builtins.min}
#      7002    0.002    0.000    0.002    0.000 {method 'keys' of 'dict' objects}
#      2000    0.002    0.000    0.002    0.000 {built-in method sys.intern}
#      1000    0.002    0.000    0.015    0.000 csvs.py:204(_need_to_save_header)
#      2000    0.002    0.000    0.002    0.000 {built-in method time.time_ns}
#      1810    0.002    0.000    0.003    0.000 threading.py:267(__exit__)
#      1000    0.002    0.000    0.002    0.000 numerictypes.py:649(<listcomp>)
#      1000    0.002    0.000    0.018    0.000 format.py:685(_initialize_justify)
#      9189    0.002    0.000    0.002    0.000 legacy_records.py:325(headers)
#      1000    0.002    0.000    0.011    0.000 pathlib.py:631(__fspath__)
#      3000    0.002    0.000    0.002    0.000 kafka.py:593(<genexpr>)
#      3000    0.002    0.000    0.002    0.000 managers.py:1980(_block)
#      2000    0.002    0.000    0.003    0.000 common.py:303(is_null_slice)
#      1000    0.002    0.000    0.008    0.000 base.py:46(__len__)
#      2000    0.002    0.000    0.002    0.000 managers.py:236(items)
#      2000    0.002    0.000    0.003    0.000 managers.py:231(is_single_block)
#      2000    0.002    0.000    0.002    0.000 contextlib.py:420(__init__)
#      1036    0.002    0.000    0.003    0.000 threading.py:276(_acquire_restore)
#      1000    0.002    0.000    0.004    0.000 format.py:793(truncate)
#      9189    0.002    0.000    0.002    0.000 legacy_records.py:307(timestamp_type)
#      3102    0.002    0.000    0.002    0.000 {built-in method builtins.iter}
#      3068    0.002    0.000    0.002    0.000 {method 'add' of 'set' objects}
#      6002    0.002    0.000    0.002    0.000 {method 'replace' of 'str' objects}
#      2000    0.002    0.000    0.002    0.000 managers.py:988(__init__)
#      1000    0.002    0.000    0.002    0.000 {built-in method fromkeys}
#      3006    0.002    0.000    0.002    0.000 {method 'startswith' of 'str' objects}
#      2000    0.002    0.000    0.003    0.000 common.py:1557(get_dtype)
#      4096    0.002    0.000    0.002    0.000 {method 'append' of 'collections.deque' objects}
#      5000    0.002    0.000    0.002    0.000 {pandas._libs.lib.is_iterator}
#      1000    0.002    0.000    0.002    0.000 csvs.py:163(_initialize_chunksize)
#      2000    0.002    0.000    0.002    0.000 {method 'count' of 'list' objects}
#      2000    0.002    0.000    0.002    0.000 format.py:769(_is_in_terminal)
#      1000    0.002    0.000    0.008    0.000 common.py:1726(validate_all_hashable)
#      1000    0.002    0.000    0.002    0.000 indexing.py:1109(_validate_key)
#      1000    0.002    0.000    0.007    0.000 generic.py:4320(_is_view)
#      3000    0.002    0.000    0.002    0.000 legacy_records.py:535(size)
#      3008    0.002    0.000    0.002    0.000 {method 'pop' of 'dict' objects}
#      4000    0.002    0.000    0.002    0.000 generic.py:354(flags)
#      1000    0.002    0.000    0.015    0.000 common.py:495(get_compression_method)
#      1000    0.002    0.000    0.012    0.000 format.py:429(__init__)
#      1789    0.002    0.000    0.002    0.000 future.py:22(failed)
#      4109    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#      1000    0.002    0.000    0.015    0.000 csvs.py:112(_initialize_index_label)
#      2000    0.002    0.000    0.002    0.000 blocks.py:501(dtype)
#      1000    0.002    0.000    0.003    0.000 inference.py:103(is_file_like)
#      1000    0.002    0.000    0.013    0.000 format.py:667(_initialize_sparsify)
#      1000    0.002    0.000    0.003    0.000 format.py:736(_calc_max_rows_fitted)
#      3000    0.002    0.000    0.002    0.000 managers.py:326(<dictcomp>)
#      2000    0.002    0.000    0.002    0.000 blocks.py:214(mgr_locs)
#      1000    0.001    0.000    0.002    0.000 common.py:151(cast_scalar_indexer)
#      1000    0.001    0.000    0.005    0.000 record_accumulator.py:513(begin_flush)
#      1001    0.001    0.000    0.629    0.001 {built-in method builtins.next}
#      1000    0.001    0.000    0.001    0.000 managers.py:1823(is_consolidated)
#      1036    0.001    0.000    0.003    0.000 threading.py:279(_is_owned)
#      1000    0.001    0.000    0.002    0.000 pathlib.py:600(_from_parsed_parts)
#      1000    0.001    0.000    0.001    0.000 format.py:691(_initialize_columns)
#      1000    0.001    0.000    0.001    0.000 getlimits.py:671(max)
#      1000    0.001    0.000    0.002    0.000 inference.py:326(is_hashable)
#      1000    0.001    0.000    0.001    0.000 blocks.py:1900(is_view)
#      2000    0.001    0.000    0.003    0.000 cast.py:1631(<genexpr>)
#      1000    0.001    0.000    0.001    0.000 base.py:1736(name)
#      1000    0.001    0.000    0.002    0.000 format.py:725(_calc_max_cols_fitted)
#      2000    0.001    0.000    0.024    0.000 iostream.py:448(_schedule_flush)
#      1022    0.001    0.000    0.001    0.000 subscription_state.py:419(is_fetchable)
#      2000    0.001    0.000    0.001    0.000 {method 'write' of '_io.StringIO' objects}
#      1000    0.001    0.000    0.001    0.000 format.py:635(is_truncated_horizontally)
#      2000    0.001    0.000    0.001    0.000 flags.py:53(allows_duplicate_labels)
#      1000    0.001    0.000    0.001    0.000 csvs.py:134(_initialize_quotechar)
#      1000    0.001    0.000    0.001    0.000 {built-in method _codecs.lookup_error}
#      1000    0.001    0.000    0.001    0.000 {pandas._libs.lib.item_from_zerodim}
#      3000    0.001    0.000    0.001    0.000 csvs.py:96(float_format)
#      4003    0.001    0.000    0.001    0.000 {built-in method posix.fspath}
#      4000    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_float}
#      2000    0.001    0.000    0.002    0.000 common.py:323(is_full_slice)
#      1000    0.001    0.000    0.001    0.000 format.py:1027(__init__)
#      1000    0.001    0.000    0.001    0.000 {built-in method pandas._libs.writers.word_len}
#      1214    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      1000    0.001    0.000    0.001    0.000 pathlib.py:239(splitroot)
#      3030    0.001    0.000    0.001    0.000 {method 'popleft' of 'collections.deque' objects}
#      3000    0.001    0.000    0.001    0.000 csvs.py:100(decimal)
#      1000    0.001    0.000    0.001    0.000 common.py:394(is_timedelta64_dtype)
#      1000    0.001    0.000    0.001    0.000 subscription_state.py:389(_set_position)
#      1789    0.001    0.000    0.001    0.000 {method '__enter__' of '_thread.lock' objects}
#      1000    0.001    0.000    0.001    0.000 frame.py:599(_constructor)
#       287    0.001    0.000    0.001    0.000 {method 'recv' of '_socket.socket' objects}
#      1000    0.001    0.000    0.001    0.000 {built-in method _stat.S_ISDIR}
#      1036    0.001    0.000    0.002    0.000 threading.py:273(_release_save)
#      2002    0.001    0.000    0.001    0.000 {method 'clear' of 'dict' objects}
#         2    0.001    0.000    0.001    0.000 {built-in method _socket.getaddrinfo}
#      3000    0.001    0.000    0.001    0.000 legacy_records.py:527(offset)
#      1000    0.001    0.000    0.001    0.000 indexing.py:2639(need_slice)
#        54    0.001    0.000    0.001    0.000 frame.py:6(read)
#      1000    0.001    0.000    0.001    0.000 format.py:701(_initialize_colspace)
#      2000    0.001    0.000    0.001    0.000 contextlib.py:426(__exit__)
#      2000    0.001    0.000    0.001    0.000 indexing.py:1128(_has_valid_setitem_indexer)
#    132/85    0.001    0.000    0.003    0.000 sensor.py:55(record)
#      1003    0.001    0.000    0.001    0.000 base.py:5128(_values)
#      3000    0.001    0.000    0.001    0.000 legacy_records.py:531(crc)
#      2000    0.001    0.000    0.001    0.000 {method 'reverse' of 'list' objects}
#      3000    0.001    0.000    0.001    0.000 legacy_records.py:539(timestamp)
#        19    0.001    0.000    0.005    0.000 conn.py:1079(_recv)
#      1000    0.001    0.000    0.001    0.000 base.py:988(dtype)
#        22    0.001    0.000    0.001    0.000 fetcher.py:146(_clean_done_fetch_futures)
#       278    0.001    0.000    0.001    0.000 sampled_stat.py:38(record)
#      2000    0.001    0.000    0.001    0.000 parse.py:103(_noop)
#      1000    0.001    0.000    0.001    0.000 base.py:2019(nlevels)
#      1000    0.001    0.000    0.001    0.000 format.py:672(_initialize_formatters)
#      1036    0.001    0.000    0.001    0.000 {method 'release' of '_thread.lock' objects}
#        59    0.001    0.000    0.023    0.000 iostream.py:202(schedule)
#      2000    0.001    0.000    0.001    0.000 contextlib.py:423(__enter__)
#      1000    0.000    0.000    0.000    0.000 common.py:130(__enter__)
#      1000    0.000    0.000    0.000    0.000 {method 'is_integer' of 'numpy.float64' objects}
#        25    0.000    0.000    0.111    0.004 client_async.py:625(_poll)
#         1    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#         2    0.000    0.000    0.001    0.000 fetcher.py:352(_append)
#        22    0.000    0.000    0.000    0.000 frame.py:15(write)
#        25    0.000    0.000    0.102    0.004 selectors.py:452(select)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:128(<listcomp>)
#      1000    0.000    0.000    0.000    0.000 format.py:639(is_truncated_vertically)
#      1010    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 frame.py:2(__init__)
#      1000    0.000    0.000    0.000    0.000 numerictypes.py:650(<listcomp>)
#      1000    0.000    0.000    0.000    0.000 format.py:755(_adjust_max_rows)
#        30    0.000    0.000    0.001    0.000 sensor.py:113(add)
#         4    0.000    0.000    0.000    0.000 {method 'connect_ex' of '_socket.socket' objects}
#        22    0.000    0.000    0.615    0.028 group.py:665(_poll_once)
#       278    0.000    0.000    0.000    0.000 sampled_stat.py:52(current)
#        24    0.000    0.000    0.116    0.005 client_async.py:550(poll)
#       132    0.000    0.000    0.000    0.000 sensor.py:78(_check_quotas)
#        40    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
#        22    0.000    0.000    0.001    0.000 fetcher.py:659(_create_fetch_requests)
#        59    0.000    0.000    0.000    0.000 threading.py:1169(is_alive)
#       278    0.000    0.000    0.000    0.000 sampled_stat.py:99(is_complete)
#         3    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#       115    0.000    0.000    0.000    0.000 copy.py:66(copy)
#        60    0.000    0.000    0.000    0.000 metric_name.py:79(__hash__)
#        40    0.000    0.000    0.000    0.000 conn.py:1134(requests_timed_out)
#       193    0.000    0.000    0.001    0.000 rate.py:47(record)
#        59    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#        43    0.000    0.000    0.396    0.009 fetcher.py:310(fetched_records)
#        19    0.000    0.000    0.002    0.000 parser.py:80(receive_bytes)
#        30    0.000    0.000    0.001    0.000 metrics.py:224(register_metric)
#       556    0.000    0.000    0.000    0.000 kafka_metric.py:25(config)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:950(get_code)
#        19    0.000    0.000    0.006    0.000 conn.py:1048(recv)
#         2    0.000    0.000    0.001    0.001 conn.py:1309(__init__)
#        41    0.000    0.000    0.000    0.000 client_async.py:709(in_flight_request_count)
#        21    0.000    0.000    0.000    0.000 base.py:322(time_to_next_heartbeat)
#        59    0.000    0.000    0.000    0.000 threading.py:1102(_wait_for_tstate_lock)
#        22    0.000    0.000    0.002    0.000 fetcher.py:115(send_fetches)
#         8    0.000    0.000    0.000    0.000 __init__.py:430(_replace)
#        18    0.000    0.000    0.000    0.000 metrics.py:119(sensor)
#         2    0.000    0.000    0.000    0.000 selectors.py:352(register)
#        25    0.000    0.000    0.000    0.000 client_async.py:728(_fire_pending_completed_requests)
#         4    0.000    0.000    0.002    0.001 conn.py:359(connect)
#        25    0.000    0.000    0.000    0.000 client_async.py:807(_maybe_refresh_metadata)
#        30    0.000    0.000    0.000    0.000 metrics.py:85(metric_name)
#        22    0.000    0.000    0.000    0.000 fetcher.py:648(_fetchable_partitions)
#        22    0.000    0.000    0.000    0.000 subscription_state.py:305(fetchable_partitions)
#         9    0.000    0.000    0.000    0.000 types.py:90(decode)
#       5/4    0.000    0.000    0.001    0.000 client_async.py:268(_conn_state_change)
#        26    0.000    0.000    0.000    0.000 cluster.py:167(ttl)
#        10    0.000    0.000    0.000    0.000 struct.py:14(__init__)
#         1    0.000    0.000    0.000    0.000 {function socket.close at 0x7f7f49b7e950}
#        30    0.000    0.000    0.000    0.000 metric_name.py:42(__init__)
#        12    0.000    0.000    0.000    0.000 sensor.py:18(__init__)
#         2    0.000    0.000    0.615    0.307 group.py:614(poll)
#        21    0.000    0.000    0.000    0.000 client_async.py:984(update)
#         2    0.000    0.000    0.003    0.002 client_async.py:365(_maybe_connect)
#         2    0.000    0.000    0.001    0.001 conn.py:232(__init__)
#        22    0.000    0.000    0.000    0.000 consumer.py:258(poll)
#        12    0.000    0.000    0.000    0.000 util.py:34(__init__)
#        42    0.000    0.000    0.000    0.000 metrics.py:105(get_sensor)
#        92    0.000    0.000    0.000    0.000 count.py:13(update)
#       101    0.000    0.000    0.000    0.000 rate.py:113(update)
#        48    0.000    0.000    0.000    0.000 sampled_stat.py:45(new_sample)
#        21    0.000    0.000    0.000    0.000 consumer.py:362(need_rejoin)
#        19    0.000    0.000    0.000    0.000 cluster.py:135(leader_for_partition)
#         8    0.000    0.000    0.000    0.000 selectors.py:376(modify)
#        25    0.000    0.000    0.000    0.000 six.py:589(itervalues)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#        23    0.000    0.000    0.000    0.000 subscription_state.py:343(has_all_fetch_positions)
#        60    0.000    0.000    0.000    0.000 metric_name.py:75(tags)
#         1    0.000    0.000    0.000    0.000 {built-in method io.open_code}
#       9/6    0.000    0.000    0.001    0.000 types.py:152(<listcomp>)
#        24    0.000    0.000    0.000    0.000 client_async.py:999(next_check_ms)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#         1    0.000    0.000    0.000    0.000 csvs.py:1(<module>)
#        21    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 socket.py:220(__init__)
#        48    0.000    0.000    0.000    0.000 sampled_stat.py:88(__init__)
#        25    0.000    0.000    0.000    0.000 conn.py:945(_can_send_recv)
#         1    0.000    0.000    0.000    0.000 cluster.py:229(update_metadata)
#         3    0.000    0.000    0.000    0.000 parser.py:47(send_request)
#         2    0.000    0.000    0.000    0.000 fetcher.py:513(_send_offset_requests)
#         1    0.000    0.000    0.104    0.104 fetcher.py:249(_retrieve_offsets)
#         1    0.000    0.000    0.000    0.000 fetcher.py:978(record_topic_fetch_metrics)
#     24/12    0.000    0.000    0.000    0.000 sensor.py:34(_check_forest)
#        68    0.000    0.000    0.000    0.000 avg.py:13(update)
#        31    0.000    0.000    0.000    0.000 types.py:62(decode)
#        18    0.000    0.000    0.000    0.000 __init__.py:1532(log)
#        93    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 client_async.py:742(least_loaded_node)
#         3    0.000    0.000    0.000    0.000 api.py:17(__init__)
#        59    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#       113    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        25    0.000    0.000    0.000    0.000 client_async.py:947(_maybe_close_oldest_connection)
#      10/6    0.000    0.000    0.000    0.000 types.py:146(<listcomp>)
#        22    0.000    0.000    0.000    0.000 consumer.py:190(_auto_assign_all_partitions)
#         2    0.000    0.000    0.000    0.000 fetcher.py:563(_send_offset_request)
#         2    0.000    0.000    0.000    0.000 base.py:883(_engine)
#        25    0.000    0.000    0.000    0.000 client_async.py:615(_register_send_sockets)
#         3    0.000    0.000    0.001    0.000 parser.py:137(_process_response)
#     12/11    0.000    0.000    0.001    0.000 util.py:46(__call__)
#        47    0.000    0.000    0.000    0.000 types.py:18(_unpack)
#        21    0.000    0.000    0.000    0.000 consumer.py:295(time_to_next_poll)
#        26    0.000    0.000    0.000    0.000 selectors.py:276(_key_from_fd)
#      10/6    0.000    0.000    0.000    0.000 types.py:143(encode)
#        25    0.000    0.000    0.000    0.000 client_async.py:1011(poll_expired_connection)
#         3    0.000    0.000    0.000    0.000 conn.py:961(_send)
#         1    0.000    0.000    0.000    0.000 fetcher.py:750(_handle_fetch_response)
#         8    0.000    0.000    0.000    0.000 {method 'modify' of 'select.epoll' objects}
#         5    0.000    0.000    0.000    0.000 random.py:380(shuffle)
#        14    0.000    0.000    0.000    0.000 selectors.py:21(_fileobj_to_fd)
#        24    0.000    0.000    0.000    0.000 client_async.py:725(<listcomp>)
#      10/4    0.000    0.000    0.001    0.000 types.py:189(decode)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1536(find_spec)
#        30    0.000    0.000    0.000    0.000 kafka_metric.py:8(__init__)
#         3    0.000    0.000    0.000    0.000 conn.py:1010(send_pending_requests_v2)
#        47    0.000    0.000    0.000    0.000 {method 'unpack' of '_struct.Struct' objects}
#        30    0.000    0.000    0.000    0.000 sampled_stat.py:25(__init__)
#         4    0.000    0.000    0.001    0.000 client_async.py:515(send)
#         2    0.000    0.000    0.000    0.000 fetcher.py:898(take)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:921(_find_spec)
#         1    0.000    0.000    0.000    0.000 conn.py:906(close)
#         3    0.000    0.000    0.000    0.000 future.py:39(failure)
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        41    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#         6    0.000    0.000    0.000    0.000 random.py:239(_randbelow_with_getrandbits)
#        33    0.000    0.000    0.000    0.000 types.py:9(_pack)
#        13    0.000    0.000    0.000    0.000 conn.py:871(connecting)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:670(_compile_bytecode)
#        22    0.000    0.000    0.000    0.000 {method '__copy__' of 'collections.deque' objects}
#        23    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         7    0.000    0.000    0.000    0.000 max_stat.py:8(__init__)
#       5/3    0.000    0.000    0.000    0.000 types.py:181(encode)
#        15    0.000    0.000    0.000    0.000 rate.py:40(__init__)
#        12    0.000    0.000    0.000    0.000 threading.py:90(RLock)
#         3    0.000    0.000    0.001    0.000 struct.py:46(decode)
#         2    0.000    0.000    0.000    0.000 conn.py:1417(_address_family)
#         2    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#        33    0.000    0.000    0.000    0.000 {method 'pack' of '_struct.Struct' objects}
#         2    0.000    0.000    0.001    0.000 socket.py:938(getaddrinfo)
#         6    0.000    0.000    0.000    0.000 types.py:84(encode)
# ...
#         3    0.000    0.000    0.000    0.000 conn.py:570(_send_bytes)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1070(get_data)
#         3    0.000    0.000    0.000    0.000 cluster.py:83(brokers)
#         8    0.000    0.000    0.000    0.000 avg.py:10(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         2    0.000    0.000    0.000    0.000 idna.py:147(encode)
#         2    0.000    0.000    0.000    0.000 {method 'register' of 'select.epoll' objects}
#        13    0.000    0.000    0.000    0.000 types.py:49(decode)
#         2    0.000    0.000    0.000    0.000 selectors.py:235(register)
#         3    0.000    0.000    0.000    0.000 parser.py:28(__init__)
#         9    0.000    0.000    0.000    0.000 fetcher.py:890(__len__)
#        42    0.000    0.000    0.000    0.000 metrics.py:74(config)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#         1    0.000    0.000    0.000    0.000 csvs.py:47(CSVFormatter)
#         4    0.000    0.000    0.000    0.000 enum.py:359(__call__)
#       6/3    0.000    0.000    0.000    0.000 future.py:31(success)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1022(_find_and_load)
#        14    0.000    0.000    0.000    0.000 selectors.py:216(_fileobj_lookup)
#        34    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#        19    0.000    0.000    0.000    0.000 types.py:58(encode)
#         2    0.000    0.000    0.000    0.000 conn.py:1435(get_ip_port_afi)
#        20    0.000    0.000    0.000    0.000 subscription_state.py:393(_get_position)
#         8    0.000    0.000    0.000    0.000 __init__.py:420(_make)
#        23    0.000    0.000    0.000    0.000 subscription_state.py:313(partitions_auto_assigned)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:664(_load_unlocked)
#         1    0.000    0.000    0.104    0.104 fetcher.py:218(_reset_offset)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:492(_init_module_attrs)
#         1    0.000    0.000    0.000    0.000 consumer.py:159(_handle_metadata_update)
#         7    0.000    0.000    0.000    0.000 count.py:10(__init__)
#         1    0.000    0.000    0.000    0.000 fetcher.py:587(_handle_offset_response)
#         4    0.000    0.000    0.000    0.000 socket.py:99(_intenum_converter)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:126(_path_join)
#        15    0.000    0.000    0.000    0.000 conn.py:867(connected)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:721(spec_from_file_location)
#         3    0.000    0.000    0.000    0.000 client_async.py:260(_can_connect)
#         3    0.000    0.000    0.000    0.000 client_async.py:334(maybe_connect)
#         2    0.000    0.000    0.000    0.000 client_async.py:939(_clear_wake_fd)
#        12    0.000    0.000    0.000    0.000 types.py:45(encode)
#         2    0.000    0.000    0.001    0.000 conn.py:320(_next_afi_sockaddr)
#        25    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 conn.py:886(_update_reconnect_backoff)
#         3    0.000    0.000    0.000    0.000 selectors.py:181(get_key)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         4    0.000    0.000    0.000    0.000 enum.py:678(__new__)
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        30    0.000    0.000    0.000    0.000 metric_name.py:67(group)
#         6    0.000    0.000    0.000    0.000 struct.py:43(<listcomp>)
#         8    0.000    0.000    0.000    0.000 conn.py:1043(can_send_more)
#         1    0.000    0.000    0.000    0.000 fetcher.py:869(__init__)
#        30    0.000    0.000    0.000    0.000 metric_name.py:63(name)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1399(_get_spec)
#         2    0.000    0.000    0.000    0.000 base.py:5154(_get_engine_target)
#         3    0.000    0.000    0.001    0.000 struct.py:50(<listcomp>)
#         3    0.000    0.000    0.000    0.000 parser.py:180(_reset_buffer)
#         1    0.000    0.000    0.000    0.000 socket.py:494(_real_close)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#         1    0.000    0.000    0.000    0.000 conn.py:1302(__str__)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:877(exec_module)
#         1    0.000    0.000    0.000    0.000 subscription_state.py:233(assign_from_subscribed)
#         2    0.000    0.000    0.001    0.000 conn.py:312(_dns_lookup)
#         1    0.000    0.000    0.104    0.104 fetcher.py:159(update_fetch_positions)
#         1    0.000    0.000    0.000    0.000 random.py:546(uniform)
#         6    0.000    0.000    0.000    0.000 __init__.py:1467(info)
#         4    0.000    0.000    0.000    0.000 conn.py:882(_reset_reconnect_backoff)
#       5/3    0.000    0.000    0.000    0.000 types.py:186(<listcomp>)
#         4    0.000    0.000    0.000    0.000 cluster.py:91(broker_metadata)
#         2    0.000    0.000    0.000    0.000 {method 'setsockopt' of '_socket.socket' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method _socket.inet_pton}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#         4    0.000    0.000    0.000    0.000 conn.py:841(blacked_out)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#         1    0.000    0.000    0.104    0.104 group.py:1084(_update_fetch_positions)
#         2    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 selectors.py:366(unregister)
#         5    0.000    0.000    0.000    0.000 subscription_state.py:356(is_assigned)
#         1    0.000    0.000    0.000    0.000 cProfile.py:117(__exit__)
#         1    0.000    0.000    0.000    0.000 subscription_state.py:376(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:219(_acquireLock)
#         3    0.000    0.000    0.000    0.000 client_async.py:754(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1531(_get_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:510(_get_cached)
#         1    0.000    0.000    0.000    0.000 fetcher.py:925(record)
#         8    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:585(_classify_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:564(module_from_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#        16    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#         3    0.000    0.000    0.000    0.000 parser.py:40(_next_correlation_id)
#         1    0.000    0.000    0.000    0.000 consumer.py:200(_build_metadata_snapshot)
#         6    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         3    0.000    0.000    0.000    0.000 selectors.py:70(__getitem__)
#         2    0.000    0.000    0.000    0.000 conn.py:1510(is_inet_4_or_6)
#         1    0.000    0.000    0.000    0.000 {method 'unregister' of 'select.epoll' objects}
#        14    0.000    0.000    0.000    0.000 {method 'fileno' of '_socket.socket' objects}
#         1    0.000    0.000    0.001    0.001 types.py:108(decode)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#         3    0.000    0.000    0.000    0.000 errors.py:514(for_code)
#         1    0.000    0.000    0.000    0.000 conn.py:898(_close_socket)
#         1    0.000    0.000    0.000    0.000 memory_records.py:42(__init__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:897(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#        14    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 parser.py:74(send_bytes)
#         6    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:391(cached)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1431(find_spec)
#         6    0.000    0.000    0.000    0.000 cluster.py:80(is_bootstrap)
#         9    0.000    0.000    0.000    0.000 frame.py:20(seek)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:357(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'setblocking' of '_socket.socket' objects}
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:893(__enter__)
#         1    0.000    0.000    0.000    0.000 fetcher.py:919(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1356(_path_importer_cache)
#         1    0.000    0.000    0.000    0.000 fetcher.py:545(on_success)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:618(_validate_timestamp_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         2    0.000    0.000    0.000    0.000 types.py:75(decode)
#         2    0.000    0.000    0.000    0.000 __init__.py:228(_releaseLock)
#         1    0.000    0.000    0.000    0.000 subscription_state.py:349(missing_fetch_positions)
#         2    0.000    0.000    0.000    0.000 future.py:19(succeeded)
#         1    0.000    0.000    0.000    0.000 __init__.py:1710(getEffectiveLevel)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:542(_check_name_wrapper)
#         1    0.000    0.000    0.000    0.000 subscription_state.py:371(_add_assigned_partition)
#         1    0.000    0.000    0.000    0.000 fetcher.py:134(reset_offsets_if_needed)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:826(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#         1    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         1    0.000    0.000    0.000    0.000 client_async.py:483(is_ready)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1089(path_stats)
#         3    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 client_async.py:994(is_expired)
#         1    0.000    0.000    0.000    0.000 socket.py:498(close)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1040(__init__)
#         1    0.000    0.000    0.000    0.000 client_async.py:395(ready)
#         1    0.000    0.000    0.000    0.000 subscription_state.py:405(seek)
#         6    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 subscription_state.py:281(seek)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#         6    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:404(parent)
#         2    0.000    0.000    0.000    0.000 {method 'split' of 'bytes' objects}
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 numeric.py:382(_engine_type)
#         1    0.000    0.000    0.000    0.000 consumer.py:184(<listcomp>)
#         1    0.000    0.000    0.000    0.000 selectors.py:248(unregister)
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 subscription_state.py:325(need_offset_reset)
#         1    0.000    0.000    0.000    0.000 memory_records.py:53(valid_bytes)
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         6    0.000    0.000    0.000    0.000 api.py:46(expect_response)
#         6    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 fetcher.py:758(<listcomp>)
#         2    0.000    0.000    0.000    0.000 __init__.py:1307(disable)
#         3    0.000    0.000    0.000    0.000 selectors.py:273(get_map)
#         2    0.000    0.000    0.000    0.000 types.py:71(encode)
#         1    0.000    0.000    0.000    0.000 types.py:131(decode)
#         1    0.000    0.000    0.000    0.000 base.py:415(_engine_type)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 __init__.py:89(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:180(_path_isabs)
#         2    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 future.py:25(retriable)
#         1    0.000    0.000    0.000    0.000 conn.py:903(__del__)
#         1    0.000    0.000    0.000    0.000 fetcher.py:669(<lambda>)
#         1    0.000    0.000    0.000    0.000 client_async.py:990(remove)
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 conn.py:878(disconnected)
#         2    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 fetcher.py:584(<lambda>)
#         1    0.000    0.000    0.000    0.000 fetcher.py:553(on_fail)
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 subscription_state.py:398(await_reset)
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         1    0.000    0.000    0.000    0.000 client_async.py:843(refresh_done)
#         2    0.000    0.000    0.000    0.000 subscription_state.py:340(is_offset_reset_needed)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:746(find_spec)
#         1    0.000    0.000    0.000    0.000 group.py:1181(__iter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:412(has_location)
#         1    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 memory_records.py:92(has_next)
#         1    0.000    0.000    0.000    0.000 subscription_state.py:266(group_subscription)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1065(get_filename)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:71(_relax_case)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:874(create_module)

# %%
mean_rating_producer_report.dump_stats('mean_rating_producer.profile')

# %%
with cProfile.Profile() as movie_data_processor_report:
	movie_data_processor.run(1000)
# Out:
# Storing properties title, genres for movie 1
# Storing properties title, genres for movie 2
# Storing properties title, genres for movie 3
# Storing properties title, genres for movie 4
# Storing properties title, genres for movie 5
# Storing properties title, genres for movie 6
# Storing properties title, genres for movie 7
# Storing properties title, genres for movie 8
# Storing properties title, genres for movie 9
# Storing properties title, genres for movie 10
# Storing properties title, genres for movie 11
# Storing properties title, genres for movie 12
# Storing properties title, genres for movie 13
# Storing properties title, genres for movie 14
# Storing properties title, genres for movie 15
# Storing properties title, genres for movie 16
# Storing properties title, genres for movie 17
# Storing properties title, genres for movie 18
# Storing properties title, genres for movie 19
# Storing properties title, genres for movie 20
# Storing properties title, genres for movie 21
# Storing properties title, genres for movie 22
# Storing properties title, genres for movie 23
# Storing properties title, genres for movie 24
# Storing properties title, genres for movie 25
# Storing properties title, genres for movie 26
# Storing properties title, genres for movie 27
# Storing properties title, genres for movie 28
# Storing properties title, genres for movie 29
# Storing properties title, genres for movie 30
# Storing properties title, genres for movie 31
# Storing properties title, genres for movie 32
# Storing properties title, genres for movie 33
# Storing properties title, genres for movie 34
# Storing properties title, genres for movie 35
# Storing properties title, genres for movie 36
# Storing properties title, genres for movie 37
# Storing properties title, genres for movie 38
# Storing properties title, genres for movie 39
# Storing properties title, genres for movie 40
# Storing properties title, genres for movie 41
# Storing properties title, genres for movie 42
# Storing properties title, genres for movie 43
# Storing properties title, genres for movie 44
# Storing properties title, genres for movie 45
# Storing properties title, genres for movie 46
# Storing properties title, genres for movie 47
# Storing properties title, genres for movie 48
# Storing properties title, genres for movie 49
# Storing properties title, genres for movie 50
# Storing properties title, genres for movie 51
# Storing properties title, genres for movie 52
# Storing properties title, genres for movie 53
# Storing properties title, genres for movie 54
# Storing properties title, genres for movie 55
# Storing properties title, genres for movie 56
# Storing properties title, genres for movie 57
# Storing properties title, genres for movie 58
# Storing properties title, genres for movie 59
# Storing properties title, genres for movie 60
# Storing properties title, genres for movie 61
# Storing properties title, genres for movie 62
# Storing properties title, genres for movie 63
# Storing properties title, genres for movie 64
# Storing properties title, genres for movie 65
# Storing properties title, genres for movie 66
# Storing properties title, genres for movie 67
# Storing properties title, genres for movie 68
# Storing properties title, genres for movie 69
# Storing properties title, genres for movie 70
# Storing properties title, genres for movie 71
# Storing properties title, genres for movie 72
# Storing properties title, genres for movie 73
# Storing properties title, genres for movie 74
# Storing properties title, genres for movie 75
# Storing properties title, genres for movie 76
# Storing properties title, genres for movie 77
# Storing properties title, genres for movie 78
# Storing properties title, genres for movie 79
# Storing properties title, genres for movie 80
# Storing properties title, genres for movie 81
# Storing properties title, genres for movie 82
# Storing properties title, genres for movie 83
# Storing properties title, genres for movie 84
# Storing properties title, genres for movie 85
# Storing properties title, genres for movie 86
# Storing properties title, genres for movie 87
# Storing properties title, genres for movie 88
# Storing properties title, genres for movie 89
# Storing properties title, genres for movie 90
# Storing properties title, genres for movie 92
# Storing properties title, genres for movie 93
# Storing properties title, genres for movie 94
# Storing properties title, genres for movie 95
# Storing properties title, genres for movie 96
# Storing properties title, genres for movie 97
# Storing properties title, genres for movie 98
# Storing properties title, genres for movie 99
# Storing properties title, genres for movie 100
# Storing properties title, genres for movie 101
# Storing properties title, genres for movie 102
# Storing properties title, genres for movie 103
# Storing properties title, genres for movie 104
# Storing properties title, genres for movie 105
# Storing properties title, genres for movie 106
# Storing properties title, genres for movie 107
# Storing properties title, genres for movie 108
# Storing properties title, genres for movie 109
# Storing properties title, genres for movie 110
# Storing properties title, genres for movie 111
# Storing properties title, genres for movie 112
# Storing properties title, genres for movie 113
# Storing properties title, genres for movie 114
# Storing properties title, genres for movie 115
# Storing properties title, genres for movie 116
# Storing properties title, genres for movie 117
# Storing properties title, genres for movie 118
# Storing properties title, genres for movie 119
# Storing properties title, genres for movie 120
# Storing properties title, genres for movie 121
# Storing properties title, genres for movie 122
# Storing properties title, genres for movie 123
# Storing properties title, genres for movie 124
# Storing properties title, genres for movie 125
# Storing properties title, genres for movie 126
# Storing properties title, genres for movie 127
# Storing properties title, genres for movie 128
# Storing properties title, genres for movie 129
# Storing properties title, genres for movie 130
# Storing properties title, genres for movie 131
# Storing properties title, genres for movie 132
# Storing properties title, genres for movie 133
# Storing properties title, genres for movie 134
# Storing properties title, genres for movie 135
# Storing properties title, genres for movie 136
# Storing properties title, genres for movie 137
# Storing properties title, genres for movie 138
# Storing properties title, genres for movie 139
# Storing properties title, genres for movie 140
# Storing properties title, genres for movie 141
# Storing properties title, genres for movie 142
# Storing properties title, genres for movie 143
# Storing properties title, genres for movie 144
# Storing properties title, genres for movie 145
# Storing properties title, genres for movie 146
# Storing properties title, genres for movie 147
# Storing properties title, genres for movie 148
# Storing properties title, genres for movie 149
# Storing properties title, genres for movie 150
# Storing properties title, genres for movie 151
# Storing properties title, genres for movie 152
# Storing properties title, genres for movie 153
# Storing properties title, genres for movie 154
# Storing properties title, genres for movie 155
# Storing properties title, genres for movie 156
# Storing properties title, genres for movie 157
# Storing properties title, genres for movie 158
# Storing properties title, genres for movie 159
# Storing properties title, genres for movie 160
# Storing properties title, genres for movie 161
# Storing properties title, genres for movie 162
# Storing properties title, genres for movie 163
# Storing properties title, genres for movie 164
# Storing properties title, genres for movie 165
# Storing properties title, genres for movie 166
# Storing properties title, genres for movie 167
# Storing properties title, genres for movie 168
# Storing properties title, genres for movie 169
# Storing properties title, genres for movie 170
# Storing properties title, genres for movie 171
# Storing properties title, genres for movie 172
# Storing properties title, genres for movie 173
# Storing properties title, genres for movie 174
# Storing properties title, genres for movie 175
# Storing properties title, genres for movie 176
# Storing properties title, genres for movie 177
# Storing properties title, genres for movie 178
# Storing properties title, genres for movie 179
# Storing properties title, genres for movie 180
# Storing properties title, genres for movie 181
# Storing properties title, genres for movie 182
# Storing properties title, genres for movie 183
# Storing properties title, genres for movie 184
# Storing properties title, genres for movie 185
# Storing properties title, genres for movie 186
# Storing properties title, genres for movie 187
# Storing properties title, genres for movie 188
# Storing properties title, genres for movie 189
# Storing properties title, genres for movie 190
# Storing properties title, genres for movie 191
# Storing properties title, genres for movie 192
# Storing properties title, genres for movie 193
# Storing properties title, genres for movie 194
# Storing properties title, genres for movie 195
# Storing properties title, genres for movie 196
# Storing properties title, genres for movie 197
# Storing properties title, genres for movie 198
# Storing properties title, genres for movie 199
# Storing properties title, genres for movie 200
# Storing properties title, genres for movie 201
# Storing properties title, genres for movie 202
# Storing properties title, genres for movie 203
# Storing properties title, genres for movie 204
# Storing properties title, genres for movie 205
# Storing properties title, genres for movie 206
# Storing properties title, genres for movie 207
# Storing properties title, genres for movie 208
# Storing properties title, genres for movie 209
# Storing properties title, genres for movie 210
# Storing properties title, genres for movie 211
# Storing properties title, genres for movie 212
# Storing properties title, genres for movie 213
# Storing properties title, genres for movie 214
# Storing properties title, genres for movie 215
# Storing properties title, genres for movie 216
# Storing properties title, genres for movie 217
# Storing properties title, genres for movie 218
# Storing properties title, genres for movie 219
# Storing properties title, genres for movie 220
# Storing properties title, genres for movie 222
# Storing properties title, genres for movie 223
# Storing properties title, genres for movie 224
# Storing properties title, genres for movie 225
# Storing properties title, genres for movie 226
# Storing properties title, genres for movie 227
# Storing properties title, genres for movie 228
# Storing properties title, genres for movie 229
# Storing properties title, genres for movie 230
# Storing properties title, genres for movie 231
# Storing properties title, genres for movie 232
# Storing properties title, genres for movie 233
# Storing properties title, genres for movie 234
# Storing properties title, genres for movie 235
# Storing properties title, genres for movie 236
# Storing properties title, genres for movie 237
# Storing properties title, genres for movie 238
# Storing properties title, genres for movie 239
# Storing properties title, genres for movie 240
# Storing properties title, genres for movie 241
# Storing properties title, genres for movie 242
# Storing properties title, genres for movie 243
# Storing properties title, genres for movie 244
# Storing properties title, genres for movie 245
# Storing properties title, genres for movie 246
# Storing properties title, genres for movie 247
# Storing properties title, genres for movie 248
# Storing properties title, genres for movie 249
# Storing properties title, genres for movie 250
# Storing properties title, genres for movie 251
# Storing properties title, genres for movie 252
# Storing properties title, genres for movie 253
# Storing properties title, genres for movie 254
# Storing properties title, genres for movie 255
# Storing properties title, genres for movie 256
# Storing properties title, genres for movie 257
# Storing properties title, genres for movie 258
# Storing properties title, genres for movie 259
# Storing properties title, genres for movie 260
# Storing properties title, genres for movie 261
# Storing properties title, genres for movie 262
# Storing properties title, genres for movie 263
# Storing properties title, genres for movie 264
# Storing properties title, genres for movie 265
# Storing properties title, genres for movie 266
# Storing properties title, genres for movie 267
# Storing properties title, genres for movie 268
# Storing properties title, genres for movie 269
# Storing properties title, genres for movie 270
# Storing properties title, genres for movie 271
# Storing properties title, genres for movie 272
# Storing properties title, genres for movie 273
# Storing properties title, genres for movie 274
# Storing properties title, genres for movie 275
# Storing properties title, genres for movie 276
# Storing properties title, genres for movie 277
# Storing properties title, genres for movie 278
# Storing properties title, genres for movie 279
# Storing properties title, genres for movie 280
# Storing properties title, genres for movie 281
# Storing properties title, genres for movie 282
# Storing properties title, genres for movie 283
# Storing properties title, genres for movie 284
# Storing properties title, genres for movie 285
# Storing properties title, genres for movie 286
# Storing properties title, genres for movie 287
# Storing properties title, genres for movie 288
# Storing properties title, genres for movie 289
# Storing properties title, genres for movie 290
# Storing properties title, genres for movie 291
# Storing properties title, genres for movie 292
# Storing properties title, genres for movie 293
# Storing properties title, genres for movie 294
# Storing properties title, genres for movie 295
# Storing properties title, genres for movie 296
# Storing properties title, genres for movie 297
# Storing properties title, genres for movie 298
# Storing properties title, genres for movie 299
# Storing properties title, genres for movie 300
# Storing properties title, genres for movie 301
# Storing properties title, genres for movie 302
# Storing properties title, genres for movie 303
# Storing properties title, genres for movie 304
# Storing properties title, genres for movie 305
# Storing properties title, genres for movie 306
# Storing properties title, genres for movie 307
# Storing properties title, genres for movie 308
# Storing properties title, genres for movie 309
# Storing properties title, genres for movie 310
# Storing properties title, genres for movie 311
# Storing properties title, genres for movie 312
# Storing properties title, genres for movie 313
# Storing properties title, genres for movie 314
# Storing properties title, genres for movie 315
# Storing properties title, genres for movie 316
# Storing properties title, genres for movie 317
# Storing properties title, genres for movie 318
# Storing properties title, genres for movie 319
# Storing properties title, genres for movie 320
# Storing properties title, genres for movie 321
# Storing properties title, genres for movie 322
# Storing properties title, genres for movie 324
# Storing properties title, genres for movie 325
# Storing properties title, genres for movie 326
# Storing properties title, genres for movie 327
# Storing properties title, genres for movie 328
# Storing properties title, genres for movie 329
# Storing properties title, genres for movie 330
# Storing properties title, genres for movie 331
# Storing properties title, genres for movie 332
# Storing properties title, genres for movie 333
# Storing properties title, genres for movie 334
# Storing properties title, genres for movie 335
# Storing properties title, genres for movie 336
# Storing properties title, genres for movie 337
# Storing properties title, genres for movie 338
# Storing properties title, genres for movie 339
# Storing properties title, genres for movie 340
# Storing properties title, genres for movie 341
# Storing properties title, genres for movie 342
# Storing properties title, genres for movie 343
# Storing properties title, genres for movie 344
# Storing properties title, genres for movie 345
# Storing properties title, genres for movie 346
# Storing properties title, genres for movie 347
# Storing properties title, genres for movie 348
# Storing properties title, genres for movie 349
# Storing properties title, genres for movie 350
# Storing properties title, genres for movie 351
# Storing properties title, genres for movie 352
# Storing properties title, genres for movie 353
# Storing properties title, genres for movie 354
# Storing properties title, genres for movie 355
# Storing properties title, genres for movie 356
# Storing properties title, genres for movie 357
# Storing properties title, genres for movie 358
# Storing properties title, genres for movie 359
# Storing properties title, genres for movie 360
# Storing properties title, genres for movie 361
# Storing properties title, genres for movie 362
# Storing properties title, genres for movie 363
# Storing properties title, genres for movie 364
# Storing properties title, genres for movie 365
# Storing properties title, genres for movie 366
# Storing properties title, genres for movie 367
# Storing properties title, genres for movie 368
# Storing properties title, genres for movie 369
# Storing properties title, genres for movie 370
# Storing properties title, genres for movie 371
# Storing properties title, genres for movie 372
# Storing properties title, genres for movie 373
# Storing properties title, genres for movie 374
# Storing properties title, genres for movie 375
# Storing properties title, genres for movie 376
# Storing properties title, genres for movie 377
# Storing properties title, genres for movie 378
# Storing properties title, genres for movie 379
# Storing properties title, genres for movie 380
# Storing properties title, genres for movie 381
# Storing properties title, genres for movie 382
# Storing properties title, genres for movie 383
# Storing properties title, genres for movie 384
# Storing properties title, genres for movie 385
# Storing properties title, genres for movie 386
# Storing properties title, genres for movie 387
# Storing properties title, genres for movie 388
# Storing properties title, genres for movie 389
# Storing properties title, genres for movie 390
# Storing properties title, genres for movie 391
# Storing properties title, genres for movie 392
# Storing properties title, genres for movie 393
# Storing properties title, genres for movie 394
# Storing properties title, genres for movie 395
# Storing properties title, genres for movie 396
# Storing properties title, genres for movie 397
# Storing properties title, genres for movie 398
# Storing properties title, genres for movie 399
# Storing properties title, genres for movie 400
# Storing properties title, genres for movie 401
# Storing properties title, genres for movie 402
# Storing properties title, genres for movie 403
# Storing properties title, genres for movie 404
# Storing properties title, genres for movie 405
# Storing properties title, genres for movie 406
# Storing properties title, genres for movie 407
# Storing properties title, genres for movie 408
# Storing properties title, genres for movie 409
# Storing properties title, genres for movie 410
# Storing properties title, genres for movie 411
# Storing properties title, genres for movie 412
# Storing properties title, genres for movie 413
# Storing properties title, genres for movie 414
# Storing properties title, genres for movie 415
# Storing properties title, genres for movie 416
# Storing properties title, genres for movie 417
# Storing properties title, genres for movie 418
# Storing properties title, genres for movie 419
# Storing properties title, genres for movie 420
# Storing properties title, genres for movie 421
# Storing properties title, genres for movie 422
# Storing properties title, genres for movie 423
# Storing properties title, genres for movie 424
# Storing properties title, genres for movie 425
# Storing properties title, genres for movie 426
# Storing properties title, genres for movie 427
# Storing properties title, genres for movie 428
# Storing properties title, genres for movie 429
# Storing properties title, genres for movie 430
# Storing properties title, genres for movie 431
# Storing properties title, genres for movie 432
# Storing properties title, genres for movie 433
# Storing properties title, genres for movie 434
# Storing properties title, genres for movie 435
# Storing properties title, genres for movie 436
# Storing properties title, genres for movie 437
# Storing properties title, genres for movie 438
# Storing properties title, genres for movie 439
# Storing properties title, genres for movie 440
# Storing properties title, genres for movie 441
# Storing properties title, genres for movie 442
# Storing properties title, genres for movie 443
# Storing properties title, genres for movie 444
# Storing properties title, genres for movie 445
# Storing properties title, genres for movie 446
# Storing properties title, genres for movie 447
# Storing properties title, genres for movie 448
# Storing properties title, genres for movie 449
# Storing properties title, genres for movie 450
# Storing properties title, genres for movie 451
# Storing properties title, genres for movie 452
# Storing properties title, genres for movie 453
# Storing properties title, genres for movie 454
# Storing properties title, genres for movie 455
# Storing properties title, genres for movie 456
# Storing properties title, genres for movie 457
# Storing properties title, genres for movie 458
# Storing properties title, genres for movie 459
# Storing properties title, genres for movie 460
# Storing properties title, genres for movie 461
# Storing properties title, genres for movie 462
# Storing properties title, genres for movie 463
# Storing properties title, genres for movie 464
# Storing properties title, genres for movie 465
# Storing properties title, genres for movie 466
# Storing properties title, genres for movie 467
# Storing properties title, genres for movie 468
# Storing properties title, genres for movie 469
# Storing properties title, genres for movie 470
# Storing properties title, genres for movie 471
# Storing properties title, genres for movie 472
# Storing properties title, genres for movie 473
# Storing properties title, genres for movie 474
# Storing properties title, genres for movie 475
# Storing properties title, genres for movie 476
# Storing properties title, genres for movie 477
# Storing properties title, genres for movie 478
# Storing properties title, genres for movie 479
# Storing properties title, genres for movie 480
# Storing properties title, genres for movie 481
# Storing properties title, genres for movie 482
# Storing properties title, genres for movie 483
# Storing properties title, genres for movie 484
# Storing properties title, genres for movie 485
# Storing properties title, genres for movie 486
# Storing properties title, genres for movie 487
# Storing properties title, genres for movie 488
# Storing properties title, genres for movie 489
# Storing properties title, genres for movie 490
# Storing properties title, genres for movie 491
# Storing properties title, genres for movie 492
# Storing properties title, genres for movie 493
# Storing properties title, genres for movie 494
# Storing properties title, genres for movie 495
# Storing properties title, genres for movie 496
# Storing properties title, genres for movie 497
# Storing properties title, genres for movie 498
# Storing properties title, genres for movie 499
# Storing properties title, genres for movie 500
# Storing properties title, genres for movie 501
# Storing properties title, genres for movie 502
# Storing properties title, genres for movie 503
# Storing properties title, genres for movie 504
# Storing properties title, genres for movie 505
# Storing properties title, genres for movie 506
# Storing properties title, genres for movie 507
# Storing properties title, genres for movie 508
# Storing properties title, genres for movie 509
# Storing properties title, genres for movie 510
# Storing properties title, genres for movie 511
# Storing properties title, genres for movie 512
# Storing properties title, genres for movie 513
# Storing properties title, genres for movie 514
# Storing properties title, genres for movie 515
# Storing properties title, genres for movie 516
# Storing properties title, genres for movie 517
# Storing properties title, genres for movie 518
# Storing properties title, genres for movie 519
# Storing properties title, genres for movie 520
# Storing properties title, genres for movie 521
# Storing properties title, genres for movie 522
# Storing properties title, genres for movie 523
# Storing properties title, genres for movie 524
# Storing properties title, genres for movie 525
# Storing properties title, genres for movie 526
# Storing properties title, genres for movie 527
# Storing properties title, genres for movie 528
# Storing properties title, genres for movie 529
# Storing properties title, genres for movie 530
# Storing properties title, genres for movie 531
# Storing properties title, genres for movie 532
# Storing properties title, genres for movie 533
# Storing properties title, genres for movie 534
# Storing properties title, genres for movie 535
# Storing properties title, genres for movie 536
# Storing properties title, genres for movie 537
# Storing properties title, genres for movie 538
# Storing properties title, genres for movie 539
# Storing properties title, genres for movie 540
# Storing properties title, genres for movie 541
# Storing properties title, genres for movie 542
# Storing properties title, genres for movie 543
# Storing properties title, genres for movie 544
# Storing properties title, genres for movie 545
# Storing properties title, genres for movie 546
# Storing properties title, genres for movie 547
# Storing properties title, genres for movie 548
# Storing properties title, genres for movie 549
# Storing properties title, genres for movie 550
# Storing properties title, genres for movie 551
# Storing properties title, genres for movie 552
# Storing properties title, genres for movie 553
# Storing properties title, genres for movie 554
# Storing properties title, genres for movie 555
# Storing properties title, genres for movie 556
# Storing properties title, genres for movie 558
# Storing properties title, genres for movie 559
# Storing properties title, genres for movie 560
# Storing properties title, genres for movie 561
# Storing properties title, genres for movie 562
# Storing properties title, genres for movie 563
# Storing properties title, genres for movie 564
# Storing properties title, genres for movie 565
# Storing properties title, genres for movie 566
# Storing properties title, genres for movie 567
# Storing properties title, genres for movie 568
# Storing properties title, genres for movie 569
# Storing properties title, genres for movie 570
# Storing properties title, genres for movie 571
# Storing properties title, genres for movie 572
# Storing properties title, genres for movie 573
# Storing properties title, genres for movie 574
# Storing properties title, genres for movie 575
# Storing properties title, genres for movie 576
# Storing properties title, genres for movie 577
# Storing properties title, genres for movie 579
# Storing properties title, genres for movie 580
# Storing properties title, genres for movie 581
# Storing properties title, genres for movie 582
# Storing properties title, genres for movie 583
# Storing properties title, genres for movie 584
# Storing properties title, genres for movie 585
# Storing properties title, genres for movie 586
# Storing properties title, genres for movie 587
# Storing properties title, genres for movie 588
# Storing properties title, genres for movie 589
# Storing properties title, genres for movie 590
# Storing properties title, genres for movie 591
# Storing properties title, genres for movie 592
# Storing properties title, genres for movie 593
# Storing properties title, genres for movie 594
# Storing properties title, genres for movie 595
# Storing properties title, genres for movie 596
# Storing properties title, genres for movie 597
# Storing properties title, genres for movie 598
# Storing properties title, genres for movie 599
# Storing properties title, genres for movie 600
# Storing properties title, genres for movie 601
# Storing properties title, genres for movie 602
# Storing properties title, genres for movie 603
# Storing properties title, genres for movie 604
# Storing properties title, genres for movie 605
# Storing properties title, genres for movie 606
# Storing properties title, genres for movie 607
# Storing properties title, genres for movie 608
# Storing properties title, genres for movie 609
# Storing properties title, genres for movie 610
# Storing properties title, genres for movie 611
# Storing properties title, genres for movie 612
# Storing properties title, genres for movie 613
# Storing properties title, genres for movie 614
# Storing properties title, genres for movie 615
# Storing properties title, genres for movie 616
# Storing properties title, genres for movie 617
# Storing properties title, genres for movie 618
# Storing properties title, genres for movie 619
# Storing properties title, genres for movie 620
# Storing properties title, genres for movie 621
# Storing properties title, genres for movie 623
# Storing properties title, genres for movie 624
# Storing properties title, genres for movie 625
# Storing properties title, genres for movie 626
# Storing properties title, genres for movie 627
# Storing properties title, genres for movie 628
# Storing properties title, genres for movie 629
# Storing properties title, genres for movie 630
# Storing properties title, genres for movie 631
# Storing properties title, genres for movie 632
# Storing properties title, genres for movie 633
# Storing properties title, genres for movie 634
# Storing properties title, genres for movie 635
# Storing properties title, genres for movie 636
# Storing properties title, genres for movie 637
# Storing properties title, genres for movie 638
# Storing properties title, genres for movie 639
# Storing properties title, genres for movie 640
# Storing properties title, genres for movie 641
# Storing properties title, genres for movie 642
# Storing properties title, genres for movie 643
# Storing properties title, genres for movie 644
# Storing properties title, genres for movie 645
# Storing properties title, genres for movie 647
# Storing properties title, genres for movie 648
# Storing properties title, genres for movie 649
# Storing properties title, genres for movie 650
# Storing properties title, genres for movie 651
# Storing properties title, genres for movie 652
# Storing properties title, genres for movie 653
# Storing properties title, genres for movie 654
# Storing properties title, genres for movie 655
# Storing properties title, genres for movie 656
# Storing properties title, genres for movie 657
# Storing properties title, genres for movie 658
# Storing properties title, genres for movie 659
# Storing properties title, genres for movie 660
# Storing properties title, genres for movie 661
# Storing properties title, genres for movie 662
# Storing properties title, genres for movie 663
# Storing properties title, genres for movie 664
# Storing properties title, genres for movie 665
# Storing properties title, genres for movie 666
# Storing properties title, genres for movie 667
# Storing properties title, genres for movie 668
# Storing properties title, genres for movie 670
# Storing properties title, genres for movie 671
# Storing properties title, genres for movie 672
# Storing properties title, genres for movie 673
# Storing properties title, genres for movie 674
# Storing properties title, genres for movie 675
# Storing properties title, genres for movie 676
# Storing properties title, genres for movie 678
# Storing properties title, genres for movie 679
# Storing properties title, genres for movie 680
# Storing properties title, genres for movie 681
# Storing properties title, genres for movie 682
# Storing properties title, genres for movie 683
# Storing properties title, genres for movie 684
# Storing properties title, genres for movie 685
# Storing properties title, genres for movie 687
# Storing properties title, genres for movie 688
# Storing properties title, genres for movie 690
# Storing properties title, genres for movie 691
# Storing properties title, genres for movie 692
# Storing properties title, genres for movie 693
# Storing properties title, genres for movie 694
# Storing properties title, genres for movie 695
# Storing properties title, genres for movie 696
# Storing properties title, genres for movie 697
# Storing properties title, genres for movie 698
# Storing properties title, genres for movie 699
# Storing properties title, genres for movie 700
# Storing properties title, genres for movie 701
# Storing properties title, genres for movie 702
# Storing properties title, genres for movie 703
# Storing properties title, genres for movie 704
# Storing properties title, genres for movie 705
# Storing properties title, genres for movie 706
# Storing properties title, genres for movie 707
# Storing properties title, genres for movie 708
# Storing properties title, genres for movie 709
# Storing properties title, genres for movie 710
# Storing properties title, genres for movie 711
# Storing properties title, genres for movie 712
# Storing properties title, genres for movie 713
# Storing properties title, genres for movie 714
# Storing properties title, genres for movie 715
# Storing properties title, genres for movie 716
# Storing properties title, genres for movie 717
# Storing properties title, genres for movie 718
# Storing properties title, genres for movie 719
# Storing properties title, genres for movie 720
# Storing properties title, genres for movie 721
# Storing properties title, genres for movie 722
# Storing properties title, genres for movie 723
# Storing properties title, genres for movie 724
# Storing properties title, genres for movie 725
# Storing properties title, genres for movie 726
# Storing properties title, genres for movie 727
# Storing properties title, genres for movie 728
# Storing properties title, genres for movie 729
# Storing properties title, genres for movie 730
# Storing properties title, genres for movie 731
# Storing properties title, genres for movie 732
# Storing properties title, genres for movie 733
# Storing properties title, genres for movie 734
# Storing properties title, genres for movie 735
# Storing properties title, genres for movie 736
# Storing properties title, genres for movie 737
# Storing properties title, genres for movie 738
# Storing properties title, genres for movie 739
# Storing properties title, genres for movie 741
# Storing properties title, genres for movie 742
# Storing properties title, genres for movie 743
# Storing properties title, genres for movie 744
# Storing properties title, genres for movie 745
# Storing properties title, genres for movie 746
# Storing properties title, genres for movie 747
# Storing properties title, genres for movie 748
# Storing properties title, genres for movie 749
# Storing properties title, genres for movie 750
# Storing properties title, genres for movie 751
# Storing properties title, genres for movie 752
# Storing properties title, genres for movie 753
# Storing properties title, genres for movie 754
# Storing properties title, genres for movie 755
# Storing properties title, genres for movie 756
# Storing properties title, genres for movie 757
# Storing properties title, genres for movie 758
# Storing properties title, genres for movie 759
# Storing properties title, genres for movie 760
# Storing properties title, genres for movie 761
# Storing properties title, genres for movie 762
# Storing properties title, genres for movie 763
# Storing properties title, genres for movie 764
# Storing properties title, genres for movie 765
# Storing properties title, genres for movie 766
# Storing properties title, genres for movie 767
# Storing properties title, genres for movie 768
# Storing properties title, genres for movie 769
# Storing properties title, genres for movie 770
# Storing properties title, genres for movie 771
# Storing properties title, genres for movie 772
# Storing properties title, genres for movie 773
# Storing properties title, genres for movie 774
# Storing properties title, genres for movie 775
# Storing properties title, genres for movie 776
# Storing properties title, genres for movie 777
# Storing properties title, genres for movie 778
# Storing properties title, genres for movie 779
# Storing properties title, genres for movie 780
# Storing properties title, genres for movie 781
# Storing properties title, genres for movie 782
# Storing properties title, genres for movie 783
# Storing properties title, genres for movie 784
# Storing properties title, genres for movie 785
# Storing properties title, genres for movie 786
# Storing properties title, genres for movie 787
# Storing properties title, genres for movie 788
# Storing properties title, genres for movie 789
# Storing properties title, genres for movie 790
# Storing properties title, genres for movie 791
# Storing properties title, genres for movie 792
# Storing properties title, genres for movie 793
# Storing properties title, genres for movie 794
# Storing properties title, genres for movie 795
# Storing properties title, genres for movie 796
# Storing properties title, genres for movie 797
# Storing properties title, genres for movie 798
# Storing properties title, genres for movie 799
# Storing properties title, genres for movie 800
# Storing properties title, genres for movie 801
# Storing properties title, genres for movie 802
# Storing properties title, genres for movie 803
# Storing properties title, genres for movie 804
# Storing properties title, genres for movie 805
# Storing properties title, genres for movie 806
# Storing properties title, genres for movie 807
# Storing properties title, genres for movie 808
# Storing properties title, genres for movie 809
# Storing properties title, genres for movie 810
# Storing properties title, genres for movie 812
# Storing properties title, genres for movie 813
# Storing properties title, genres for movie 814
# Storing properties title, genres for movie 815
# Storing properties title, genres for movie 816
# Storing properties title, genres for movie 818
# Storing properties title, genres for movie 819
# Storing properties title, genres for movie 820
# Storing properties title, genres for movie 821
# Storing properties title, genres for movie 822
# Storing properties title, genres for movie 823
# Storing properties title, genres for movie 824
# Storing properties title, genres for movie 825
# Storing properties title, genres for movie 826
# Storing properties title, genres for movie 827
# Storing properties title, genres for movie 828
# Storing properties title, genres for movie 829
# Storing properties title, genres for movie 830
# Storing properties title, genres for movie 831
# Storing properties title, genres for movie 832
# Storing properties title, genres for movie 833
# Storing properties title, genres for movie 834
# Storing properties title, genres for movie 835
# Storing properties title, genres for movie 836
# Storing properties title, genres for movie 837
# Storing properties title, genres for movie 838
# Storing properties title, genres for movie 839
# Storing properties title, genres for movie 840
# Storing properties title, genres for movie 841
# Storing properties title, genres for movie 842
# Storing properties title, genres for movie 843
# Storing properties title, genres for movie 844
# Storing properties title, genres for movie 845
# Storing properties title, genres for movie 846
# Storing properties title, genres for movie 847
# Storing properties title, genres for movie 848
# Storing properties title, genres for movie 849
# Storing properties title, genres for movie 850
# Storing properties title, genres for movie 851
# Storing properties title, genres for movie 852
# Storing properties title, genres for movie 853
# Storing properties title, genres for movie 854
# Storing properties title, genres for movie 855
# Storing properties title, genres for movie 856
# Storing properties title, genres for movie 857
# Storing properties title, genres for movie 858
# Storing properties title, genres for movie 859
# Storing properties title, genres for movie 860
# Storing properties title, genres for movie 861
# Storing properties title, genres for movie 862
# Storing properties title, genres for movie 864
# Storing properties title, genres for movie 865
# Storing properties title, genres for movie 866
# Storing properties title, genres for movie 867
# Storing properties title, genres for movie 868
# Storing properties title, genres for movie 869
# Storing properties title, genres for movie 870
# Storing properties title, genres for movie 871
# Storing properties title, genres for movie 872
# Storing properties title, genres for movie 873
# Storing properties title, genres for movie 874
# Storing properties title, genres for movie 875
# Storing properties title, genres for movie 876
# Storing properties title, genres for movie 877
# Storing properties title, genres for movie 878
# Storing properties title, genres for movie 879
# Storing properties title, genres for movie 880
# Storing properties title, genres for movie 881
# Storing properties title, genres for movie 882
# Storing properties title, genres for movie 884
# Storing properties title, genres for movie 885
# Storing properties title, genres for movie 886
# Storing properties title, genres for movie 887
# Storing properties title, genres for movie 888
# Storing properties title, genres for movie 889
# Storing properties title, genres for movie 890
# Storing properties title, genres for movie 891
# Storing properties title, genres for movie 892
# Storing properties title, genres for movie 893
# Storing properties title, genres for movie 894
# Storing properties title, genres for movie 895
# Storing properties title, genres for movie 896
# Storing properties title, genres for movie 897
# Storing properties title, genres for movie 898
# Storing properties title, genres for movie 899
# Storing properties title, genres for movie 900
# Storing properties title, genres for movie 901
# Storing properties title, genres for movie 902
# Storing properties title, genres for movie 903
# Storing properties title, genres for movie 904
# Storing properties title, genres for movie 905
# Storing properties title, genres for movie 906
# Storing properties title, genres for movie 907
# Storing properties title, genres for movie 908
# Storing properties title, genres for movie 909
# Storing properties title, genres for movie 910
# Storing properties title, genres for movie 911
# Storing properties title, genres for movie 912
# Storing properties title, genres for movie 913
# Storing properties title, genres for movie 914
# Storing properties title, genres for movie 915
# Storing properties title, genres for movie 916
# Storing properties title, genres for movie 917
# Storing properties title, genres for movie 918
# Storing properties title, genres for movie 919
# Storing properties title, genres for movie 920
# Storing properties title, genres for movie 921
# Storing properties title, genres for movie 922
# Storing properties title, genres for movie 923
# Storing properties title, genres for movie 924
# Storing properties title, genres for movie 925
# Storing properties title, genres for movie 926
# Storing properties title, genres for movie 927
# Storing properties title, genres for movie 928
# Storing properties title, genres for movie 929
# Storing properties title, genres for movie 930
# Storing properties title, genres for movie 931
# Storing properties title, genres for movie 932
# Storing properties title, genres for movie 933
# Storing properties title, genres for movie 934
# Storing properties title, genres for movie 935
# Storing properties title, genres for movie 936
# Storing properties title, genres for movie 937
# Storing properties title, genres for movie 938
# Storing properties title, genres for movie 939
# Storing properties title, genres for movie 940
# Storing properties title, genres for movie 941
# Storing properties title, genres for movie 942
# Storing properties title, genres for movie 943
# Storing properties title, genres for movie 944
# Storing properties title, genres for movie 945
# Storing properties title, genres for movie 946
# Storing properties title, genres for movie 947
# Storing properties title, genres for movie 948
# Storing properties title, genres for movie 949
# Storing properties title, genres for movie 950
# Storing properties title, genres for movie 951
# Storing properties title, genres for movie 952
# Storing properties title, genres for movie 953
# Storing properties title, genres for movie 954
# Storing properties title, genres for movie 955
# Storing properties title, genres for movie 956
# Storing properties title, genres for movie 957
# Storing properties title, genres for movie 958
# Storing properties title, genres for movie 959
# Storing properties title, genres for movie 960
# Storing properties title, genres for movie 961
# Storing properties title, genres for movie 962
# Storing properties title, genres for movie 963
# Storing properties title, genres for movie 964
# Storing properties title, genres for movie 965
# Storing properties title, genres for movie 966
# Storing properties title, genres for movie 967
# Storing properties title, genres for movie 968
# Storing properties title, genres for movie 969
# Storing properties title, genres for movie 970
# Storing properties title, genres for movie 971
# Storing properties title, genres for movie 972
# Storing properties title, genres for movie 973
# Storing properties title, genres for movie 974
# Storing properties title, genres for movie 975
# Storing properties title, genres for movie 976
# Storing properties title, genres for movie 977
# Storing properties title, genres for movie 979
# Storing properties title, genres for movie 980
# Storing properties title, genres for movie 981
# Storing properties title, genres for movie 982
# Storing properties title, genres for movie 983
# Storing properties title, genres for movie 984
# Storing properties title, genres for movie 985
# Storing properties title, genres for movie 986
# Storing properties title, genres for movie 987
# Storing properties title, genres for movie 988
# Storing properties title, genres for movie 989
# Storing properties title, genres for movie 990
# Storing properties title, genres for movie 991
# Storing properties title, genres for movie 992
# Storing properties title, genres for movie 993
# Storing properties title, genres for movie 994
# Storing properties title, genres for movie 996
# Storing properties title, genres for movie 997
# Storing properties title, genres for movie 998
# Storing properties title, genres for movie 999
# Storing properties title, genres for movie 1000
# Storing properties title, genres for movie 1001
# Storing properties title, genres for movie 1002
# Storing properties title, genres for movie 1003
# Storing properties title, genres for movie 1004
# Storing properties title, genres for movie 1005
# Storing properties title, genres for movie 1006
# Storing properties title, genres for movie 1007
# Storing properties title, genres for movie 1008
# Storing properties title, genres for movie 1009
# Storing properties title, genres for movie 1010
# Storing properties title, genres for movie 1011
# Storing properties title, genres for movie 1012
# Storing properties title, genres for movie 1013
# Storing properties title, genres for movie 1014
# Storing properties title, genres for movie 1015
# Storing properties title, genres for movie 1016
# Storing properties title, genres for movie 1017
# Storing properties title, genres for movie 1018

# %%
movie_data_processor_report.print_stats(sort = SortKey.CALLS)
# Out:
#          1862540 function calls (1837454 primitive calls) in 8.108 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 281891/274891    0.109    0.000    0.216    0.000 {built-in method builtins.isinstance}
# 138920/123950    0.045    0.000    0.059    0.000 {built-in method builtins.len}
#     49959    0.018    0.000    0.018    0.000 {built-in method builtins.getattr}
#     40960    0.030    0.000    0.072    0.000 generic.py:45(_instancecheck)
#     40960    0.029    0.000    0.041    0.000 generic.py:40(_check)
#     27497    0.017    0.000    0.017    0.000 {built-in method _struct.unpack_from}
#     21960    0.023    0.000    0.023    0.000 config.py:612(_get_deprecated_option)
#     20622    0.005    0.000    0.005    0.000 legacy_records.py:313(key)
#     20622    0.005    0.000    0.005    0.000 legacy_records.py:319(value)
#     18830    0.008    0.000    0.013    0.000 {built-in method builtins.issubclass}
#     15560    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#     14940    0.021    0.000    0.021    0.000 {pandas._libs.lib.is_list_like}
#     13885    0.011    0.000    0.011    0.000 {built-in method __new__ of type object at 0x5597022d9540}
#     13748    0.005    0.000    0.005    0.000 {method 'tobytes' of 'memoryview' objects}
#     13748    0.004    0.000    0.004    0.000 fetcher.py:506(_deserialize)
#     13748    0.025    0.000    0.081    0.000 legacy_records.py:235(__iter__)
#     12962    0.012    0.000    0.015    0.000 base.py:927(__len__)
#     11980    0.007    0.000    0.007    0.000 {method 'split' of 'str' objects}
#     11980    0.008    0.000    0.024    0.000 managers.py:170(blknos)
#     10980    0.031    0.000    0.086    0.000 config.py:117(_get_single_key)
#     10980    0.019    0.000    0.134    0.000 config.py:135(_get_option)
#     10980    0.012    0.000    0.146    0.000 config.py:263(__call__)
#     10980    0.010    0.000    0.010    0.000 config.py:580(_select_options)
#     10980    0.023    0.000    0.030    0.000 config.py:598(_get_root)
#     10980    0.008    0.000    0.016    0.000 config.py:639(_translate_key)
#     10980    0.010    0.000    0.025    0.000 config.py:651(_warn_if_deprecated)
#      9980    0.006    0.000    0.006    0.000 managers.py:186(blklocs)
#      9963    0.005    0.000    0.005    0.000 {pandas._libs.lib.is_scalar}
#      9960    0.008    0.000    0.008    0.000 generic.py:551(_get_axis_number)
#      9003    0.005    0.000    0.015    0.000 base.py:56(<genexpr>)
#      9000    0.003    0.000    0.003    0.000 {built-in method builtins.callable}
#      9000    0.002    0.000    0.002    0.000 {method 'lower' of 'str' objects}
#      9000    0.003    0.000    0.003    0.000 {method 'endswith' of 'str' objects}
#      8982    0.011    0.000    0.011    0.000 {built-in method _abc._abc_instancecheck}
#      8982    0.008    0.000    0.020    0.000 abc.py:117(__instancecheck__)
#      8881    0.014    0.000    0.028    0.000 common.py:1592(_is_dtype_type)
#      7982    0.002    0.000    0.002    0.000 typing.py:1737(cast)
#      7980    0.015    0.000    0.021    0.000 generic.py:565(_get_axis)
#      7980    0.003    0.000    0.003    0.000 {pandas._libs.lib.is_integer}
#      7961    0.003    0.000    0.003    0.000 {built-in method builtins.hasattr}
#      7960    0.005    0.000    0.015    0.000 utils.py:67(is_list_like_indexer)
#      7000    0.010    0.000    0.010    0.000 blocks.py:826(iget)
#      7000    0.016    0.000    0.035    0.000 indexing.py:2652(check_deprecated_indexers)
# 6920/5920    0.012    0.000    0.013    0.000 {built-in method numpy.asarray}
#      6875    0.089    0.000    0.289    0.000 fetcher.py:455(_unpack_message_set)
#      6875    0.019    0.000    0.027    0.000 memory_records.py:68(_cache_next)
#      6875    0.019    0.000    0.085    0.000 memory_records.py:96(next_batch)
#      6874    0.016    0.000    0.034    0.000 legacy_records.py:135(__init__)
#      6874    0.005    0.000    0.005    0.000 legacy_records.py:149(timestamp_type)
#      6874    0.004    0.000    0.004    0.000 legacy_records.py:163(compression_type)
#      6874    0.010    0.000    0.016    0.000 legacy_records.py:198(_read_header)
#      6874    0.028    0.000    0.040    0.000 legacy_records.py:218(_read_key_value)
#      6874    0.007    0.000    0.007    0.000 legacy_records.py:289(__init__)
#      6874    0.002    0.000    0.002    0.000 legacy_records.py:297(offset)
#      6874    0.002    0.000    0.002    0.000 legacy_records.py:301(timestamp)
#      6874    0.001    0.000    0.001    0.000 legacy_records.py:307(timestamp_type)
#      6874    0.002    0.000    0.002    0.000 legacy_records.py:325(headers)
#      6874    0.002    0.000    0.002    0.000 legacy_records.py:329(checksum)
#      6874    0.006    0.000    0.006    0.000 {method 'unpack_from' of '_struct.Struct' objects}
#      6860    0.005    0.000    0.008    0.000 common.py:1557(get_dtype)
#      6350    0.002    0.000    0.002    0.000 {built-in method time.time}
#      6030    0.002    0.000    0.002    0.000 {method '__exit__' of '_thread.lock' objects}
#      6002    0.002    0.000    0.002    0.000 {method 'replace' of 'str' objects}
#      6000    0.008    0.000    0.088    0.000 managers.py:2397(_using_copy_on_write)
#      6000    0.004    0.000    0.006    0.000 indexing.py:811(<genexpr>)
#      6000    0.007    0.000    0.011    0.000 indexing.py:812(<genexpr>)
#      6000    0.004    0.000    0.005    0.000 indexing.py:2657(<genexpr>)
#      6000    0.003    0.000    0.004    0.000 indexing.py:2668(<genexpr>)
#      6000    0.004    0.000    0.006    0.000 common.py:1421(is_1d_only_ea_dtype)
#      5960    0.068    0.000    0.068    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#      5960    0.022    0.000    0.116    0.000 base.py:3756(get_loc)
#      5960    0.002    0.000    0.002    0.000 base.py:6607(_maybe_cast_indexer)
#      5941    0.004    0.000    0.004    0.000 common.py:147(classes)
#      5941    0.004    0.000    0.006    0.000 common.py:149(<lambda>)
#      5000    0.020    0.000    0.051    0.000 managers.py:1129(iget_values)
#      5000    0.004    0.000    0.005    0.000 common.py:352(apply_if_callable)
#      4981    0.005    0.000    0.485    0.000 missing.py:108(isna)
#      4981    0.019    0.000    0.480    0.000 missing.py:191(_isna)
#      4000    0.006    0.000    0.014    0.000 {built-in method builtins.any}
#      4000    0.001    0.000    0.001    0.000 {built-in method posix.fspath}
#      4000    0.007    0.000    0.011    0.000 blocks.py:2247(extend_blocks)
#      4000    0.008    0.000    0.008    0.000 managers.py:1868(__init__)
#      4000    0.020    0.000    0.078    0.000 indexing.py:1334(_convert_to_indexer)
#      4000    0.004    0.000    0.004    0.000 frame.py:856(axes)
#      4000    0.003    0.000    0.003    0.000 generic.py:665(ndim)
#      4000    0.003    0.000    0.011    0.000 inference.py:189(is_array_like)
#      4000    0.009    0.000    0.009    0.000 construction.py:462(ensure_wrapped_if_datetimelike)
#      4000    0.002    0.000    0.002    0.000 {pandas._libs.lib.is_iterator}
#      4000    0.783    0.000    0.783    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      3984    0.003    0.000    0.003    0.000 {method 'keys' of 'dict' objects}
#      3960    0.002    0.000    0.002    0.000 generic.py:354(flags)
#      3960    0.130    0.000    0.130    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      3960    0.042    0.000    0.044    0.000 {built-in method numpy.array}
#      3959    0.003    0.000    0.003    0.000 blocks.py:501(dtype)
#      3941    0.010    0.000    0.027    0.000 common.py:1247(is_float_dtype)
#      3940    0.068    0.000    0.068    0.000 {built-in method numpy.empty}
#      3260    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.RLock' objects}
#      3117    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      3058    0.003    0.000    0.003    0.000 __init__.py:1724(isEnabledFor)
#      3021    0.004    0.000    0.006    0.000 __init__.py:1455(debug)
#      3009    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#      3006    0.002    0.000    0.002    0.000 {method 'startswith' of 'str' objects}
#      3002    0.013    0.000    0.013    0.000 {method 'join' of 'str' objects}
#      3001    0.010    0.000    0.025    0.000 base.py:54(shape)
#      3000    0.009    0.000    0.013    0.000 csvs.py:168(_number_format)
#      3000    0.001    0.000    0.001    0.000 csvs.py:100(decimal)
#      3000    0.005    0.000    0.012    0.000 csvs.py:140(has_mi_columns)
#      3000    0.002    0.000    0.002    0.000 csvs.py:104(header)
#      3000    0.001    0.000    0.001    0.000 csvs.py:96(float_format)
#      3000    0.002    0.000    0.002    0.000 csvs.py:92(na_rep)
#      3000    0.001    0.000    0.001    0.000 managers.py:326(<dictcomp>)
#      3000    0.031    0.000    0.870    0.000 managers.py:297(apply)
#      3000    0.006    0.000    0.016    0.000 common.py:165(_expand_user)
#      3000    0.003    0.000    0.003    0.000 indexing.py:140(iloc)
#      3000    0.003    0.000    0.004    0.000 base.py:6620(_validate_indexer)
#      3000    0.006    0.000    0.006    0.000 common.py:538(is_string_or_object_np_dtype)
#      3000    0.036    0.000    0.400    0.000 missing.py:268(_isna_array)
#      3000    0.004    0.000    0.004    0.000 {built-in method _struct.pack_into}
#      3000    0.006    0.000    0.010    0.000 posixpath.py:228(expanduser)
#      2982    0.001    0.000    0.001    0.000 {method 'clear' of 'dict' objects}
#      2980    0.002    0.000    0.002    0.000 managers.py:988(__init__)
#      2980    0.006    0.000    0.007    0.000 frame.py:4261(_clear_item_cache)
#      2980    0.010    0.000    0.016    0.000 base.py:692(_simple_new)
#      2980    0.003    0.000    0.003    0.000 base.py:872(_reset_identity)
#      2980    0.018    0.000    0.034    0.000 cast.py:1932(np_can_hold_element)
#      2963    0.002    0.000    0.002    0.000 base.py:5128(_values)
#      2961    0.005    0.000    0.006    0.000 common.py:1155(needs_i8_conversion)
#      2960    0.006    0.000    0.006    0.000 {built-in method builtins.sorted}
#      2960    0.013    0.000    0.013    0.000 generic.py:5909(__setattr__)
#      2940    0.001    0.000    0.001    0.000 {built-in method _warnings._filters_mutated}
#      2940    0.003    0.000    0.004    0.000 common.py:157(<lambda>)
#      2940    0.001    0.000    0.001    0.000 common.py:152(classes_and_not_datetimelike)
#      2940    0.008    0.000    0.016    0.000 common.py:586(is_dtype_equal)
#      2940    0.002    0.000    0.002    0.000 {pandas._libs.algos.ensure_platform_int}
#      2103    0.002    0.000    0.002    0.000 {built-in method builtins.max}
#      2002    0.007    0.000    0.009    0.000 cluster.py:106(partitions_for_topic)
#      2000    0.001    0.000    0.001    0.000 {method 'write' of '_io.StringIO' objects}
#      2000    0.003    0.000    0.003    0.000 {built-in method _abc._abc_subclasscheck}
#      2000    0.004    0.000    0.004    0.000 {built-in method posix.getpid}
#      2000    0.002    0.000    0.002    0.000 {built-in method sys.intern}
#      2000    0.001    0.000    0.001    0.000 {method 'reverse' of 'list' objects}
#      2000    0.004    0.000    0.012    0.000 csvs.py:200(_has_aliases)
#      2000    0.001    0.000    0.001    0.000 csvs.py:108(index)
#      2000    0.061    0.000    0.061    0.000 blocks.py:842(set_inplace)
#      2000    0.017    0.000    0.050    0.000 blocks.py:940(setitem)
#      2000    0.006    0.000    0.011    0.000 blocks.py:2088(maybe_coerce_values)
#      2000    0.007    0.000    0.009    0.000 blocks.py:2117(get_block_type)
#      2000    0.008    0.000    0.038    0.000 blocks.py:2169(new_block)
#      2000    0.005    0.000    0.010    0.000 blocks.py:2183(check_ndim)
#      2000    0.006    0.000    0.012    0.000 blocks.py:2263(ensure_block_shape)
#      2000    0.049    0.000    0.707    0.000 blocks.py:2279(to_native_types)
#      2000    0.002    0.000    0.003    0.000 managers.py:231(is_single_block)
#      2000    0.009    0.000    0.116    0.000 managers.py:375(setitem)
#      2000    0.018    0.000    0.029    0.000 managers.py:1117(iget)
#      2000    0.003    0.000    0.003    0.000 managers.py:1226(value_getitem)
#      2000    0.084    0.000    0.287    0.000 managers.py:1169(iset)
#      2000    0.019    0.000    0.486    0.000 managers.py:1354(column_setitem)
#      2000    0.006    0.000    0.009    0.000 managers.py:1892(from_blocks)
#      2000    0.001    0.000    0.001    0.000 managers.py:1980(_block)
#      2000    0.002    0.000    0.002    0.000 format.py:769(_is_in_terminal)
#      2000    0.005    0.000    0.024    0.000 common.py:225(stringify_path)
#      2000    0.011    0.000    0.026    0.000 common.py:1148(_is_binary_mode)
#      2000    0.003    0.000    0.003    0.000 indexing.py:279(loc)
#      2000    0.026    0.000    0.162    0.000 indexing.py:673(_get_setitem_indexer)
#      2000    0.007    0.000    0.040    0.000 indexing.py:706(_maybe_mask_setitem_value)
#      2000    0.014    0.000    0.022    0.000 indexing.py:771(_ensure_listlike_indexer)
#      2000    0.028    0.000    1.816    0.001 indexing.py:807(__setitem__)
#      2000    0.006    0.000    0.084    0.000 indexing.py:897(<listcomp>)
#      2000    0.006    0.000    0.093    0.000 indexing.py:893(_convert_tuple)
#      2000    0.002    0.000    0.003    0.000 indexing.py:900(_validate_key_length)
#      2000    0.001    0.000    0.001    0.000 indexing.py:1128(_has_valid_setitem_indexer)
#      2000    0.052    0.000    1.583    0.001 indexing.py:1659(_setitem_with_indexer)
#      2000    0.017    0.000    0.590    0.000 indexing.py:1800(_setitem_with_indexer_split_path)
#      2000    0.021    0.000    0.545    0.000 indexing.py:1958(_setitem_single_column)
#      2000    0.002    0.000    0.003    0.000 indexing.py:2181(_ensure_iterable_column_indexer)
#      2000    0.007    0.000    0.008    0.000 blocks.py:207(_standardize_fill_value)
#      2000    0.005    0.000    0.043    0.000 blocks.py:222(make_block)
#      2000    0.005    0.000    0.005    0.000 blocks.py:324(should_store)
#      2000    0.011    0.000    0.761    0.000 blocks.py:539(to_native_types)
#      2000    0.003    0.000    0.003    0.000 {pandas._libs.internals.get_blkno_placements}
#      2000    0.002    0.000    0.007    0.000 frame.py:1497(__len__)
#      2000    0.003    0.000    0.019    0.000 frame.py:3735(_get_column_array)
#      2000    0.002    0.000    0.003    0.000 base.py:933(__array__)
#      2000    0.030    0.000    0.722    0.000 base.py:1527(_format_native_types)
#      2000    0.003    0.000    0.015    0.000 base.py:2583(is_object)
#      2000    0.004    0.000    0.012    0.000 common.py:163(is_object_dtype)
#      2000    0.009    0.000    0.356    0.000 missing.py:309(_isna_string_dtype)
#      2000    0.002    0.000    0.015    0.000 construction.py:400(extract_array)
#      2000    0.005    0.000    0.022    0.000 common.py:96(is_bool_indexer)
#      2000    0.002    0.000    0.003    0.000 common.py:303(is_null_slice)
#      2000    0.001    0.000    0.002    0.000 common.py:323(is_full_slice)
#      2000    0.004    0.000    0.005    0.000 utils.py:128(check_setitem_lengths)
#      2000    0.005    0.000    0.017    0.000 utils.py:295(length_of_indexer)
# 2000/1000    0.020    0.000    4.823    0.005 _decorators.py:170(wrapper)
#      2000    0.005    0.000    0.005    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      2000    0.004    0.000    0.007    0.000 iostream.py:429(_is_master_process)
#      2000    0.001    0.000    0.013    0.000 iostream.py:448(_schedule_flush)
#      2000    0.014    0.000    0.037    0.000 iostream.py:518(write)
#      2000    0.005    0.000    0.007    0.000 legacy_records.py:486(record_size)
#      2000    0.002    0.000    0.002    0.000 legacy_records.py:495(record_overhead)
#      2000    0.001    0.000    0.001    0.000 kafka.py:709(_serialize)
#      2000    0.001    0.000    0.001    0.000 parse.py:103(_noop)
#      2000    0.004    0.000    0.004    0.000 parse.py:114(_coerce_args)
#      2000    0.006    0.000    0.019    0.000 typing.py:993(__instancecheck__)
#      2000    0.004    0.000    0.012    0.000 typing.py:1154(__subclasscheck__)
#      2000    0.002    0.000    0.005    0.000 abc.py:121(__subclasscheck__)
#      2000    0.003    0.000    0.003    0.000 contextlib.py:420(__init__)
#      2000    0.001    0.000    0.001    0.000 contextlib.py:423(__enter__)
#      2000    0.001    0.000    0.001    0.000 contextlib.py:426(__exit__)
#      1998    0.003    0.000    0.003    0.000 future.py:12(__init__)
#      1980    0.007    0.000    0.008    0.000 managers.py:1051(from_blocks)
#      1980    0.004    0.000    0.004    0.000 flags.py:85(allows_duplicate_labels)
#      1980    0.001    0.000    0.001    0.000 flags.py:53(allows_duplicate_labels)
#      1980    0.008    0.000    0.031    0.000 frame.py:608(__init__)
#      1980    0.001    0.000    0.001    0.000 frame.py:599(_constructor)
#      1980    0.017    0.000    0.021    0.000 generic.py:260(__init__)
#      1980    0.002    0.000    0.002    0.000 generic.py:333(attrs)
#      1980    0.004    0.000    0.005    0.000 generic.py:571(_get_block_manager_axis)
#      1980    0.018    0.000    0.027    0.000 generic.py:5849(__finalize__)
#      1980    0.001    0.000    0.001    0.000 base.py:988(dtype)
#      1980    0.002    0.000    0.002    0.000 base.py:1736(name)
#      1980    0.005    0.000    0.005    0.000 flags.py:49(__init__)
#      1980    0.005    0.000    0.006    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#      1961    0.007    0.000    0.037    0.000 missing.py:641(na_value_for_dtype)
#      1960    0.001    0.000    0.001    0.000 {built-in method _operator.index}
#      1960    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#      1960    0.014    0.000    0.167    0.000 blocks.py:860(take_nd)
#      1960    0.006    0.000    0.043    0.000 blocks.py:201(fill_value)
#      1960    0.007    0.000    0.007    0.000 blocks.py:237(make_block_same_class)
#      1960    0.004    0.000    0.005    0.000 common.py:1488(is_ea_or_datetimelike_dtype)
#      1960    0.006    0.000    0.006    0.000 cast.py:528(maybe_promote)
#      1960    0.009    0.000    0.136    0.000 take.py:57(take_nd)
#      1960    0.020    0.000    0.126    0.000 take.py:120(_take_nd_ndarray)
#      1960    0.004    0.000    0.004    0.000 take.py:326(_get_take_nd_function)
#      1960    0.004    0.000    0.010    0.000 take.py:554(_take_preprocess_indexer_and_fill_value)
#      1960    0.002    0.000    0.004    0.000 numeric.py:1391(<listcomp>)
#      1960    0.011    0.000    0.016    0.000 numeric.py:1341(normalize_axis_tuple)
#  1960/980    0.008    0.000    0.117    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      1960    0.001    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#      1278    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      1113    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#      1101    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#      1094    0.001    0.000    0.001    0.000 {built-in method builtins.hash}
#      1076    0.003    0.000    0.004    0.000 six.py:592(iteritems)
#      1071    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#      1035    0.001    0.000    0.001    0.000 subscription_state.py:419(is_fetchable)
#      1020    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#      1013    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#      1012    0.002    0.000    0.002    0.000 future.py:48(add_callback)
#      1012    0.001    0.000    0.001    0.000 future.py:57(add_errback)
#      1005    0.004    0.000    0.005    0.000 subscription_state.py:362(is_fetchable)
#      1001    0.001    0.000    0.616    0.001 {built-in method builtins.next}
#      1001    0.008    0.000    0.017    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#      1001    0.002    0.000    0.002    0.000 base.py:2283(_can_hold_na)
#      1001    0.006    0.000    0.615    0.001 group.py:1114(_message_generator_v2)
#      1000    0.001    0.000    0.002    0.000 {built-in method builtins.all}
#      1000    0.006    0.000    0.043    0.000 {built-in method builtins.print}
#      1000    0.001    0.000    0.001    0.000 {method 'extend' of 'bytearray' objects}
#      1000    0.310    0.000    0.310    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#      1000    0.465    0.000    0.467    0.000 {built-in method io.open}
#      1000    0.001    0.000    0.001    0.000 {built-in method time.time_ns}
#      1000    0.001    0.000    0.001    0.000 {built-in method _stat.S_ISDIR}
#      1000    0.002    0.000    0.002    0.000 {built-in method _codecs.lookup}
#      1000    0.001    0.000    0.001    0.000 {built-in method _codecs.lookup_error}
#      1000    0.003    0.000    0.003    0.000 {method 'match' of 're.Pattern' objects}
#      1000    0.050    0.000    0.058    0.000 {built-in method posix.stat}
#      1000    0.015    0.000    0.015    0.000 {built-in method posix.urandom}
#      1000    0.001    0.000    0.001    0.000 {built-in method from_bytes}
#      1000    0.001    0.000    0.001    0.000 {method 'count' of 'list' objects}
#      1000    0.026    0.000    3.432    0.003 csvs.py:296(_save_body)
#      1000    0.025    0.000    3.392    0.003 csvs.py:306(_save_chunk)
#      1000    0.003    0.000    0.037    0.000 csvs.py:312(<listcomp>)
#      1000    0.003    0.000    0.005    0.000 csvs.py:193(nlevels)
#      1000    0.004    0.000    0.055    0.000 csvs.py:268(_save_header)
#      1000    0.004    0.000    3.503    0.004 csvs.py:263(_save)
#      1000    0.012    0.000    4.582    0.005 csvs.py:236(save)
#      1000    0.003    0.000    0.004    0.000 csvs.py:130(_get_index_label_flat)
#      1000    0.015    0.000    0.040    0.000 csvs.py:223(encoded_labels)
#      1000    0.004    0.000    0.011    0.000 csvs.py:208(write_cols)
#      1000    0.002    0.000    0.011    0.000 csvs.py:204(_need_to_save_header)
#      1000    0.002    0.000    0.009    0.000 csvs.py:179(data_index)
#      1000    0.001    0.000    0.002    0.000 csvs.py:163(_initialize_chunksize)
#      1000    0.006    0.000    0.082    0.000 csvs.py:144(_initialize_columns)
#      1000    0.003    0.000    0.010    0.000 csvs.py:121(_get_index_label_from_obj)
#      1000    0.001    0.000    0.011    0.000 csvs.py:112(_initialize_index_label)
#      1000    0.001    0.000    0.001    0.000 csvs.py:134(_initialize_quotechar)
#      1000    0.009    0.000    0.106    0.000 csvs.py:50(__init__)
#      1000    0.006    0.000    0.006    0.000 movie_data_sink.py:27(<lambda>)
#      1000    0.010    0.000    6.728    0.007 movie_data_sink.py:32(on_message)
#      1000    0.001    0.000    0.001    0.000 {built-in method pandas._libs.writers.word_len}
#      1000    1.701    0.002    1.701    0.002 {pandas._libs.writers.write_csv_rows}
#      1000    0.001    0.000    0.001    0.000 managers.py:236(items)
#      1000    0.004    0.000    0.792    0.001 managers.py:495(to_native_types)
#      1000    0.002    0.000    0.011    0.000 format.py:429(__init__)
#      1000    0.003    0.000    0.025    0.000 format.py:481(get_adjustment)
#      1000    0.015    0.000    0.078    0.000 format.py:566(__init__)
#      1000    0.001    0.000    0.001    0.000 format.py:635(is_truncated_horizontally)
#      1000    0.000    0.000    0.000    0.000 format.py:639(is_truncated_vertically)
#      1000    0.001    0.000    0.011    0.000 format.py:667(_initialize_sparsify)
#      1000    0.001    0.000    0.001    0.000 format.py:672(_initialize_formatters)
#      1000    0.002    0.000    0.015    0.000 format.py:685(_initialize_justify)
#      1000    0.002    0.000    0.002    0.000 format.py:691(_initialize_columns)
#      1000    0.001    0.000    0.001    0.000 format.py:701(_initialize_colspace)
#      1000    0.001    0.000    0.003    0.000 format.py:725(_calc_max_cols_fitted)
#      1000    0.002    0.000    0.002    0.000 format.py:736(_calc_max_rows_fitted)
#      1000    0.000    0.000    0.000    0.000 format.py:755(_adjust_max_rows)
#      1000    0.002    0.000    0.003    0.000 format.py:793(truncate)
#      1000    0.001    0.000    0.001    0.000 format.py:1027(__init__)
#      1000    0.015    0.000    4.703    0.005 format.py:1139(to_csv)
#      1000    0.007    0.000    0.317    0.000 common.py:113(close)
#      1000    0.000    0.000    0.000    0.000 common.py:130(__enter__)
#      1000    0.002    0.000    0.319    0.000 common.py:133(__exit__)
#      1000    0.004    0.000    0.029    0.000 common.py:137(is_url)
#      1000    0.002    0.000    0.006    0.000 common.py:269(is_fsspec_url)
#      1000    0.013    0.000    0.109    0.000 common.py:281(_get_filepath_or_buffer)
#      1000    0.001    0.000    0.012    0.000 common.py:495(get_compression_method)
#      1000    0.011    0.000    0.024    0.000 common.py:530(infer_compression)
#      1000    0.007    0.000    0.105    0.000 common.py:587(check_parent_directory)
#      1000    0.023    0.000    0.740    0.001 common.py:646(get_handle)
#      1000    0.002    0.000    0.002    0.000 common.py:1103(_maybe_memory_map)
#      1000    0.002    0.000    0.002    0.000 <string>:2(__init__)
#      1000    0.005    0.000    0.130    0.000 indexing.py:1060(__getitem__)
#      1000    0.002    0.000    0.121    0.000 indexing.py:1593(_getitem_axis)
#      1000    0.007    0.000    0.116    0.000 indexing.py:1630(_get_slice_axis)
#      1000    0.001    0.000    0.001    0.000 indexing.py:2639(need_slice)
#      1000    0.013    0.000    0.675    0.001 numeric.py:283(_format_native_types)
#      1000    0.042    0.000    0.051    0.000 {method 'get_slice' of 'pandas._libs.internals.BlockManager' objects}
#      1000    0.017    0.000    4.816    0.005 generic.py:3537(to_csv)
#      1000    0.011    0.000    0.097    0.000 generic.py:4098(_slice)
#      1000    0.002    0.000    0.004    0.000 generic.py:4115(_set_is_copy)
#      1000    0.000    0.000    0.000    0.000 base.py:2019(nlevels)
#      1000    0.003    0.000    0.026    0.000 base.py:2813(_isnan)
#      1000    0.002    0.000    0.028    0.000 base.py:2838(isna)
#      1000    0.003    0.000    0.007    0.000 base.py:4203(_validate_positional_slice)
#      1000    0.006    0.000    0.012    0.000 base.py:5342(__getitem__)
#      1000    0.003    0.000    0.008    0.000 base.py:5394(_getitem_slice)
#      1000    0.006    0.000    0.010    0.000 common.py:193(is_sparse)
#      1000    0.001    0.000    0.002    0.000 inference.py:103(is_file_like)
#      1000    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#      1000    0.016    0.000    0.016    0.000 {built-in method pandas._libs.missing.isnaobj}
#      1000    0.331    0.000    0.331    0.000 {pandas._libs.missing.isnaobj2d}
#      1000    0.009    0.000    0.009    0.000 {method 'ParseFromString' of 'google.protobuf.pyext._message.CMessage' objects}
#      1000    0.018    0.000    0.018    0.000 {method 'SerializeToString' of 'google.protobuf.pyext._message.CMessage' objects}
#      1000    0.002    0.000    0.002    0.000 cluster.py:131(<listcomp>)
#      1000    0.005    0.000    0.011    0.000 cluster.py:119(available_partitions_for_topic)
#      1000    0.003    0.000    0.626    0.001 group.py:1184(__next__)
#      1000    0.003    0.000    0.623    0.001 group.py:1195(next_v2)
#      1000    0.003    0.000    0.004    0.000 group.py:1217(_set_consumer_timeout)
#      1000    0.005    0.000    0.005    0.000 {method 'writerow' of '_csv.writer' objects}
#      1000    0.008    0.000    0.008    0.000 {built-in method _csv.writer}
#      1000    0.042    0.000    0.730    0.001 message_service.py:84(__report_consumption)
#      1000    0.016    0.000    0.016    0.000 {method 'fill' of 'numpy.ndarray' objects}
#      1000    0.021    0.000    6.708    0.007 movie_data_sink.py:14(save)
#      1000    0.002    0.000    0.044    0.000 memory_records.py:137(append)
#      1000    0.001    0.000    0.002    0.000 memory_records.py:176(is_full)
#      1000    0.011    0.000    0.042    0.000 legacy_records.py:352(append)
#      1000    0.011    0.000    0.022    0.000 legacy_records.py:391(_encode_msg)
#      1000    0.001    0.000    0.001    0.000 legacy_records.py:472(size)
#      1000    0.002    0.000    0.005    0.000 legacy_records.py:479(size_in_bytes)
#      1000    0.002    0.000    0.006    0.000 legacy_records.py:503(estimate_size_in_bytes)
#      1000    0.002    0.000    0.002    0.000 legacy_records.py:521(__init__)
#      1000    0.000    0.000    0.000    0.000 legacy_records.py:527(offset)
#      1000    0.000    0.000    0.000    0.000 legacy_records.py:531(crc)
#      1000    0.000    0.000    0.000    0.000 legacy_records.py:535(size)
#      1000    0.000    0.000    0.000    0.000 legacy_records.py:539(timestamp)
#      1000    0.002    0.000    0.004    0.000 util.py:131(calc_crc32)
#      1000    0.001    0.000    0.001    0.000 subscription_state.py:389(_set_position)
#      1000    0.002    0.000    0.002    0.000 kafka.py:521(_max_usable_produce_magic)
#      1000    0.004    0.000    0.012    0.000 kafka.py:529(_estimate_size_in_bytes)
#      1000    0.001    0.000    0.001    0.000 kafka.py:593(<genexpr>)
#      1000    0.029    0.000    0.601    0.001 kafka.py:538(send)
#      1000    0.001    0.000    0.001    0.000 kafka.py:651(_ensure_valid_record_size)
#      1000    0.008    0.000    0.019    0.000 kafka.py:664(_wait_on_metadata)
#      1000    0.007    0.000    0.063    0.000 kafka.py:716(_partition)
#      1000    0.003    0.000    0.040    0.000 default.py:15(__call__)
#      1000    0.037    0.000    0.037    0.000 default.py:36(murmur2)
#      1000    0.004    0.000    0.004    0.000 record_accumulator.py:24(increment)
#      1000    0.005    0.000    0.010    0.000 future.py:32(__init__)
#      1000    0.002    0.000    0.002    0.000 record_accumulator.py:29(decrement)
#      1000    0.009    0.000    0.065    0.000 record_accumulator.py:57(try_append)
#      1000    0.020    0.000    0.138    0.000 record_accumulator.py:200(append)
#      1000    0.003    0.000    0.003    0.000 sender.py:173(add_topic)
#      1000    0.010    0.000    0.014    0.000 pathlib.py:56(parse_parts)
#      1000    0.001    0.000    0.001    0.000 pathlib.py:239(splitroot)
#      1000    0.005    0.000    0.020    0.000 pathlib.py:569(_parse_args)
#      1000    0.005    0.000    0.026    0.000 pathlib.py:589(_from_parts)
#      1000    0.001    0.000    0.001    0.000 pathlib.py:600(_from_parsed_parts)
#      1000    0.001    0.000    0.002    0.000 pathlib.py:608(_format_parsed_parts)
#      1000    0.005    0.000    0.007    0.000 pathlib.py:621(__str__)
#      1000    0.002    0.000    0.009    0.000 pathlib.py:631(__fspath__)
#      1000    0.003    0.000    0.004    0.000 pathlib.py:865(parent)
#      1000    0.004    0.000    0.029    0.000 pathlib.py:957(__new__)
#      1000    0.002    0.000    0.060    0.000 pathlib.py:1092(stat)
#      1000    0.004    0.000    0.065    0.000 pathlib.py:1300(is_dir)
#      1000    0.018    0.000    0.020    0.000 uuid.py:138(__init__)
#      1000    0.008    0.000    0.008    0.000 uuid.py:279(__str__)
#      1000    0.008    0.000    0.044    0.000 uuid.py:713(uuid4)
#      1000    0.007    0.000    0.025    0.000 parse.py:372(urlparse)
#      1000    0.008    0.000    0.012    0.000 parse.py:437(urlsplit)
#      1000    0.003    0.000    0.003    0.000 {built-in method binascii.crc32}
#      1000    0.002    0.000    0.002    0.000 {method 'pack_into' of '_struct.Struct' objects}
#      1000    0.003    0.000    0.003    0.000 typing.py:306(inner)
#      1000    0.016    0.000    0.016    0.000 {built-in method _socket.gethostname}
#      1000    0.002    0.000    0.002    0.000 codecs.py:186(__init__)
#       983    0.005    0.000    0.327    0.000 client_async.py:929(wakeup)
#       983    0.321    0.000    0.321    0.000 {method 'sendall' of '_socket.socket' objects}
#       982    0.001    0.000    0.001    0.000 {built-in method _thread.allocate_lock}
#       982    0.012    0.000    0.024    0.000 base.py:883(_engine)
#       982    0.003    0.000    0.010    0.000 base.py:5154(_get_engine_target)
#       981    0.001    0.000    0.001    0.000 numeric.py:382(_engine_type)
#       981    0.002    0.000    0.009    0.000 missing.py:695(is_valid_na_for_dtype)
#       981    0.002    0.000    0.002    0.000 {built-in method pandas._libs.missing.checknull}
#       980    0.003    0.000    0.003    0.000 {method 'remove' of 'list' objects}
#       980    0.013    0.000    0.224    0.000 managers.py:743(<listcomp>)
#       980    0.011    0.000    0.307    0.000 managers.py:682(reindex_indexer)
#       980    0.002    0.000    0.002    0.000 indexing.py:2570(convert_missing_indexer)
#       980    0.001    0.000    0.001    0.000 indexing.py:2608(is_nested_tuple)
#       980    0.007    0.000    0.015    0.000 numeric.py:133(_ensure_array)
#       980    0.001    0.000    0.001    0.000 numeric.py:182(_validate_dtype)
#       980    0.001    0.000    0.001    0.000 numeric.py:193(_ensure_dtype)
#       980    0.004    0.000    0.033    0.000 generic.py:3749(_maybe_update_cacher)
#       980    0.005    0.000    0.027    0.000 generic.py:4138(_check_setitem_copy)
#       980    0.018    0.000    0.363    0.000 generic.py:5337(_reindex_with_indexers)
#       980    0.001    0.000    0.001    0.000 base.py:243(disallow_kwargs)
#       980    0.024    0.000    0.091    0.000 base.py:432(__new__)
#       980    0.009    0.000    0.028    0.000 base.py:590(_dtype_to_subclass)
#       980    0.015    0.000    0.150    0.000 base.py:710(_with_infer)
#       980    0.005    0.000    0.039    0.000 base.py:5242(_validate_fill_value)
#       980    0.020    0.000    0.341    0.000 base.py:6882(insert)
#       980    0.001    0.000    0.002    0.000 base.py:7315(ensure_index)
#       980    0.002    0.000    0.004    0.000 base.py:7410(maybe_extract_name)
#       980    0.002    0.000    0.005    0.000 common.py:685(is_integer_dtype)
#       980    0.002    0.000    0.006    0.000 common.py:737(is_signed_integer_dtype)
#       980    0.002    0.000    0.005    0.000 common.py:791(is_unsigned_integer_dtype)
#       980    0.004    0.000    0.010    0.000 common.py:1279(is_bool_dtype)
#       980    0.002    0.000    0.002    0.000 inference.py:326(is_hashable)
#       980    0.002    0.000    0.004    0.000 cast.py:920(_maybe_infer_dtype_type)
#       980    0.001    0.000    0.001    0.000 {pandas._libs.lib.item_from_zerodim}
#       980    0.024    0.000    0.024    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#       980    0.006    0.000    0.006    0.000 {pandas._libs.algos.take_2d_axis0_float64_float64}
#       980    0.001    0.000    0.001    0.000 function_base.py:5139(_insert_dispatcher)
#       980    0.066    0.000    0.111    0.000 function_base.py:5143(insert)
#       980    0.003    0.000    0.121    0.000 <__array_function__ internals>:177(insert)
#       980    0.000    0.000    0.000    0.000 numeric.py:1400(_moveaxis_dispatcher)
#       980    0.001    0.000    0.001    0.000 numeric.py:1466(<listcomp>)
#       980    0.010    0.000    0.032    0.000 numeric.py:1404(moveaxis)
#       980    0.002    0.000    0.035    0.000 <__array_function__ internals>:177(moveaxis)
#       980    0.007    0.000    0.007    0.000 getlimits.py:647(__init__)
#       980    0.002    0.000    0.002    0.000 getlimits.py:658(min)
#       980    0.002    0.000    0.002    0.000 getlimits.py:671(max)
#       980    0.001    0.000    0.001    0.000 {method 'item' of 'numpy.ndarray' objects}
#       980    0.002    0.000    0.002    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       980    0.055    0.000    0.055    0.000 {built-in method numpy.arange}
#       980    0.002    0.000    0.012    0.000 re.py:249(compile)
#       980    0.007    0.000    0.010    0.000 re.py:288(_compile)
#       980    0.001    0.000    0.001    0.000 enum.py:801(value)
#       980    0.003    0.000    0.003    0.000 types.py:176(__get__)
#       980    0.010    0.000    0.031    0.000 warnings.py:130(filterwarnings)
#       980    0.004    0.000    0.008    0.000 warnings.py:181(_add_filter)
#       980    0.004    0.000    0.004    0.000 warnings.py:437(__init__)
#       980    0.005    0.000    0.005    0.000 warnings.py:458(__enter__)
#       980    0.003    0.000    0.003    0.000 warnings.py:477(__exit__)
#       979    0.002    0.000    0.329    0.000 sender.py:331(wakeup)
#       978    0.004    0.000    0.006    0.000 memory_records.py:118(__init__)
#       978    0.002    0.000    0.002    0.000 legacy_records.py:346(__init__)
#       978    0.005    0.000    0.023    0.000 future.py:11(__init__)
#       978    0.005    0.000    0.028    0.000 record_accumulator.py:39(__init__)
#       978    0.002    0.000    0.003    0.000 record_accumulator.py:580(add)
#       978    0.003    0.000    0.004    0.000 buffer.py:38(allocate)
#       978    0.011    0.000    0.011    0.000 threading.py:236(__init__)
#       978    0.004    0.000    0.016    0.000 threading.py:545(__init__)
#       592    0.000    0.000    0.000    0.000 kafka_metric.py:25(config)
#       367    0.001    0.000    0.001    0.000 {method 'recv' of '_socket.socket' objects}
#       296    0.001    0.000    0.002    0.000 sampled_stat.py:38(record)
#       296    0.000    0.000    0.000    0.000 sampled_stat.py:52(current)
#       296    0.000    0.000    0.000    0.000 sampled_stat.py:99(is_complete)
#       199    0.000    0.000    0.001    0.000 rate.py:47(record)
#    138/88    0.001    0.000    0.003    0.000 sensor.py:55(record)
#       138    0.000    0.000    0.000    0.000 sensor.py:78(_check_quotas)
#       138    0.000    0.000    0.000    0.000 copy.py:66(copy)
#       120    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#       119    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       104    0.000    0.000    0.000    0.000 rate.py:113(update)
#        95    0.000    0.000    0.000    0.000 count.py:13(update)
#        85    0.001    0.000    0.001    0.000 frame.py:6(read)
#        76    0.000    0.000    0.000    0.000 kafka_metric.py:17(metric_name)
#        76    0.000    0.000    0.000    0.000 metric_name.py:75(tags)
#        76    0.000    0.000    0.001    0.000 metric_name.py:79(__hash__)
#        76    0.000    0.000    0.000    0.000 metrics.py:78(metrics)
#        76    0.000    0.000    0.000    0.000 types.py:18(_unpack)
#        76    0.000    0.000    0.000    0.000 {method 'unpack' of '_struct.Struct' objects}
#        74    0.000    0.000    0.000    0.000 avg.py:13(update)
#        60    0.000    0.000    0.000    0.000 types.py:9(_pack)
#        60    0.000    0.000    0.000    0.000 {method 'pack' of '_struct.Struct' objects}
#        56    0.000    0.000    0.000    0.000 conn.py:1134(requests_timed_out)
#        56    0.000    0.000    0.000    0.000 metrics.py:105(get_sensor)
#        56    0.000    0.000    0.000    0.000 sampled_stat.py:45(new_sample)
#        56    0.000    0.000    0.000    0.000 sampled_stat.py:88(__init__)
#        55    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
#        53    0.000    0.000    0.000    0.000 metrics.py:74(config)
#        53    0.000    0.000    0.000    0.000 types.py:62(decode)
#        52    0.000    0.000    0.000    0.000 client_async.py:709(in_flight_request_count)
#        46    0.000    0.000    0.000    0.000 conn.py:1137(<lambda>)
#        46    0.000    0.000    0.000    0.000 frame.py:23(tell)
#        43    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        38    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        38    0.000    0.000    0.000    0.000 kafka_metric.py:8(__init__)
#        38    0.000    0.000    0.000    0.000 metric_name.py:63(name)
#        38    0.000    0.000    0.000    0.000 metric_name.py:42(__init__)
#        38    0.000    0.000    0.000    0.000 metric_name.py:67(group)
#        38    0.000    0.000    0.000    0.000 metrics.py:85(metric_name)
#        38    0.000    0.000    0.001    0.000 metrics.py:224(register_metric)
#        38    0.000    0.000    0.000    0.000 sampled_stat.py:25(__init__)
#        38    0.000    0.000    0.001    0.000 sensor.py:113(add)
#        37    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#        37    0.000    0.000    0.294    0.008 fetcher.py:310(fetched_records)
#        36    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        36    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#        36    0.000    0.000    0.011    0.000 iostream.py:202(schedule)
#        36    0.011    0.000    0.011    0.000 socket.py:545(send)
#        36    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#        36    0.000    0.000    0.000    0.000 threading.py:1102(_wait_for_tstate_lock)
#        36    0.000    0.000    0.000    0.000 threading.py:1169(is_alive)
#        35    0.000    0.000    0.000    0.000 types.py:58(encode)
#        33    0.000    0.000    0.000    0.000 cluster.py:135(leader_for_partition)
#     32/15    0.000    0.000    0.000    0.000 sensor.py:34(_check_forest)
#        32    0.000    0.000    0.000    0.000 subscription_state.py:393(_get_position)
#        30    0.000    0.000    0.000    0.000 selectors.py:276(_key_from_fd)
#        29    0.000    0.000    0.000    0.000 __init__.py:1532(log)
#        28    0.000    0.000    0.000    0.000 conn.py:945(_can_send_recv)
#        27    0.000    0.000    0.000    0.000 cluster.py:167(ttl)
#        25    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        25    0.000    0.000    0.000    0.000 six.py:589(itervalues)
#        25    0.000    0.000    0.000    0.000 client_async.py:615(_register_send_sockets)
#        25    0.001    0.000    0.099    0.004 client_async.py:625(_poll)
#        25    0.000    0.000    0.000    0.000 client_async.py:728(_fire_pending_completed_requests)
#        25    0.000    0.000    0.000    0.000 client_async.py:807(_maybe_refresh_metadata)
#        25    0.000    0.000    0.000    0.000 client_async.py:947(_maybe_close_oldest_connection)
#        25    0.000    0.000    0.000    0.000 client_async.py:1011(poll_expired_connection)
#        25    0.086    0.003    0.086    0.003 {method 'poll' of 'select.epoll' objects}
#        25    0.000    0.000    0.087    0.003 selectors.py:452(select)
#        24    0.000    0.000    0.000    0.000 metrics.py:119(sensor)
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        23    0.000    0.000    0.106    0.005 client_async.py:550(poll)
#        23    0.000    0.000    0.000    0.000 client_async.py:725(<listcomp>)
#        23    0.000    0.000    0.000    0.000 client_async.py:999(next_check_ms)
#        23    0.000    0.000    0.000    0.000 conn.py:867(connected)
#        23    0.000    0.000    0.000    0.000 max_stat.py:11(update)
#        23    0.000    0.000    0.000    0.000 frame.py:15(write)
#        22    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#        22    0.000    0.000    0.000    0.000 selectors.py:21(_fileobj_to_fd)
#        22    0.000    0.000    0.000    0.000 selectors.py:216(_fileobj_lookup)
#        22    0.000    0.000    0.000    0.000 {method 'fileno' of '_socket.socket' objects}
#        21    0.000    0.000    0.000    0.000 client_async.py:984(update)
#        21    0.000    0.000    0.000    0.000 types.py:45(encode)
#        20    0.000    0.000    0.000    0.000 conn.py:871(connecting)
#        20    0.000    0.000    0.000    0.000 subscription_state.py:313(partitions_auto_assigned)
#        20    0.000    0.000    0.000    0.000 subscription_state.py:343(has_all_fetch_positions)
#        19    0.000    0.000    0.000    0.000 {method '__copy__' of 'collections.deque' objects}
#        19    0.000    0.000    0.000    0.000 rate.py:40(__init__)
#        19    0.000    0.000    0.000    0.000 util.py:34(__init__)
#        19    0.000    0.000    0.604    0.032 group.py:665(_poll_once)
#        19    0.000    0.000    0.002    0.000 fetcher.py:115(send_fetches)
#        19    0.000    0.000    0.000    0.000 fetcher.py:146(_clean_done_fetch_futures)
#        19    0.000    0.000    0.000    0.000 fetcher.py:648(_fetchable_partitions)
#        19    0.000    0.000    0.001    0.000 fetcher.py:659(_create_fetch_requests)
#        19    0.000    0.000    0.000    0.000 subscription_state.py:305(fetchable_partitions)
#        19    0.000    0.000    0.000    0.000 consumer.py:190(_auto_assign_all_partitions)
#        19    0.000    0.000    0.000    0.000 consumer.py:258(poll)
#        18    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#        18    0.000    0.000    0.008    0.000 conn.py:1048(recv)
#        18    0.001    0.000    0.007    0.000 conn.py:1079(_recv)
#        18    0.000    0.000    0.004    0.000 parser.py:80(receive_bytes)
#        18    0.000    0.000    0.000    0.000 types.py:49(decode)
#     18/17    0.000    0.000    0.001    0.000 util.py:46(__call__)
#     18/10    0.000    0.000    0.000    0.000 types.py:146(<listcomp>)
#     18/10    0.000    0.000    0.000    0.000 types.py:143(encode)
#        18    0.000    0.000    0.000    0.000 consumer.py:295(time_to_next_poll)
#        18    0.000    0.000    0.000    0.000 consumer.py:362(need_rejoin)
#        18    0.000    0.000    0.000    0.000 base.py:322(time_to_next_heartbeat)
#        18    0.000    0.000    0.000    0.000 threading.py:264(__enter__)
#        18    0.000    0.000    0.000    0.000 threading.py:267(__exit__)
#     16/10    0.000    0.000    0.000    0.000 future.py:76(_call_backs)
#        16    0.000    0.000    0.000    0.000 struct.py:14(__init__)
#      16/5    0.000    0.000    0.001    0.000 types.py:193(<listcomp>)
#      16/5    0.000    0.000    0.001    0.000 types.py:189(decode)
#        15    0.000    0.000    0.000    0.000 sensor.py:18(__init__)
#        15    0.000    0.000    0.000    0.000 threading.py:90(RLock)
#        14    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        13    0.000    0.000    0.000    0.000 conn.py:1043(can_send_more)
#      13/8    0.000    0.000    0.001    0.000 types.py:152(<listcomp>)
#      13/8    0.000    0.000    0.001    0.000 types.py:151(decode)
#        13    0.000    0.000    0.000    0.000 frame.py:20(seek)
#        13    0.000    0.000    0.000    0.000 {method 'modify' of 'select.epoll' objects}
#        13    0.000    0.000    0.000    0.000 selectors.py:376(modify)
#        13    0.000    0.000    0.000    0.000 __init__.py:420(_make)
#        13    0.000    0.000    0.000    0.000 __init__.py:430(_replace)
#        11    0.000    0.000    0.000    0.000 types.py:84(encode)
#        11    0.000    0.000    0.000    0.000 types.py:90(decode)
#        10    0.000    0.000    0.000    0.000 client_async.py:509(_can_send_request)
#        10    0.000    0.000    0.000    0.000 cluster.py:80(is_bootstrap)
#        10    0.000    0.000    0.000    0.000 avg.py:10(__init__)
#        10    0.000    0.000    0.000    0.000 rate.py:108(__init__)
#        10    0.000    0.000    0.000    0.000 api.py:46(expect_response)
#        10    0.000    0.000    0.000    0.000 struct.py:43(<listcomp>)
#        10    0.000    0.000    0.000    0.000 struct.py:41(_encode_self)
#       9/4    0.000    0.000    0.000    0.000 future.py:31(success)
#         9    0.000    0.000    0.000    0.000 count.py:10(__init__)
#         9    0.000    0.000    0.000    0.000 max_stat.py:8(__init__)
#       9/5    0.000    0.000    0.000    0.000 types.py:186(<listcomp>)
#       9/5    0.000    0.000    0.000    0.000 types.py:181(encode)
#         9    0.001    0.000    0.001    0.000 frame.py:2(__init__)
#         9    0.000    0.000    0.000    0.000 fetcher.py:890(__len__)
#         8    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         8    0.000    0.000    0.000    0.000 subscription_state.py:356(is_assigned)
#         8    0.000    0.000    0.000    0.000 __init__.py:1467(info)
#       7/6    0.000    0.000    0.001    0.000 client_async.py:268(_conn_state_change)
#         7    0.000    0.000    0.001    0.000 client_async.py:515(send)
#         6    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         6    0.000    0.000    0.000    0.000 cluster.py:91(broker_metadata)
#         6    0.000    0.000    0.003    0.001 conn.py:359(connect)
#         6    0.000    0.000    0.000    0.000 conn.py:882(_reset_reconnect_backoff)
#         6    0.000    0.000    0.000    0.000 future.py:39(failure)
#         6    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#         6    0.000    0.000    0.000    0.000 random.py:239(_randbelow_with_getrandbits)
#         6    0.000    0.000    0.000    0.000 socket.py:99(_intenum_converter)
#         6    0.000    0.000    0.000    0.000 enum.py:359(__call__)
#         6    0.000    0.000    0.000    0.000 enum.py:678(__new__)
#         6    0.000    0.000    0.000    0.000 {method 'connect_ex' of '_socket.socket' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _socket.inet_pton}
#         5    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 client_async.py:260(_can_connect)
#         5    0.000    0.000    0.000    0.000 client_async.py:334(maybe_connect)
#         5    0.000    0.000    0.000    0.000 errors.py:514(for_code)
#         5    0.000    0.000    0.001    0.000 conn.py:570(_send_bytes)
#         5    0.000    0.000    0.000    0.000 conn.py:841(blacked_out)
#         5    0.000    0.000    0.001    0.000 conn.py:950(send)
#         5    0.000    0.000    0.001    0.000 conn.py:961(_send)
#         5    0.000    0.000    0.001    0.000 conn.py:1010(send_pending_requests_v2)
#         5    0.000    0.000    0.000    0.000 parser.py:40(_next_correlation_id)
#         5    0.000    0.000    0.000    0.000 parser.py:74(send_bytes)
#         5    0.000    0.000    0.001    0.000 parser.py:47(send_request)
#         5    0.000    0.000    0.000    0.000 api.py:17(__init__)
#         5    0.000    0.000    0.000    0.000 random.py:380(shuffle)
#         5    0.000    0.000    0.000    0.000 selectors.py:70(__getitem__)
#         5    0.000    0.000    0.000    0.000 selectors.py:181(get_key)
#         5    0.000    0.000    0.000    0.000 selectors.py:273(get_map)
#         5    0.001    0.000    0.001    0.000 {method 'send' of '_socket.socket' objects}
#         4    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 client_async.py:939(_clear_wake_fd)
#         4    0.000    0.000    0.000    0.000 future.py:19(succeeded)
#         4    0.000    0.000    0.000    0.000 parser.py:28(__init__)
#         4    0.000    0.000    0.002    0.000 parser.py:137(_process_response)
#         4    0.000    0.000    0.001    0.000 struct.py:50(<listcomp>)
#         4    0.000    0.000    0.002    0.000 struct.py:46(decode)
#         4    0.000    0.000    0.000    0.000 types.py:71(encode)
#         4    0.000    0.000    0.000    0.000 parser.py:180(_reset_buffer)
#         4    0.000    0.000    0.001    0.000 fetcher.py:513(_send_offset_requests)
#         4    0.000    0.000    0.001    0.000 fetcher.py:563(_send_offset_request)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:282(issubclass_)
#         4    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         4    0.000    0.000    0.000    0.000 _dtype.py:314(_name_includes_bit_suffix)
#         4    0.000    0.000    0.000    0.000 _dtype.py:328(_name_get)
#         4    0.000    0.000    0.000    0.000 subscription_state.py:340(is_offset_reset_needed)
#         3    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'split' of 'bytes' objects}
#         3    0.000    0.000    0.005    0.002 client_async.py:365(_maybe_connect)
#         3    0.000    0.000    0.000    0.000 client_async.py:754(<listcomp>)
#         3    0.000    0.000    0.000    0.000 client_async.py:742(least_loaded_node)
#         3    0.000    0.000    0.000    0.000 cluster.py:83(brokers)
#         3    0.000    0.000    0.002    0.001 conn.py:232(__init__)
#         3    0.000    0.000    0.002    0.001 conn.py:312(_dns_lookup)
#         3    0.000    0.000    0.002    0.001 conn.py:320(_next_afi_sockaddr)
#         3    0.000    0.000    0.002    0.001 conn.py:1309(__init__)
#         3    0.000    0.000    0.000    0.000 conn.py:1417(_address_family)
#         3    0.000    0.000    0.000    0.000 conn.py:1435(get_ip_port_afi)
#         3    0.000    0.000    0.000    0.000 conn.py:1510(is_inet_4_or_6)
#         3    0.000    0.000    0.002    0.001 conn.py:1515(dns_lookup)
#         3    0.000    0.000    0.000    0.000 types.py:75(decode)
#         3    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         3    0.000    0.000    0.000    0.000 idna.py:147(encode)
#         3    0.000    0.000    0.000    0.000 socket.py:220(__init__)
#         3    0.000    0.000    0.002    0.001 socket.py:938(getaddrinfo)
#         3    0.000    0.000    0.000    0.000 {method 'register' of 'select.epoll' objects}
#         3    0.000    0.000    0.000    0.000 selectors.py:235(register)
#         3    0.000    0.000    0.000    0.000 selectors.py:352(register)
#         3    0.000    0.000    0.000    0.000 {method 'setblocking' of '_socket.socket' objects}
#         3    0.000    0.000    0.000    0.000 {method 'setsockopt' of '_socket.socket' objects}
#         3    0.002    0.001    0.002    0.001 {built-in method _socket.getaddrinfo}
#         2    0.201    0.100    0.201    0.100 {built-in method time.sleep}
#         2    0.000    0.000    0.000    0.000 take.py:288(_get_take_nd_function_cached)
#         2    0.000    0.000    0.000    0.000 client_async.py:395(ready)
#         2    0.000    0.000    0.000    0.000 client_async.py:483(is_ready)
#         2    0.000    0.000    0.000    0.000 conn.py:878(disconnected)
#         2    0.000    0.000    0.000    0.000 future.py:25(retriable)
#         2    0.000    0.000    0.000    0.000 types.py:131(decode)
#         2    0.000    0.000    0.604    0.302 group.py:614(poll)
#         2    0.000    0.000    0.210    0.105 fetcher.py:218(_reset_offset)
#         2    0.000    0.000    0.210    0.105 fetcher.py:249(_retrieve_offsets)
#         2    0.000    0.000    0.001    0.000 fetcher.py:352(_append)
#         2    0.000    0.000    0.000    0.000 fetcher.py:545(on_success)
#         2    0.000    0.000    0.000    0.000 fetcher.py:553(on_fail)
#         2    0.000    0.000    0.000    0.000 fetcher.py:584(<lambda>)
#         2    0.000    0.000    0.000    0.000 fetcher.py:587(_handle_offset_response)
#         2    0.000    0.000    0.000    0.000 fetcher.py:669(<lambda>)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:356(issubdtype)
#         2    0.000    0.000    0.000    0.000 fetcher.py:898(take)
#         2    0.000    0.000    0.000    0.000 subscription_state.py:281(seek)
#         2    0.000    0.000    0.000    0.000 subscription_state.py:325(need_offset_reset)
#         2    0.000    0.000    0.000    0.000 subscription_state.py:371(_add_assigned_partition)
#         2    0.000    0.000    0.000    0.000 subscription_state.py:376(__init__)
#         2    0.000    0.000    0.000    0.000 subscription_state.py:398(await_reset)
#         2    0.000    0.000    0.000    0.000 subscription_state.py:405(seek)
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 base.py:415(_engine_type)
#         1    0.000    0.000    0.000    0.000 cast.py:509(ensure_dtype_can_hold_na)
#         1    0.000    0.000    0.000    0.000 cast.py:567(_maybe_promote_cached)
#         1    0.000    0.000    0.000    0.000 cast.py:575(_maybe_promote)
#         1    0.000    0.000    0.000    0.000 client_async.py:843(refresh_done)
#         1    0.000    0.000    0.000    0.000 client_async.py:990(remove)
#         1    0.000    0.000    0.000    0.000 client_async.py:994(is_expired)
#         1    0.000    0.000    0.000    0.000 cluster.py:229(update_metadata)
#         1    0.000    0.000    0.000    0.000 conn.py:886(_update_reconnect_backoff)
#         1    0.000    0.000    0.000    0.000 conn.py:898(_close_socket)
#         1    0.000    0.000    0.000    0.000 conn.py:903(__del__)
#         1    0.000    0.000    0.000    0.000 conn.py:906(close)
#         1    0.000    0.000    0.000    0.000 conn.py:1302(__str__)
#         1    0.000    0.000    0.001    0.001 types.py:108(decode)
#         1    0.000    0.000    0.210    0.210 group.py:1084(_update_fetch_positions)
#         1    0.000    0.000    0.000    0.000 group.py:1181(__iter__)
#         1    0.000    0.000    0.000    0.000 fetcher.py:134(reset_offsets_if_needed)
#         1    0.000    0.000    0.210    0.210 fetcher.py:159(update_fetch_positions)
#         1    0.000    0.000    0.000    0.000 fetcher.py:758(<listcomp>)
#         1    0.000    0.000    0.000    0.000 fetcher.py:750(_handle_fetch_response)
#         1    0.003    0.003    0.293    0.293 fetcher.py:781(_parse_fetched_data)
#         1    0.000    0.000    0.000    0.000 fetcher.py:869(__init__)
#         1    0.018    0.018    8.117    8.117 message_service.py:68(run)
#         1    0.000    0.000    0.000    0.000 cProfile.py:117(__exit__)
#         1    0.000    0.000    0.000    0.000 fetcher.py:919(__init__)
#         1    0.000    0.000    0.000    0.000 fetcher.py:925(record)
#         1    0.000    0.000    0.001    0.001 fetcher.py:978(record_topic_fetch_metrics)
#         1    0.000    0.000    0.000    0.000 memory_records.py:42(__init__)
#         1    0.000    0.000    0.000    0.000 memory_records.py:53(valid_bytes)
#         1    0.000    0.000    0.000    0.000 memory_records.py:92(has_next)
#         1    0.000    0.000    0.000    0.000 subscription_state.py:233(assign_from_subscribed)
#         1    0.000    0.000    0.000    0.000 subscription_state.py:266(group_subscription)
#         1    0.000    0.000    0.000    0.000 subscription_state.py:349(missing_fetch_positions)
#         1    0.000    0.000    0.000    0.000 consumer.py:184(<listcomp>)
#         1    0.000    0.000    0.000    0.000 consumer.py:159(_handle_metadata_update)
#         1    0.000    0.000    0.000    0.000 consumer.py:200(_build_metadata_snapshot)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 random.py:546(uniform)
#         1    0.000    0.000    0.000    0.000 socket.py:494(_real_close)
#         1    0.000    0.000    0.000    0.000 socket.py:498(close)
#         1    0.000    0.000    0.000    0.000 {method 'unregister' of 'select.epoll' objects}
#         1    0.000    0.000    0.000    0.000 selectors.py:248(unregister)
#         1    0.000    0.000    0.000    0.000 selectors.py:366(unregister)
#         1    0.000    0.000    0.000    0.000 {function socket.close at 0x7f7f49b7e950}

# %%
movie_data_processor_report.dump_stats('movie_data_processor.profile')

# %% [markdown]
# ## Visualisation of Profilings

# %%
# %load_ext snakeviz

# %%
# %snakeviz movie_data_processor.run(1000)
# Out:
# Storing properties title, genres for movie 1019
# Storing properties title, genres for movie 1020
# Storing properties title, genres for movie 1021
# Storing properties title, genres for movie 1022
# Storing properties title, genres for movie 1023
# Storing properties title, genres for movie 1024
# Storing properties title, genres for movie 1025
# Storing properties title, genres for movie 1026
# Storing properties title, genres for movie 1027
# Storing properties title, genres for movie 1028
# Storing properties title, genres for movie 1029
# Storing properties title, genres for movie 1030
# Storing properties title, genres for movie 1031
# Storing properties title, genres for movie 1032
# Storing properties title, genres for movie 1033
# Storing properties title, genres for movie 1034
# Storing properties title, genres for movie 1035
# Storing properties title, genres for movie 1036
# Storing properties title, genres for movie 1037
# Storing properties title, genres for movie 1038
# Storing properties title, genres for movie 1039
# Storing properties title, genres for movie 1040
# Storing properties title, genres for movie 1041
# Storing properties title, genres for movie 1042
# Storing properties title, genres for movie 1043
# Storing properties title, genres for movie 1044
# Storing properties title, genres for movie 1045
# Storing properties title, genres for movie 1046
# Storing properties title, genres for movie 1047
# Storing properties title, genres for movie 1049
# Storing properties title, genres for movie 1050
# Storing properties title, genres for movie 1051
# Storing properties title, genres for movie 1052
# Storing properties title, genres for movie 1053
# Storing properties title, genres for movie 1054
# Storing properties title, genres for movie 1055
# Storing properties title, genres for movie 1056
# Storing properties title, genres for movie 1057
# Storing properties title, genres for movie 1058
# Storing properties title, genres for movie 1059
# Storing properties title, genres for movie 1060
# Storing properties title, genres for movie 1061
# Storing properties title, genres for movie 1062
# Storing properties title, genres for movie 1063
# Storing properties title, genres for movie 1064
# Storing properties title, genres for movie 1065
# Storing properties title, genres for movie 1066
# Storing properties title, genres for movie 1067
# Storing properties title, genres for movie 1068
# Storing properties title, genres for movie 1069
# Storing properties title, genres for movie 1070
# Storing properties title, genres for movie 1071
# Storing properties title, genres for movie 1073
# Storing properties title, genres for movie 1075
# Storing properties title, genres for movie 1076
# Storing properties title, genres for movie 1077
# Storing properties title, genres for movie 1078
# Storing properties title, genres for movie 1079
# Storing properties title, genres for movie 1080
# Storing properties title, genres for movie 1081
# Storing properties title, genres for movie 1082
# Storing properties title, genres for movie 1083
# Storing properties title, genres for movie 1084
# Storing properties title, genres for movie 1085
# Storing properties title, genres for movie 1086
# Storing properties title, genres for movie 1087
# Storing properties title, genres for movie 1088
# Storing properties title, genres for movie 1089
# Storing properties title, genres for movie 1090
# Storing properties title, genres for movie 1091
# Storing properties title, genres for movie 1092
# Storing properties title, genres for movie 1093
# Storing properties title, genres for movie 1094
# Storing properties title, genres for movie 1095
# Storing properties title, genres for movie 1096
# Storing properties title, genres for movie 1097
# Storing properties title, genres for movie 1098
# Storing properties title, genres for movie 1099
# Storing properties title, genres for movie 1100
# Storing properties title, genres for movie 1101
# Storing properties title, genres for movie 1102
# Storing properties title, genres for movie 1103
# Storing properties title, genres for movie 1104
# Storing properties title, genres for movie 1105
# Storing properties title, genres for movie 1106
# Storing properties title, genres for movie 1107
# Storing properties title, genres for movie 1109
# Storing properties title, genres for movie 1110
# Storing properties title, genres for movie 1111
# Storing properties title, genres for movie 1112
# Storing properties title, genres for movie 1113
# Storing properties title, genres for movie 1114
# Storing properties title, genres for movie 1115
# Storing properties title, genres for movie 1116
# Storing properties title, genres for movie 1117
# Storing properties title, genres for movie 1118
# Storing properties title, genres for movie 1119
# Storing properties title, genres for movie 1120
# Storing properties title, genres for movie 1121
# Storing properties title, genres for movie 1122
# Storing properties title, genres for movie 1123
# Storing properties title, genres for movie 1124
# Storing properties title, genres for movie 1125
# Storing properties title, genres for movie 1126
# Storing properties title, genres for movie 1127
# Storing properties title, genres for movie 1128
# Storing properties title, genres for movie 1129
# Storing properties title, genres for movie 1130
# Storing properties title, genres for movie 1131
# Storing properties title, genres for movie 1132
# Storing properties title, genres for movie 1133
# Storing properties title, genres for movie 1134
# Storing properties title, genres for movie 1135
# Storing properties title, genres for movie 1136
# Storing properties title, genres for movie 1137
# Storing properties title, genres for movie 1138
# Storing properties title, genres for movie 1139
# Storing properties title, genres for movie 1140
# Storing properties title, genres for movie 1141
# Storing properties title, genres for movie 1142
# Storing properties title, genres for movie 1143
# Storing properties title, genres for movie 1144
# Storing properties title, genres for movie 1145
# Storing properties title, genres for movie 1146
# Storing properties title, genres for movie 1147
# Storing properties title, genres for movie 1148
# Storing properties title, genres for movie 1149
# Storing properties title, genres for movie 1150
# Storing properties title, genres for movie 1151
# Storing properties title, genres for movie 1152
# Storing properties title, genres for movie 1153
# Storing properties title, genres for movie 1154
# Storing properties title, genres for movie 1155
# Storing properties title, genres for movie 1156
# Storing properties title, genres for movie 1157
# Storing properties title, genres for movie 1158
# Storing properties title, genres for movie 1159
# Storing properties title, genres for movie 1160
# Storing properties title, genres for movie 1161
# Storing properties title, genres for movie 1162
# Storing properties title, genres for movie 1163
# Storing properties title, genres for movie 1164
# Storing properties title, genres for movie 1165
# Storing properties title, genres for movie 1166
# Storing properties title, genres for movie 1167
# Storing properties title, genres for movie 1168
# Storing properties title, genres for movie 1169
# Storing properties title, genres for movie 1170
# Storing properties title, genres for movie 1171
# Storing properties title, genres for movie 1172
# Storing properties title, genres for movie 1173
# Storing properties title, genres for movie 1174
# Storing properties title, genres for movie 1175
# Storing properties title, genres for movie 1176
# Storing properties title, genres for movie 1177
# Storing properties title, genres for movie 1178
# Storing properties title, genres for movie 1179
# Storing properties title, genres for movie 1180
# Storing properties title, genres for movie 1181
# Storing properties title, genres for movie 1183
# Storing properties title, genres for movie 1184
# Storing properties title, genres for movie 1185
# Storing properties title, genres for movie 1186
# Storing properties title, genres for movie 1187
# Storing properties title, genres for movie 1188
# Storing properties title, genres for movie 1189
# Storing properties title, genres for movie 1190
# Storing properties title, genres for movie 1191
# Storing properties title, genres for movie 1192
# Storing properties title, genres for movie 1193
# Storing properties title, genres for movie 1194
# Storing properties title, genres for movie 1196
# Storing properties title, genres for movie 1197
# Storing properties title, genres for movie 1198
# Storing properties title, genres for movie 1199
# Storing properties title, genres for movie 1200
# Storing properties title, genres for movie 1201
# Storing properties title, genres for movie 1202
# Storing properties title, genres for movie 1203
# Storing properties title, genres for movie 1204
# Storing properties title, genres for movie 1206
# Storing properties title, genres for movie 1207
# Storing properties title, genres for movie 1208
# Storing properties title, genres for movie 1209
# Storing properties title, genres for movie 1210
# Storing properties title, genres for movie 1211
# Storing properties title, genres for movie 1212
# Storing properties title, genres for movie 1213
# Storing properties title, genres for movie 1214
# Storing properties title, genres for movie 1215
# Storing properties title, genres for movie 1216
# Storing properties title, genres for movie 1217
# Storing properties title, genres for movie 1218
# Storing properties title, genres for movie 1219
# Storing properties title, genres for movie 1220
# Storing properties title, genres for movie 1221
# Storing properties title, genres for movie 1222
# Storing properties title, genres for movie 1223
# Storing properties title, genres for movie 1224
# Storing properties title, genres for movie 1225
# Storing properties title, genres for movie 1226
# Storing properties title, genres for movie 1227
# Storing properties title, genres for movie 1228
# Storing properties title, genres for movie 1230
# Storing properties title, genres for movie 1231
# Storing properties title, genres for movie 1232
# Storing properties title, genres for movie 1233
# Storing properties title, genres for movie 1234
# Storing properties title, genres for movie 1235
# Storing properties title, genres for movie 1236
# Storing properties title, genres for movie 1237
# Storing properties title, genres for movie 1238
# Storing properties title, genres for movie 1240
# Storing properties title, genres for movie 1241
# Storing properties title, genres for movie 1242
# Storing properties title, genres for movie 1243
# Storing properties title, genres for movie 1244
# Storing properties title, genres for movie 1245
# Storing properties title, genres for movie 1246
# Storing properties title, genres for movie 1247
# Storing properties title, genres for movie 1248
# Storing properties title, genres for movie 1249
# Storing properties title, genres for movie 1250
# Storing properties title, genres for movie 1251
# Storing properties title, genres for movie 1252
# Storing properties title, genres for movie 1253
# Storing properties title, genres for movie 1254
# Storing properties title, genres for movie 1255
# Storing properties title, genres for movie 1256
# Storing properties title, genres for movie 1257
# Storing properties title, genres for movie 1258
# Storing properties title, genres for movie 1259
# Storing properties title, genres for movie 1260
# Storing properties title, genres for movie 1261
# Storing properties title, genres for movie 1262
# Storing properties title, genres for movie 1263
# Storing properties title, genres for movie 1264
# Storing properties title, genres for movie 1265
# Storing properties title, genres for movie 1266
# Storing properties title, genres for movie 1267
# Storing properties title, genres for movie 1268
# Storing properties title, genres for movie 1269
# Storing properties title, genres for movie 1270
# Storing properties title, genres for movie 1271
# Storing properties title, genres for movie 1272
# Storing properties title, genres for movie 1273
# Storing properties title, genres for movie 1274
# Storing properties title, genres for movie 1275
# Storing properties title, genres for movie 1276
# Storing properties title, genres for movie 1277
# Storing properties title, genres for movie 1278
# Storing properties title, genres for movie 1279
# Storing properties title, genres for movie 1280
# Storing properties title, genres for movie 1281
# Storing properties title, genres for movie 1282
# Storing properties title, genres for movie 1283
# Storing properties title, genres for movie 1284
# Storing properties title, genres for movie 1285
# Storing properties title, genres for movie 1286
# Storing properties title, genres for movie 1287
# Storing properties title, genres for movie 1288
# Storing properties title, genres for movie 1289
# Storing properties title, genres for movie 1290
# Storing properties title, genres for movie 1291
# Storing properties title, genres for movie 1292
# Storing properties title, genres for movie 1293
# Storing properties title, genres for movie 1295
# Storing properties title, genres for movie 1296
# Storing properties title, genres for movie 1297
# Storing properties title, genres for movie 1298
# Storing properties title, genres for movie 1299
# Storing properties title, genres for movie 1300
# Storing properties title, genres for movie 1301
# Storing properties title, genres for movie 1302
# Storing properties title, genres for movie 1303
# Storing properties title, genres for movie 1304
# Storing properties title, genres for movie 1305
# Storing properties title, genres for movie 1306
# Storing properties title, genres for movie 1307
# Storing properties title, genres for movie 1308
# Storing properties title, genres for movie 1309
# Storing properties title, genres for movie 1310
# Storing properties title, genres for movie 1311
# Storing properties title, genres for movie 1312
# Storing properties title, genres for movie 1313
# Storing properties title, genres for movie 1314
# Storing properties title, genres for movie 1315
# Storing properties title, genres for movie 1316
# Storing properties title, genres for movie 1317
# Storing properties title, genres for movie 1318
# Storing properties title, genres for movie 1319
# Storing properties title, genres for movie 1320
# Storing properties title, genres for movie 1321
# Storing properties title, genres for movie 1322
# Storing properties title, genres for movie 1323
# Storing properties title, genres for movie 1324
# Storing properties title, genres for movie 1325
# Storing properties title, genres for movie 1326
# Storing properties title, genres for movie 1327
# Storing properties title, genres for movie 1328
# Storing properties title, genres for movie 1329
# Storing properties title, genres for movie 1330
# Storing properties title, genres for movie 1331
# Storing properties title, genres for movie 1332
# Storing properties title, genres for movie 1333
# Storing properties title, genres for movie 1334
# Storing properties title, genres for movie 1335
# Storing properties title, genres for movie 1336
# Storing properties title, genres for movie 1337
# Storing properties title, genres for movie 1339
# Storing properties title, genres for movie 1340
# Storing properties title, genres for movie 1341
# Storing properties title, genres for movie 1342
# Storing properties title, genres for movie 1343
# Storing properties title, genres for movie 1344
# Storing properties title, genres for movie 1345
# Storing properties title, genres for movie 1346
# Storing properties title, genres for movie 1347
# Storing properties title, genres for movie 1348
# Storing properties title, genres for movie 1349
# Storing properties title, genres for movie 1350
# Storing properties title, genres for movie 1351
# Storing properties title, genres for movie 1352
# Storing properties title, genres for movie 1353
# Storing properties title, genres for movie 1354
# Storing properties title, genres for movie 1355
# Storing properties title, genres for movie 1356
# Storing properties title, genres for movie 1357
# Storing properties title, genres for movie 1358
# Storing properties title, genres for movie 1359
# Storing properties title, genres for movie 1360
# Storing properties title, genres for movie 1361
# Storing properties title, genres for movie 1363
# Storing properties title, genres for movie 1364
# Storing properties title, genres for movie 1365
# Storing properties title, genres for movie 1366
# Storing properties title, genres for movie 1367
# Storing properties title, genres for movie 1368
# Storing properties title, genres for movie 1369
# Storing properties title, genres for movie 1370
# Storing properties title, genres for movie 1371
# Storing properties title, genres for movie 1372
# Storing properties title, genres for movie 1373
# Storing properties title, genres for movie 1374
# Storing properties title, genres for movie 1375
# Storing properties title, genres for movie 1376
# Storing properties title, genres for movie 1377
# Storing properties title, genres for movie 1378
# Storing properties title, genres for movie 1379
# Storing properties title, genres for movie 1380
# Storing properties title, genres for movie 1381
# Storing properties title, genres for movie 1382
# Storing properties title, genres for movie 1383
# Storing properties title, genres for movie 1384
# Storing properties title, genres for movie 1385
# Storing properties title, genres for movie 1386
# Storing properties title, genres for movie 1387
# Storing properties title, genres for movie 1388
# Storing properties title, genres for movie 1389
# Storing properties title, genres for movie 1390
# Storing properties title, genres for movie 1391
# Storing properties title, genres for movie 1392
# Storing properties title, genres for movie 1393
# Storing properties title, genres for movie 1394
# Storing properties title, genres for movie 1395
# Storing properties title, genres for movie 1396
# Storing properties title, genres for movie 1397
# Storing properties title, genres for movie 1398
# Storing properties title, genres for movie 1399
# Storing properties title, genres for movie 1400
# Storing properties title, genres for movie 1401
# Storing properties title, genres for movie 1404
# Storing properties title, genres for movie 1405
# Storing properties title, genres for movie 1406
# Storing properties title, genres for movie 1407
# Storing properties title, genres for movie 1408
# Storing properties title, genres for movie 1409
# Storing properties title, genres for movie 1410
# Storing properties title, genres for movie 1411
# Storing properties title, genres for movie 1412
# Storing properties title, genres for movie 1413
# Storing properties title, genres for movie 1414
# Storing properties title, genres for movie 1415
# Storing properties title, genres for movie 1416
# Storing properties title, genres for movie 1417
# Storing properties title, genres for movie 1419
# Storing properties title, genres for movie 1420
# Storing properties title, genres for movie 1421
# Storing properties title, genres for movie 1422
# Storing properties title, genres for movie 1423
# Storing properties title, genres for movie 1424
# Storing properties title, genres for movie 1425
# Storing properties title, genres for movie 1426
# Storing properties title, genres for movie 1427
# Storing properties title, genres for movie 1428
# Storing properties title, genres for movie 1429
# Storing properties title, genres for movie 1430
# Storing properties title, genres for movie 1431
# Storing properties title, genres for movie 1432
# Storing properties title, genres for movie 1433
# Storing properties title, genres for movie 1434
# Storing properties title, genres for movie 1436
# Storing properties title, genres for movie 1437
# Storing properties title, genres for movie 1438
# Storing properties title, genres for movie 1439
# Storing properties title, genres for movie 1440
# Storing properties title, genres for movie 1441
# Storing properties title, genres for movie 1442
# Storing properties title, genres for movie 1443
# Storing properties title, genres for movie 1444
# Storing properties title, genres for movie 1445
# Storing properties title, genres for movie 1446
# Storing properties title, genres for movie 1447
# Storing properties title, genres for movie 1448
# Storing properties title, genres for movie 1449
# Storing properties title, genres for movie 1450
# Storing properties title, genres for movie 1453
# Storing properties title, genres for movie 1454
# Storing properties title, genres for movie 1455
# Storing properties title, genres for movie 1456
# Storing properties title, genres for movie 1457
# Storing properties title, genres for movie 1458
# Storing properties title, genres for movie 1459
# Storing properties title, genres for movie 1460
# Storing properties title, genres for movie 1461
# Storing properties title, genres for movie 1462
# Storing properties title, genres for movie 1463
# Storing properties title, genres for movie 1464
# Storing properties title, genres for movie 1465
# Storing properties title, genres for movie 1466
# Storing properties title, genres for movie 1467
# Storing properties title, genres for movie 1468
# Storing properties title, genres for movie 1470
# Storing properties title, genres for movie 1471
# Storing properties title, genres for movie 1472
# Storing properties title, genres for movie 1473
# Storing properties title, genres for movie 1474
# Storing properties title, genres for movie 1475
# Storing properties title, genres for movie 1476
# Storing properties title, genres for movie 1477
# Storing properties title, genres for movie 1479
# Storing properties title, genres for movie 1480
# Storing properties title, genres for movie 1482
# Storing properties title, genres for movie 1483
# Storing properties title, genres for movie 1484
# Storing properties title, genres for movie 1485
# Storing properties title, genres for movie 1486
# Storing properties title, genres for movie 1487
# Storing properties title, genres for movie 1488
# Storing properties title, genres for movie 1489
# Storing properties title, genres for movie 1490
# Storing properties title, genres for movie 1493
# Storing properties title, genres for movie 1495
# Storing properties title, genres for movie 1496
# Storing properties title, genres for movie 1497
# Storing properties title, genres for movie 1498
# Storing properties title, genres for movie 1499
# Storing properties title, genres for movie 1500
# Storing properties title, genres for movie 1501
# Storing properties title, genres for movie 1502
# Storing properties title, genres for movie 1503
# Storing properties title, genres for movie 1504
# Storing properties title, genres for movie 1507
# Storing properties title, genres for movie 1508
# Storing properties title, genres for movie 1509
# Storing properties title, genres for movie 1510
# Storing properties title, genres for movie 1511
# Storing properties title, genres for movie 1513
# Storing properties title, genres for movie 1514
# Storing properties title, genres for movie 1515
# Storing properties title, genres for movie 1516
# Storing properties title, genres for movie 1517
# Storing properties title, genres for movie 1518
# Storing properties title, genres for movie 1519
# Storing properties title, genres for movie 1520
# Storing properties title, genres for movie 1522
# Storing properties title, genres for movie 1523
# Storing properties title, genres for movie 1524
# Storing properties title, genres for movie 1525
# Storing properties title, genres for movie 1526
# Storing properties title, genres for movie 1527
# Storing properties title, genres for movie 1528
# Storing properties title, genres for movie 1529
# Storing properties title, genres for movie 1531
# Storing properties title, genres for movie 1532
# Storing properties title, genres for movie 1533
# Storing properties title, genres for movie 1534
# Storing properties title, genres for movie 1535
# Storing properties title, genres for movie 1537
# Storing properties title, genres for movie 1538
# Storing properties title, genres for movie 1539
# Storing properties title, genres for movie 1541
# Storing properties title, genres for movie 1542
# Storing properties title, genres for movie 1543
# Storing properties title, genres for movie 1544
# Storing properties title, genres for movie 1545
# Storing properties title, genres for movie 1546
# Storing properties title, genres for movie 1547
# Storing properties title, genres for movie 1548
# Storing properties title, genres for movie 1549
# Storing properties title, genres for movie 1550
# Storing properties title, genres for movie 1551
# Storing properties title, genres for movie 1552
# Storing properties title, genres for movie 1553
# Storing properties title, genres for movie 1554
# Storing properties title, genres for movie 1555
# Storing properties title, genres for movie 1556
# Storing properties title, genres for movie 1557
# Storing properties title, genres for movie 1558
# Storing properties title, genres for movie 1559
# Storing properties title, genres for movie 1561
# Storing properties title, genres for movie 1562
# Storing properties title, genres for movie 1563
# Storing properties title, genres for movie 1564
# Storing properties title, genres for movie 1565
# Storing properties title, genres for movie 1566
# Storing properties title, genres for movie 1567
# Storing properties title, genres for movie 1568
# Storing properties title, genres for movie 1569
# Storing properties title, genres for movie 1570
# Storing properties title, genres for movie 1571
# Storing properties title, genres for movie 1572
# Storing properties title, genres for movie 1573
# Storing properties title, genres for movie 1574
# Storing properties title, genres for movie 1575
# Storing properties title, genres for movie 1577
# Storing properties title, genres for movie 1578
# Storing properties title, genres for movie 1579
# Storing properties title, genres for movie 1580
# Storing properties title, genres for movie 1581
# Storing properties title, genres for movie 1582
# Storing properties title, genres for movie 1583
# Storing properties title, genres for movie 1584
# Storing properties title, genres for movie 1585
# Storing properties title, genres for movie 1586
# Storing properties title, genres for movie 1587
# Storing properties title, genres for movie 1588
# Storing properties title, genres for movie 1589
# Storing properties title, genres for movie 1590
# Storing properties title, genres for movie 1591
# Storing properties title, genres for movie 1592
# Storing properties title, genres for movie 1593
# Storing properties title, genres for movie 1594
# Storing properties title, genres for movie 1595
# Storing properties title, genres for movie 1596
# Storing properties title, genres for movie 1597
# Storing properties title, genres for movie 1598
# Storing properties title, genres for movie 1599
# Storing properties title, genres for movie 1600
# Storing properties title, genres for movie 1601
# Storing properties title, genres for movie 1602
# Storing properties title, genres for movie 1603
# Storing properties title, genres for movie 1604
# Storing properties title, genres for movie 1605
# Storing properties title, genres for movie 1606
# Storing properties title, genres for movie 1608
# Storing properties title, genres for movie 1609
# Storing properties title, genres for movie 1610
# Storing properties title, genres for movie 1611
# Storing properties title, genres for movie 1612
# Storing properties title, genres for movie 1613
# Storing properties title, genres for movie 1614
# Storing properties title, genres for movie 1615
# Storing properties title, genres for movie 1616
# Storing properties title, genres for movie 1617
# Storing properties title, genres for movie 1619
# Storing properties title, genres for movie 1620
# Storing properties title, genres for movie 1621
# Storing properties title, genres for movie 1622
# Storing properties title, genres for movie 1623
# Storing properties title, genres for movie 1624
# Storing properties title, genres for movie 1625
# Storing properties title, genres for movie 1626
# Storing properties title, genres for movie 1627
# Storing properties title, genres for movie 1628
# Storing properties title, genres for movie 1629
# Storing properties title, genres for movie 1630
# Storing properties title, genres for movie 1631
# Storing properties title, genres for movie 1632
# Storing properties title, genres for movie 1633
# Storing properties title, genres for movie 1635
# Storing properties title, genres for movie 1636
# Storing properties title, genres for movie 1639
# Storing properties title, genres for movie 1640
# Storing properties title, genres for movie 1641
# Storing properties title, genres for movie 1642
# Storing properties title, genres for movie 1643
# Storing properties title, genres for movie 1644
# Storing properties title, genres for movie 1645
# Storing properties title, genres for movie 1646
# Storing properties title, genres for movie 1647
# Storing properties title, genres for movie 1648
# Storing properties title, genres for movie 1649
# Storing properties title, genres for movie 1650
# Storing properties title, genres for movie 1651
# Storing properties title, genres for movie 1652
# Storing properties title, genres for movie 1653
# Storing properties title, genres for movie 1654
# Storing properties title, genres for movie 1655
# Storing properties title, genres for movie 1656
# Storing properties title, genres for movie 1657
# Storing properties title, genres for movie 1658
# Storing properties title, genres for movie 1659
# Storing properties title, genres for movie 1660
# Storing properties title, genres for movie 1661
# Storing properties title, genres for movie 1662
# Storing properties title, genres for movie 1663
# Storing properties title, genres for movie 1664
# Storing properties title, genres for movie 1665
# Storing properties title, genres for movie 1666
# Storing properties title, genres for movie 1667
# Storing properties title, genres for movie 1668
# Storing properties title, genres for movie 1669
# Storing properties title, genres for movie 1670
# Storing properties title, genres for movie 1671
# Storing properties title, genres for movie 1672
# Storing properties title, genres for movie 1673
# Storing properties title, genres for movie 1674
# Storing properties title, genres for movie 1675
# Storing properties title, genres for movie 1676
# Storing properties title, genres for movie 1677
# Storing properties title, genres for movie 1678
# Storing properties title, genres for movie 1679
# Storing properties title, genres for movie 1680
# Storing properties title, genres for movie 1681
# Storing properties title, genres for movie 1682
# Storing properties title, genres for movie 1683
# Storing properties title, genres for movie 1684
# Storing properties title, genres for movie 1685
# Storing properties title, genres for movie 1686
# Storing properties title, genres for movie 1687
# Storing properties title, genres for movie 1688
# Storing properties title, genres for movie 1689
# Storing properties title, genres for movie 1690
# Storing properties title, genres for movie 1692
# Storing properties title, genres for movie 1693
# Storing properties title, genres for movie 1694
# Storing properties title, genres for movie 1695
# Storing properties title, genres for movie 1696
# Storing properties title, genres for movie 1697
# Storing properties title, genres for movie 1698
# Storing properties title, genres for movie 1699
# Storing properties title, genres for movie 1701
# Storing properties title, genres for movie 1702
# Storing properties title, genres for movie 1703
# Storing properties title, genres for movie 1704
# Storing properties title, genres for movie 1705
# Storing properties title, genres for movie 1706
# Storing properties title, genres for movie 1707
# Storing properties title, genres for movie 1708
# Storing properties title, genres for movie 1709
# Storing properties title, genres for movie 1710
# Storing properties title, genres for movie 1711
# Storing properties title, genres for movie 1713
# Storing properties title, genres for movie 1714
# Storing properties title, genres for movie 1715
# Storing properties title, genres for movie 1716
# Storing properties title, genres for movie 1717
# Storing properties title, genres for movie 1718
# Storing properties title, genres for movie 1719
# Storing properties title, genres for movie 1720
# Storing properties title, genres for movie 1721
# Storing properties title, genres for movie 1722
# Storing properties title, genres for movie 1723
# Storing properties title, genres for movie 1724
# Storing properties title, genres for movie 1725
# Storing properties title, genres for movie 1726
# Storing properties title, genres for movie 1727
# Storing properties title, genres for movie 1728
# Storing properties title, genres for movie 1729
# Storing properties title, genres for movie 1730
# Storing properties title, genres for movie 1731
# Storing properties title, genres for movie 1732
# Storing properties title, genres for movie 1733
# Storing properties title, genres for movie 1734
# Storing properties title, genres for movie 1735
# Storing properties title, genres for movie 1738
# Storing properties title, genres for movie 1739
# Storing properties title, genres for movie 1740
# Storing properties title, genres for movie 1742
# Storing properties title, genres for movie 1743
# Storing properties title, genres for movie 1744
# Storing properties title, genres for movie 1746
# Storing properties title, genres for movie 1747
# Storing properties title, genres for movie 1748
# Storing properties title, genres for movie 1749
# Storing properties title, genres for movie 1750
# Storing properties title, genres for movie 1752
# Storing properties title, genres for movie 1753
# Storing properties title, genres for movie 1754
# Storing properties title, genres for movie 1755
# Storing properties title, genres for movie 1756
# Storing properties title, genres for movie 1757
# Storing properties title, genres for movie 1759
# Storing properties title, genres for movie 1760
# Storing properties title, genres for movie 1762
# Storing properties title, genres for movie 1764
# Storing properties title, genres for movie 1765
# Storing properties title, genres for movie 1767
# Storing properties title, genres for movie 1768
# Storing properties title, genres for movie 1769
# Storing properties title, genres for movie 1770
# Storing properties title, genres for movie 1771
# Storing properties title, genres for movie 1772
# Storing properties title, genres for movie 1773
# Storing properties title, genres for movie 1774
# Storing properties title, genres for movie 1776
# Storing properties title, genres for movie 1777
# Storing properties title, genres for movie 1779
# Storing properties title, genres for movie 1780
# Storing properties title, genres for movie 1781
# Storing properties title, genres for movie 1782
# Storing properties title, genres for movie 1783
# Storing properties title, genres for movie 1784
# Storing properties title, genres for movie 1785
# Storing properties title, genres for movie 1787
# Storing properties title, genres for movie 1788
# Storing properties title, genres for movie 1789
# Storing properties title, genres for movie 1791
# Storing properties title, genres for movie 1792
# Storing properties title, genres for movie 1793
# Storing properties title, genres for movie 1794
# Storing properties title, genres for movie 1795
# Storing properties title, genres for movie 1796
# Storing properties title, genres for movie 1797
# Storing properties title, genres for movie 1798
# Storing properties title, genres for movie 1799
# Storing properties title, genres for movie 1801
# Storing properties title, genres for movie 1804
# Storing properties title, genres for movie 1805
# Storing properties title, genres for movie 1806
# Storing properties title, genres for movie 1807
# Storing properties title, genres for movie 1809
# Storing properties title, genres for movie 1810
# Storing properties title, genres for movie 1811
# Storing properties title, genres for movie 1812
# Storing properties title, genres for movie 1814
# Storing properties title, genres for movie 1815
# Storing properties title, genres for movie 1816
# Storing properties title, genres for movie 1817
# Storing properties title, genres for movie 1819
# Storing properties title, genres for movie 1820
# Storing properties title, genres for movie 1821
# Storing properties title, genres for movie 1822
# Storing properties title, genres for movie 1824
# Storing properties title, genres for movie 1825
# Storing properties title, genres for movie 1826
# Storing properties title, genres for movie 1827
# Storing properties title, genres for movie 1829
# Storing properties title, genres for movie 1830
# Storing properties title, genres for movie 1831
# Storing properties title, genres for movie 1832
# Storing properties title, genres for movie 1833
# Storing properties title, genres for movie 1834
# Storing properties title, genres for movie 1835
# Storing properties title, genres for movie 1836
# Storing properties title, genres for movie 1837
# Storing properties title, genres for movie 1839
# Storing properties title, genres for movie 1840
# Storing properties title, genres for movie 1841
# Storing properties title, genres for movie 1842
# Storing properties title, genres for movie 1843
# Storing properties title, genres for movie 1844
# Storing properties title, genres for movie 1845
# Storing properties title, genres for movie 1846
# Storing properties title, genres for movie 1847
# Storing properties title, genres for movie 1848
# Storing properties title, genres for movie 1849
# Storing properties title, genres for movie 1850
# Storing properties title, genres for movie 1851
# Storing properties title, genres for movie 1852
# Storing properties title, genres for movie 1853
# Storing properties title, genres for movie 1854
# Storing properties title, genres for movie 1855
# Storing properties title, genres for movie 1856
# Storing properties title, genres for movie 1857
# Storing properties title, genres for movie 1858
# Storing properties title, genres for movie 1859
# Storing properties title, genres for movie 1860
# Storing properties title, genres for movie 1861
# Storing properties title, genres for movie 1862
# Storing properties title, genres for movie 1863
# Storing properties title, genres for movie 1864
# Storing properties title, genres for movie 1865
# Storing properties title, genres for movie 1866
# Storing properties title, genres for movie 1867
# Storing properties title, genres for movie 1869
# Storing properties title, genres for movie 1870
# Storing properties title, genres for movie 1871
# Storing properties title, genres for movie 1872
# Storing properties title, genres for movie 1873
# Storing properties title, genres for movie 1874
# Storing properties title, genres for movie 1875
# Storing properties title, genres for movie 1876
# Storing properties title, genres for movie 1877
# Storing properties title, genres for movie 1878
# Storing properties title, genres for movie 1879
# Storing properties title, genres for movie 1880
# Storing properties title, genres for movie 1881
# Storing properties title, genres for movie 1882
# Storing properties title, genres for movie 1883
# Storing properties title, genres for movie 1884
# Storing properties title, genres for movie 1885
# Storing properties title, genres for movie 1886
# Storing properties title, genres for movie 1887
# Storing properties title, genres for movie 1888
# Storing properties title, genres for movie 1889
# Storing properties title, genres for movie 1890
# Storing properties title, genres for movie 1891
# Storing properties title, genres for movie 1892
# Storing properties title, genres for movie 1893
# Storing properties title, genres for movie 1894
# Storing properties title, genres for movie 1895
# Storing properties title, genres for movie 1896
# Storing properties title, genres for movie 1897
# Storing properties title, genres for movie 1898
# Storing properties title, genres for movie 1899
# Storing properties title, genres for movie 1900
# Storing properties title, genres for movie 1901
# Storing properties title, genres for movie 1902
# Storing properties title, genres for movie 1903
# Storing properties title, genres for movie 1904
# Storing properties title, genres for movie 1905
# Storing properties title, genres for movie 1906
# Storing properties title, genres for movie 1907
# Storing properties title, genres for movie 1908
# Storing properties title, genres for movie 1909
# Storing properties title, genres for movie 1910
# Storing properties title, genres for movie 1911
# Storing properties title, genres for movie 1912
# Storing properties title, genres for movie 1913
# Storing properties title, genres for movie 1914
# Storing properties title, genres for movie 1915
# Storing properties title, genres for movie 1916
# Storing properties title, genres for movie 1917
# Storing properties title, genres for movie 1918
# Storing properties title, genres for movie 1919
# Storing properties title, genres for movie 1920
# Storing properties title, genres for movie 1921
# Storing properties title, genres for movie 1922
# Storing properties title, genres for movie 1923
# Storing properties title, genres for movie 1924
# Storing properties title, genres for movie 1925
# Storing properties title, genres for movie 1926
# Storing properties title, genres for movie 1927
# Storing properties title, genres for movie 1928
# Storing properties title, genres for movie 1929
# Storing properties title, genres for movie 1930
# Storing properties title, genres for movie 1931
# Storing properties title, genres for movie 1932
# Storing properties title, genres for movie 1933
# Storing properties title, genres for movie 1934
# Storing properties title, genres for movie 1935
# Storing properties title, genres for movie 1936
# Storing properties title, genres for movie 1937
# Storing properties title, genres for movie 1938
# Storing properties title, genres for movie 1939
# Storing properties title, genres for movie 1940
# Storing properties title, genres for movie 1941
# Storing properties title, genres for movie 1942
# Storing properties title, genres for movie 1943
# Storing properties title, genres for movie 1944
# Storing properties title, genres for movie 1945
# Storing properties title, genres for movie 1946
# Storing properties title, genres for movie 1947
# Storing properties title, genres for movie 1948
# Storing properties title, genres for movie 1949
# Storing properties title, genres for movie 1950
# Storing properties title, genres for movie 1951
# Storing properties title, genres for movie 1952
# Storing properties title, genres for movie 1953
# Storing properties title, genres for movie 1954
# Storing properties title, genres for movie 1955
# Storing properties title, genres for movie 1956
# Storing properties title, genres for movie 1957
# Storing properties title, genres for movie 1958
# Storing properties title, genres for movie 1959
# Storing properties title, genres for movie 1960
# Storing properties title, genres for movie 1961
# Storing properties title, genres for movie 1962
# Storing properties title, genres for movie 1963
# Storing properties title, genres for movie 1964
# Storing properties title, genres for movie 1965
# Storing properties title, genres for movie 1966
# Storing properties title, genres for movie 1967
# Storing properties title, genres for movie 1968
# Storing properties title, genres for movie 1969
# Storing properties title, genres for movie 1970
# Storing properties title, genres for movie 1971
# Storing properties title, genres for movie 1972
# Storing properties title, genres for movie 1973
# Storing properties title, genres for movie 1974
# Storing properties title, genres for movie 1975
# Storing properties title, genres for movie 1976
# Storing properties title, genres for movie 1977
# Storing properties title, genres for movie 1978
# Storing properties title, genres for movie 1979
# Storing properties title, genres for movie 1980
# Storing properties title, genres for movie 1981
# Storing properties title, genres for movie 1982
# Storing properties title, genres for movie 1983
# Storing properties title, genres for movie 1984
# Storing properties title, genres for movie 1985
# Storing properties title, genres for movie 1986
# Storing properties title, genres for movie 1987
# Storing properties title, genres for movie 1988
# Storing properties title, genres for movie 1989
# Storing properties title, genres for movie 1990
# Storing properties title, genres for movie 1991
# Storing properties title, genres for movie 1992
# Storing properties title, genres for movie 1993
# Storing properties title, genres for movie 1994
# Storing properties title, genres for movie 1995
# Storing properties title, genres for movie 1996
# Storing properties title, genres for movie 1997
# Storing properties title, genres for movie 1998
# Storing properties title, genres for movie 1999
# Storing properties title, genres for movie 2000
# Storing properties title, genres for movie 2001
# Storing properties title, genres for movie 2002
# Storing properties title, genres for movie 2003
# Storing properties title, genres for movie 2004
# Storing properties title, genres for movie 2005
# Storing properties title, genres for movie 2006
# Storing properties title, genres for movie 2007
# Storing properties title, genres for movie 2008
# Storing properties title, genres for movie 2009
# Storing properties title, genres for movie 2010
# Storing properties title, genres for movie 2011
# Storing properties title, genres for movie 2012
# Storing properties title, genres for movie 2013
# Storing properties title, genres for movie 2014
# Storing properties title, genres for movie 2015
# Storing properties title, genres for movie 2016
# Storing properties title, genres for movie 2017
# Storing properties title, genres for movie 2018
# Storing properties title, genres for movie 2019
# Storing properties title, genres for movie 2020
# Storing properties title, genres for movie 2021
# Storing properties title, genres for movie 2022
# Storing properties title, genres for movie 2023
# Storing properties title, genres for movie 2024
# Storing properties title, genres for movie 2025
# Storing properties title, genres for movie 2026
# Storing properties title, genres for movie 2027
# Storing properties title, genres for movie 2028
# Storing properties title, genres for movie 2029
# Storing properties title, genres for movie 2030
# Storing properties title, genres for movie 2031
# Storing properties title, genres for movie 2032
# Storing properties title, genres for movie 2033
# Storing properties title, genres for movie 2034
# Storing properties title, genres for movie 2035
# Storing properties title, genres for movie 2036
# Storing properties title, genres for movie 2037
# Storing properties title, genres for movie 2038
# Storing properties title, genres for movie 2039
# Storing properties title, genres for movie 2040
# Storing properties title, genres for movie 2041
# Storing properties title, genres for movie 2042
# Storing properties title, genres for movie 2043
# Storing properties title, genres for movie 2044
# Storing properties title, genres for movie 2045
# Storing properties title, genres for movie 2046
# Storing properties title, genres for movie 2047
# Storing properties title, genres for movie 2048
# Storing properties title, genres for movie 2049
# Storing properties title, genres for movie 2050
# Storing properties title, genres for movie 2051
# Storing properties title, genres for movie 2052
# Storing properties title, genres for movie 2053
# Storing properties title, genres for movie 2054
# Storing properties title, genres for movie 2055
# Storing properties title, genres for movie 2056
# Storing properties title, genres for movie 2057
# Storing properties title, genres for movie 2058
# Storing properties title, genres for movie 2059
# Storing properties title, genres for movie 2060
# Storing properties title, genres for movie 2061
# Storing properties title, genres for movie 2062
# Storing properties title, genres for movie 2063
# Storing properties title, genres for movie 2064
# Storing properties title, genres for movie 2065
# Storing properties title, genres for movie 2066
# Storing properties title, genres for movie 2067
# Storing properties title, genres for movie 2068
# Storing properties title, genres for movie 2069
# Storing properties title, genres for movie 2070
# Storing properties title, genres for movie 2071
# Storing properties title, genres for movie 2072
# Storing properties title, genres for movie 2073
# Storing properties title, genres for movie 2074
# Storing properties title, genres for movie 2075
# Storing properties title, genres for movie 2076
# Storing properties title, genres for movie 2077
# Storing properties title, genres for movie 2078
# Storing properties title, genres for movie 2079
# Storing properties title, genres for movie 2080
# Storing properties title, genres for movie 2081
# Storing properties title, genres for movie 2082
#
# *** Profile stats marshalled to file '/tmp/tmp7lcu8ut9'.
# Embedding SnakeViz in this document...
# <iframe id='snakeviz-cee42edc-5561-11ed-8e3b-0242ac150004' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-cee42edc-5561-11ed-8e3b-0242ac150004").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/%2Ftmp%2Ftmp7lcu8ut9")</script>

# %%
# %snakeviz mean_rating_producer.run(1000)
# Out:
# Storing rating 3.5 for movie 11
# Storing rating 4.0 for movie 16
# Storing rating 4.7 for movie 47
# Storing rating 4.75 for movie 50
# Storing rating 2.0 for movie 19
# Storing rating 4.0 for movie 111
# Storing rating 2.5 for movie 20
# Storing rating 4.6875 for movie 141
# Storing rating 3.0 for movie 23
# Storing rating 2.5714285714285716 for movie 153
# Storing rating 4.5 for movie 25
# Storing rating 4.0 for movie 161
# Storing rating 2.9285714285714284 for movie 163
# Storing rating 3.0 for movie 31
# Storing rating 3.25 for movie 170
# Storing rating 4.45 for movie 32
# Storing rating 3.357142857142857 for movie 173
# Storing rating 3.5 for movie 34
# Storing rating 3.5 for movie 36
# Storing rating 3.0625 for movie 204
# Storing rating 3.0 for movie 208
# Storing rating 2.5 for movie 39
# Storing rating 5.0 for movie 224
# Storing rating 4.5 for movie 41
# Storing rating 2.0 for movie 227
# Storing rating 1.0 for movie 44
# Storing rating 4.0 for movie 261
# Storing rating 3.0 for movie 273
# Storing rating 2.142857142857143 for movie 45
# Storing rating 4.7272727272727275 for movie 47
# Storing rating 3.9 for movie 288
# Storing rating 4.625 for movie 296
# Storing rating 4.7272727272727275 for movie 50
# Storing rating 3.611111111111111 for movie 307
# Storing rating 1.6 for movie 315
# Storing rating 3.0 for movie 61
# Storing rating 4.2 for movie 316
# Storing rating 4.611111111111111 for movie 318
# Storing rating 4.0 for movie 337
# Storing rating 2.4 for movie 350
# Storing rating 3.5714285714285716 for movie 62
# Storing rating 3.6 for movie 353
# Storing rating 0.5 for movie 65
# Storing rating 4.0 for movie 364
# Storing rating 0.5 for movie 66
# Storing rating 2.7 for movie 367
# Storing rating 3.6 for movie 380
# Storing rating 3.0 for movie 70
# Storing rating 2.4 for movie 420
# Storing rating 2.0 for movie 76
# Storing rating 1.4 for movie 434
# Storing rating 3.6 for movie 440
# Storing rating 4.0 for movie 85
# Storing rating 2.4 for movie 442
# Storing rating 2.8 for movie 454
# Storing rating 4.5 for movie 95
# Storing rating 4.0 for movie 100
# Storing rating 4.3 for movie 457
# Storing rating 3.0 for movie 104
# Storing rating 5.0 for movie 515
# Storing rating 4.5 for movie 110
# Storing rating 3.7 for movie 552
# Storing rating 4.666666666666667 for movie 141
# Storing rating 3.0 for movie 555
# Storing rating 4.0 for movie 145
# Storing rating 3.6 for movie 592
# Storing rating 4.0 for movie 150
# Storing rating 4.142857142857143 for movie 593
# Storing rating 4.5 for movie 151
# Storing rating 4.0 for movie 666
# Storing rating 2.5 for movie 153
# Storing rating 4.0 for movie 381
# Storing rating 0.9285714285714286 for movie 158
# Storing rating 3.5 for movie 531
# Storing rating 2.5 for movie 160
# Storing rating 4.0 for movie 161
# Storing rating 3.0 for movie 880
# Storing rating 2.875 for movie 163
# Storing rating 3.5 for movie 1041
# Storing rating 4.5 for movie 165
# Storing rating 2.5 for movie 1416
# Storing rating 0.5 for movie 169
# Storing rating 4.0 for movie 2160
# Storing rating 3.5 for movie 3328
# Storing rating 3.2333333333333334 for movie 170
# Storing rating 3.0 for movie 3744
# Storing rating 1.75 for movie 3981
# Storing rating 3.5 for movie 172
# Storing rating 3.0 for movie 3986
# Storing rating 3.375 for movie 173
# Storing rating 4.0 for movie 4033
# Storing rating 3.5 for movie 4903
# Storing rating 3.5 for movie 175
# Storing rating 1.25 for movie 5945
# Storing rating 3.1666666666666665 for movie 5954
# Storing rating 4.5 for movie 180
# Storing rating 0.5 for movie 181
# Storing rating 4.5 for movie 41997
# Storing rating 3.0 for movie 3
# Storing rating 3.0 for movie 185
# Storing rating 2.0714285714285716 for movie 186
# Storing rating 2.2222222222222223 for movie 5
# Storing rating 0.5 for movie 193
# Storing rating 4.0 for movie 7
# Storing rating 3.0 for movie 12
# Storing rating 4.5 for movie 198
# Storing rating 3.0 for movie 14
# Storing rating 3.111111111111111 for movie 204
# Storing rating 4.0 for movie 52
# Storing rating 2.2857142857142856 for movie 216
# Storing rating 4.571428571428571 for movie 223
# Storing rating 3.625 for movie 62
# Storing rating 0.5 for movie 231
# Storing rating 4.0 for movie 100
# Storing rating 3.0 for movie 135
# Storing rating 4.5 for movie 253
# Storing rating 0.5 for movie 255
# Storing rating 3.0 for movie 140
# Storing rating 2.5 for movie 256
# Storing rating 4.7 for movie 141
# Storing rating 4.5 for movie 260
# Storing rating 4.428571428571429 for movie 260
# Storing rating 3.0 for movie 605
# Storing rating 3.5 for movie 267
# Storing rating 4.0 for movie 288
# Storing rating 3.5 for movie 292
# Storing rating 3.0 for movie 637
# Storing rating 4.166666666666667 for movie 293
# Storing rating 3.6 for movie 648
# Storing rating 4.666666666666667 for movie 296
# Storing rating 3.0 for movie 743
# Storing rating 1.6666666666666667 for movie 315
# Storing rating 4.333333333333333 for movie 316
# Storing rating 2.9 for movie 762
# Storing rating 2.0 for movie 317
# Storing rating 3.0 for movie 765
# Storing rating 4.65 for movie 318
# Storing rating 3.6 for movie 780
# Storing rating 1.5 for movie 327
# Storing rating 4.0 for movie 869
# Storing rating 3.5 for movie 329
# Storing rating 4.0 for movie 1057
# Storing rating 4.0 for movie 1113
# Storing rating 2.0 for movie 332
# Storing rating 1.5 for movie 333
# Storing rating 4.3 for movie 1210
# Storing rating 3.0 for movie 1317
# Storing rating 2.5 for movie 338
# Storing rating 3.7 for movie 1356
# Storing rating 0.5 for movie 339
# Storing rating 4.0 for movie 1363
# Storing rating 3.0 for movie 344
# Storing rating 3.0 for movie 1390
# Storing rating 5.0 for movie 349
# Storing rating 1.6 for movie 1391
# Storing rating 2.3333333333333335 for movie 350
# Storing rating 3.0833333333333335 for movie 1393
# Storing rating 3.6666666666666665 for movie 353
# Storing rating 3.6 for movie 356
# Storing rating 3.5 for movie 361
# Storing rating 3.0 for movie 1409
# Storing rating 3.0 for movie 1457
# Storing rating 4.0 for movie 364
# Storing rating 4.571428571428571 for movie 2858
# Storing rating 2.6666666666666665 for movie 367
# Storing rating 4.25 for movie 1
# Storing rating 3.5 for movie 368
# Storing rating 4.318181818181818 for movie 32
# Storing rating 2.0 for movie 370
# Storing rating 4.0 for movie 43
# Storing rating 4.666666666666667 for movie 47
# Storing rating 3.5 for movie 377
# Storing rating 1.5 for movie 379
# Storing rating 4.75 for movie 50
# Storing rating 3.6666666666666665 for movie 380
# Storing rating 4.0 for movie 111
# Storing rating 3.0 for movie 382
# Storing rating 5.0 for movie 162
# Storing rating 3.0 for movie 405
# Storing rating 1.0 for movie 410
# Storing rating 4.0 for movie 176
# Storing rating 2.3333333333333335 for movie 420
# Storing rating 4.625 for movie 223
# Storing rating 3.0 for movie 423
# Storing rating 3.0 for movie 246
# Storing rating 2.5 for movie 432
# Storing rating 4.5 for movie 260
# Storing rating 5.0 for movie 299
# Storing rating 4.590909090909091 for movie 318
# Storing rating 4.0 for movie 348
# Storing rating 4.0 for movie 501
# Storing rating 1.3333333333333333 for movie 434
# Storing rating 4.555555555555555 for movie 527
# Storing rating 2.0 for movie 435
# Storing rating 3.0 for movie 534
# Storing rating 3.6666666666666665 for movie 440
# Storing rating 4.3 for movie 541
# Storing rating 5.0 for movie 551
# Storing rating 2.3333333333333335 for movie 442
# Storing rating 3.1666666666666665 for movie 588
# Storing rating 2.6666666666666665 for movie 454
# Storing rating 4.0 for movie 593
# Storing rating 2.0 for movie 455
# Storing rating 4.333333333333333 for movie 457
# Storing rating 5.0 for movie 594
# Storing rating 2.5 for movie 466
# Storing rating 3.5 for movie 595
# Storing rating 4.5 for movie 471
# Storing rating 3.5 for movie 474
# Storing rating 5.0 for movie 608
# Storing rating 4.0 for movie 661
# Storing rating 4.1 for movie 480
# Storing rating 4.0 for movie 741
# Storing rating 3.6818181818181817 for movie 481
# Storing rating 4.0 for movie 745
# Storing rating 0.5 for movie 485
# Storing rating 5.0 for movie 750
# Storing rating 4.0 for movie 837
# Storing rating 4.0 for movie 494
# Storing rating 3.0 for movie 500
# Storing rating 5.0 for movie 902
# Storing rating 4.0 for movie 903
# Storing rating 4.5 for movie 514
# Storing rating 5.0 for movie 904
# Storing rating 3.5 for movie 517
# Storing rating 3.5 for movie 520
# Storing rating 5.0 for movie 908
# Storing rating 4.0 for movie 524
# Storing rating 5.0 for movie 910
# Storing rating 4.55 for movie 527
# Storing rating 5.0 for movie 912
# Storing rating 4.0 for movie 913
# Storing rating 0.5 for movie 539
# Storing rating 5.0 for movie 916
# Storing rating 4.333333333333333 for movie 541
# Storing rating 0.5 for movie 546
# Storing rating 4.4 for movie 919
# Storing rating 3.6666666666666665 for movie 552
# Storing rating 5.0 for movie 923
# Storing rating 2.5 for movie 586
# Storing rating 4.4 for movie 924
# Storing rating 2.0 for movie 587
# Storing rating 4.0 for movie 946
# Storing rating 3.0714285714285716 for movie 588
# Storing rating 4.0 for movie 994
# Storing rating 4.5 for movie 589
# Storing rating 4.0 for movie 1029
# Storing rating 4.0 for movie 590
# Storing rating 4.0 for movie 1077
# Storing rating 3.6666666666666665 for movie 592
# Storing rating 3.9 for movie 1079
# Storing rating 4.055555555555555 for movie 593
# Storing rating 3.3333333333333335 for movie 595
# Storing rating 4.7 for movie 1089
# Storing rating 3.0 for movie 597
# Storing rating 5.0 for movie 608
# Storing rating 2.0 for movie 1093
# Storing rating 2.3333333333333335 for movie 1094
# Storing rating 4.0 for movie 610
# Storing rating 5.0 for movie 1095
# Storing rating 3.5 for movie 647
# Storing rating 3.6666666666666665 for movie 648
# Storing rating 4.0 for movie 1131
# Storing rating 4.6 for movie 1136
# Storing rating 3.5 for movie 653
# Storing rating 4.0 for movie 1148
# Storing rating 3.0 for movie 724
# Storing rating 4.0 for movie 1188
# Storing rating 5.0 for movie 733
# Storing rating 4.5 for movie 1193
# Storing rating 3.5 for movie 736
# Storing rating 5.0 for movie 1196
# Storing rating 4.0 for movie 741
# Storing rating 4.7 for movie 1198
# Storing rating 3.0 for movie 762
# Storing rating 5.0 for movie 1199
# Storing rating 4.0 for movie 778
# Storing rating 5.0 for movie 1202
# Storing rating 3.6666666666666665 for movie 780
# Storing rating 4.166666666666667 for movie 1206
# Storing rating 0.5 for movie 784
# Storing rating 3.1 for movie 1207
# Storing rating 5.0 for movie 1213
# Storing rating 5.0 for movie 1219
# Storing rating 4.0 for movie 1223
# Storing rating 4.0 for movie 785
# Storing rating 4.0 for movie 1225
# Storing rating 4.0 for movie 786
# Storing rating 5.0 for movie 1230
# Storing rating 5.0 for movie 1234
# Storing rating 1.0 for movie 788
# Storing rating 3.6 for movie 1240
# Storing rating 3.0 for movie 798
# Storing rating 3.4444444444444446 for movie 1244
# Storing rating 4.0 for movie 805
# Storing rating 0.5 for movie 818
# Storing rating 4.0 for movie 1247
# Storing rating 4.0 for movie 832
# Storing rating 4.0 for movie 1249
# Storing rating 2.5 for movie 836
# Storing rating 2.0 for movie 1255
# Storing rating 3.5 for movie 852
# Storing rating 5.0 for movie 1258
# Storing rating 3.5 for movie 1274
# Storing rating 4.142857142857143 for movie 858
# Storing rating 3.5 for movie 875
# Storing rating 2.5 for movie 879
# Storing rating 4.833333333333333 for movie 1282
# Storing rating 5.0 for movie 1284
# Storing rating 4.333333333333333 for movie 919
# Storing rating 4.333333333333333 for movie 924
# Storing rating 5.0 for movie 1288
# Storing rating 4.0 for movie 941
# Storing rating 3.0 for movie 1307
# Storing rating 3.0714285714285716 for movie 1393
# Storing rating 0.5 for movie 1015
# Storing rating 3.5 for movie 1020
# Storing rating 2.9 for movie 1517
# Storing rating 3.0 for movie 1566
# Storing rating 4.5 for movie 1036
# Storing rating 4.0 for movie 1635
# Storing rating 2.0 for movie 1037
# Storing rating 2.625 for movie 1639
# Storing rating 3.0 for movie 1688
# Storing rating 3.8 for movie 1047
# Storing rating 3.6666666666666665 for movie 1704
# Storing rating 4.0 for movie 1049
# Storing rating 3.0714285714285716 for movie 1732
# Storing rating 4.5 for movie 1059
# Storing rating 4.0 for movie 1079
# Storing rating 4.0 for movie 1907
# Storing rating 4.0 for movie 1952
# Storing rating 4.0 for movie 1080
# Storing rating 4.0 for movie 1953
# Storing rating 2.5 for movie 1088
# Storing rating 4.0 for movie 1957
# Storing rating 5.0 for movie 2010
# Storing rating 4.666666666666667 for movie 1089
# Storing rating 4.666666666666667 for movie 2078
# Storing rating 3.9 for movie 1090
# Storing rating 5.0 for movie 2080
# Storing rating 5.0 for movie 2087
# Storing rating 1.3181818181818181 for movie 1091
# Storing rating 4.0 for movie 2102
# Storing rating 4.0 for movie 1092
# Storing rating 4.0 for movie 2116
# Storing rating 2.2857142857142856 for movie 1094
# Storing rating 3.0 for movie 1100
# Storing rating 4.0 for movie 2138
# Storing rating 4.0 for movie 1101
# Storing rating 3.5 for movie 1126
# Storing rating 5.0 for movie 2186
# Storing rating 4.5 for movie 1127
# Storing rating 4.666666666666667 for movie 1136
# Storing rating 3.75 for movie 2294
# Storing rating 4.0 for movie 2300
# Storing rating 5.0 for movie 1196
# Storing rating 4.166666666666667 for movie 2324
# Storing rating 4.666666666666667 for movie 1198
# Storing rating 5.0 for movie 2360
# Storing rating 3.0 for movie 1200
# Storing rating 4.0 for movie 2394
# Storing rating 1.5 for movie 1203
# Storing rating 3.0 for movie 1207
# Storing rating 4.0 for movie 1208
# Storing rating 4.0 for movie 2396
# Storing rating 4.0 for movie 2687
# Storing rating 4.333333333333333 for movie 1210
# Storing rating 1.25 for movie 2712
# Storing rating 2.0 for movie 1214
# Storing rating 3.75 for movie 2716
# Storing rating 4.0 for movie 1215
# Storing rating 0.5 for movie 1220
# Storing rating 5.0 for movie 2761
# Storing rating 5.0 for movie 2973
# Storing rating 5.0 for movie 1222
# Storing rating 4.25 for movie 2987
# Storing rating 3.6666666666666665 for movie 1240
# Storing rating 5.0 for movie 3022
# Storing rating 5.0 for movie 1242
# Storing rating 4.0 for movie 3067
# Storing rating 4.0 for movie 3072
# Storing rating 3.0 for movie 1259
# Storing rating 4.0 for movie 3077
# Storing rating 2.5 for movie 1265
# Storing rating 4.0 for movie 3081
# Storing rating 4.0 for movie 1270
# Storing rating 3.5 for movie 3082
# Storing rating 3.3333333333333335 for movie 1274
# Storing rating 5.0 for movie 3083
# Storing rating 3.0 for movie 3203
# Storing rating 5.0 for movie 1275
# Storing rating 3.0 for movie 3246
# Storing rating 4.5 for movie 1291
# Storing rating 2.75 for movie 3253
# Storing rating 3.5 for movie 1320
# Storing rating 3.0 for movie 3260
# Storing rating 4.5 for movie 1339
# Storing rating 4.0 for movie 3265
# Storing rating 2.8333333333333335 for movie 48
# Storing rating 1.25 for movie 158
# Storing rating 3.6666666666666665 for movie 1356
# Storing rating 4.5 for movie 527
# Storing rating 4.0 for movie 1370
# Storing rating 4.5 for movie 1193
# Storing rating 4.5 for movie 1372
# Storing rating 4.0 for movie 1374
# Storing rating 4.75 for movie 1282
# Storing rating 3.5 for movie 1375
# Storing rating 2.9 for movie 1639
# Storing rating 3.8 for movie 1722
# Storing rating 3.5 for movie 1376
# Storing rating 3.5 for movie 1777
# Storing rating 2.0 for movie 1377
# Storing rating 3.3 for movie 1876
# Storing rating 3.5 for movie 1385
# Storing rating 2.5 for movie 2054
# Storing rating 1.6666666666666667 for movie 1391
# Storing rating 3.0 for movie 1393
# Storing rating 5.0 for movie 1396
# Storing rating 3.5 for movie 2302
# Storing rating 0.5 for movie 1405
# Storing rating 2.0 for movie 1407
# Storing rating 4.214285714285714 for movie 2502
# Storing rating 5.0 for movie 1425
# Storing rating 3.75 for movie 2791
# Storing rating 1.5 for movie 1445
# Storing rating 4.25 for movie 3052
# Storing rating 5.0 for movie 1466
# Storing rating 3.0 for movie 3623
# Storing rating 2.5 for movie 1476
# Storing rating 3.0 for movie 3977
# Storing rating 4.6 for movie 4886
# Storing rating 2.0 for movie 1485
# Storing rating 4.25 for movie 5952
# Storing rating 3.0 for movie 1500
# Storing rating 4.833333333333333 for movie 7361
# Storing rating 1.0 for movie 1515
# Storing rating 2.25 for movie 45
# Storing rating 3.0 for movie 1517
# Storing rating 2.75 for movie 48
# Storing rating 3.0 for movie 1518
# Storing rating 3.0 for movie 105
# Storing rating 5.0 for movie 1527
# Storing rating 2.125 for movie 186
# Storing rating 2.3 for movie 1544
# Storing rating 2.0 for movie 596
# Storing rating 3.8333333333333335 for movie 1090
# Storing rating 3.5 for movie 1552
# Storing rating 2.25 for movie 1094
# Storing rating 1.0 for movie 1562
# Storing rating 3.0 for movie 1380
# Storing rating 4.0 for movie 1580
# Storing rating 2.8333333333333335 for movie 1639
# Storing rating 4.0 for movie 1584
# Storing rating 3.6 for movie 2001
# Storing rating 3.5 for movie 1586
# Storing rating 2.7 for movie 2012
# Storing rating 2.8636363636363638 for movie 1590
# Storing rating 2.8 for movie 2100
# Storing rating 2.227272727272727 for movie 1591
# Storing rating 0.5 for movie 1592
# Storing rating 3.3333333333333335 for movie 2302
# Storing rating 3.5 for movie 1597
# Storing rating 4.0 for movie 1606
# Storing rating 3.5 for movie 2353
# Storing rating 3.75 for movie 2406
# Storing rating 3.5 for movie 1608
# Storing rating 4.125 for movie 2502
# Storing rating 5.0 for movie 1610
# Storing rating 2.0 for movie 2657
# Storing rating 4.5 for movie 1615
# Storing rating 3.0 for movie 3897
# Storing rating 3.5 for movie 1616
# Storing rating 3.3 for movie 204
# Storing rating 2.5 for movie 216
# Storing rating 4.833333333333333 for movie 1617
# Storing rating 4.0 for movie 362
# Storing rating 5.0 for movie 1625
# Storing rating 4.0 for movie 720
# Storing rating 3.5 for movie 1641
# Storing rating 2.0 for movie 1642
# Storing rating 3.5 for movie 838
# Storing rating 4.181818181818182 for movie 1645
# Storing rating 3.8333333333333335 for movie 849
# Storing rating 3.0 for movie 1647
# Storing rating 4.0 for movie 1047
# Storing rating 3.111111111111111 for movie 1663
# Storing rating 3.5 for movie 1653
# Storing rating 2.5 for movie 1665
# Storing rating 4.6 for movie 2140
# Storing rating 3.0 for movie 1673
# Storing rating 4.0 for movie 2144
# Storing rating 3.5 for movie 1676
# Storing rating 4.25 for movie 2490
# Storing rating 4.4 for movie 1682
# Storing rating 3.5 for movie 2541
# Storing rating 4.25 for movie 2723
# Storing rating 4.5 for movie 1687
# Storing rating 4.0 for movie 2724
# Storing rating 3.5 for movie 1690
# Storing rating 3.5 for movie 2908
# Storing rating 4.5 for movie 2968
# Storing rating 3.7142857142857144 for movie 1704
# Storing rating 3.5 for movie 3107
# Storing rating 0.5 for movie 1721
# Storing rating 3.5 for movie 3210
# Storing rating 3.8333333333333335 for movie 1722
# Storing rating 4.5 for movie 3703
# Storing rating 4.0 for movie 3863
# Storing rating 2.75 for movie 1732
# Storing rating 4.2727272727272725 for movie 1
# Storing rating 4.0 for movie 1747
# Storing rating 4.0 for movie 2
# Storing rating 5.0 for movie 1748
# Storing rating 4.5 for movie 110
# Storing rating 0.5 for movie 1760
# Storing rating 4.6 for movie 296
# Storing rating 4.0 for movie 1769
# Storing rating 4.583333333333333 for movie 318
# Storing rating 3.0 for movie 1779
# Storing rating 3.6666666666666665 for movie 356
# Storing rating 3.0 for movie 1784
# Storing rating 4.166666666666667 for movie 480
# Storing rating 4.0 for movie 1792
# Storing rating 4.5 for movie 527
# Storing rating 3.125 for movie 588
# Storing rating 4.5 for movie 1805
# Storing rating 4.1 for movie 593
# Storing rating 4.5 for movie 1810
# Storing rating 4.125 for movie 858
# Storing rating 3.5 for movie 1831
# Storing rating 4.0 for movie 1111
# Storing rating 3.3333333333333335 for movie 1876
# Storing rating 4.25 for movie 1206
# Storing rating 3.0 for movie 1882
# Storing rating 2.5 for movie 1884
# Storing rating 4.0 for movie 1270
# Storing rating 4.5 for movie 1892
# Storing rating 4.0 for movie 1281
# Storing rating 3.0 for movie 1909
# Storing rating 3.9 for movie 1917
# Storing rating 4.0 for movie 1918
# Storing rating 2.5 for movie 1544
# Storing rating 2.0 for movie 1921
# Storing rating 3.5 for movie 1923
# Storing rating 4.333333333333333 for movie 1682
# Storing rating 3.0 for movie 1961
# Storing rating 3.75 for movie 1704
# Storing rating 4.0 for movie 1967
# Storing rating 3.0 for movie 1882
# Storing rating 0.5 for movie 1968
# Storing rating 4.0 for movie 1907
# Storing rating 4.5 for movie 2000
# Storing rating 3.8333333333333335 for movie 1917
# Storing rating 4.916666666666667 for movie 2028
# Storing rating 3.6666666666666665 for movie 2001
# Storing rating 4.0 for movie 2002
# Storing rating 4.5 for movie 2078
# Storing rating 2.5 for movie 2003
# Storing rating 4.25 for movie 2324
# Storing rating 4.0 for movie 2355
# Storing rating 2.5 for movie 2004
# Storing rating 2.0 for movie 2720
# Storing rating 4.0 for movie 2006
# Storing rating 4.5 for movie 2858
# Storing rating 4.0 for movie 2011
# Storing rating 2.8333333333333335 for movie 2012
# Storing rating 4.666666666666667 for movie 2959
# Storing rating 3.5 for movie 3034
# Storing rating 3.0 for movie 2021
# Storing rating 3.5 for movie 3114
# Storing rating 4.923076923076923 for movie 2028
# Storing rating 4.5 for movie 3147
# Storing rating 1.5 for movie 2036
# Storing rating 4.5 for movie 3578
# Storing rating 3.5 for movie 2046
# Storing rating 4.0 for movie 3793
# Storing rating 1.5 for movie 2053
# Storing rating 4.666666666666667 for movie 4226
# Storing rating 4.75 for movie 4306
# Storing rating 2.5 for movie 2054
# Storing rating 3.25 for movie 4638
# Storing rating 4.0 for movie 2058
# Storing rating 4.666666666666667 for movie 4886
# Storing rating 2.0 for movie 2081
# Storing rating 4.25 for movie 4963
# Storing rating 3.0 for movie 2082
# Storing rating 4.5 for movie 4973
# Storing rating 2.0 for movie 2094
# Storing rating 2.8333333333333335 for movie 2100
# Storing rating 4.0 for movie 2105
# Storing rating 4.5 for movie 2115
# Storing rating 3.25 for movie 4993
# Storing rating 3.5 for movie 2126
# Storing rating 4.0 for movie 4995
# Storing rating 2.0 for movie 2133
# Storing rating 4.666666666666667 for movie 2140
# Storing rating 3.75 for movie 5218
# Storing rating 4.25 for movie 5349
# Storing rating 4.0 for movie 2150
# Storing rating 4.0 for movie 5618
# Storing rating 0.5 for movie 2152
# Storing rating 4.1 for movie 5952
# Storing rating 1.5 for movie 2153
# Storing rating 4.666666666666667 for movie 5995
# Storing rating 3.5 for movie 2161
# Storing rating 4.7 for movie 6016
# Storing rating 4.5 for movie 2167
# Storing rating 3.6666666666666665 for movie 6373
# Storing rating 3.0 for movie 2174
# Storing rating 4.5 for movie 6377
# Storing rating 5.0 for movie 2193
# Storing rating 3.3333333333333335 for movie 6534
# Storing rating 5.0 for movie 2194
# Storing rating 5.0 for movie 2231
# Storing rating 4.666666666666667 for movie 6539
# Storing rating 4.0 for movie 2268
# Storing rating 3.5 for movie 6863
# Storing rating 4.0 for movie 7254
# Storing rating 4.0 for movie 2273
# Storing rating 4.785714285714286 for movie 7361
# Storing rating 5.0 for movie 2278
# Storing rating 4.333333333333333 for movie 7458
# Storing rating 3.5 for movie 2291
# Storing rating 3.5 for movie 7669
# Storing rating 3.7 for movie 2294
# Storing rating 1.5 for movie 2296
# Storing rating 4.666666666666667 for movie 8360
# Storing rating 4.0 for movie 8622
# Storing rating 3.4285714285714284 for movie 2302
# Storing rating 4.0 for movie 8645
# Storing rating 4.0 for movie 2311
# Storing rating 4.5 for movie 8874
# Storing rating 4.0 for movie 2334
# Storing rating 4.833333333333333 for movie 8961
# Storing rating 3.0 for movie 2335
# Storing rating 4.0 for movie 31410
# Storing rating 3.7 for movie 2353
# Storing rating 4.0 for movie 33166
# Storing rating 4.4 for movie 33794
# Storing rating 4.0 for movie 2355
# Storing rating 3.0 for movie 35836
# Storing rating 2.5 for movie 2378
# Storing rating 3.0 for movie 40339
# Storing rating 3.5 for movie 40629
# Storing rating 3.0 for movie 2379
# Storing rating 4.666666666666667 for movie 44191
# Storing rating 0.5 for movie 2381
# Storing rating 4.0 for movie 45517
# Storing rating 4.5 for movie 47099
# Storing rating 4.5 for movie 2391
# Storing rating 4.333333333333333 for movie 48516
# Storing rating 3.5 for movie 2393
# Storing rating 4.0 for movie 48780
# Storing rating 4.0 for movie 2405
# Storing rating 3.9 for movie 2406
# Storing rating 4.5 for movie 50872
# Storing rating 3.0 for movie 2407
# Storing rating 3.0 for movie 51086
# Storing rating 3.5 for movie 53125
# Storing rating 2.5 for movie 2424
# Storing rating 4.0 for movie 2433
# Storing rating 4.166666666666667 for movie 53996
# Storing rating 4.0 for movie 55721
# Storing rating 0.5 for movie 2450
# Storing rating 5.0 for movie 58559
# Storing rating 3.5 for movie 2468
# Storing rating 4.0 for movie 59315
# Storing rating 3.0 for movie 2470
# Storing rating 3.5 for movie 59784
# Storing rating 2.0 for movie 2471
# Storing rating 4.5 for movie 60069
# Storing rating 3.7 for movie 2478
# Storing rating 4.1 for movie 2490
# Storing rating 4.5 for movie 63082
# Storing rating 4.0 for movie 2501
# Storing rating 4.0 for movie 63859
# Storing rating 4.222222222222222 for movie 2502
# Storing rating 3.5 for movie 64969
# Storing rating 5.0 for movie 68157
# Storing rating 4.0 for movie 2505
# Storing rating 4.0 for movie 68954
# Storing rating 4.0 for movie 71033
# Storing rating 4.0 for movie 2539
# Storing rating 4.5 for movie 71899
# Storing rating 3.5 for movie 2541
# Storing rating 4.5 for movie 2542
# Storing rating 4.5 for movie 72356
# Storing rating 3.5 for movie 72641
# Storing rating 3.0 for movie 2549
# Storing rating 4.5 for movie 73017
# Storing rating 4.5 for movie 2571
# Storing rating 4.5 for movie 76093
# Storing rating 3.5 for movie 2600
# Storing rating 3.5 for movie 78105
# Storing rating 5.0 for movie 78499
# Storing rating 4.0 for movie 2605
# Storing rating 4.5 for movie 79091
# Storing rating 3.5 for movie 2616
# Storing rating 5.0 for movie 79132
# Storing rating 4.0 for movie 2617
# Storing rating 4.0 for movie 80463
# Storing rating 2.5 for movie 2628
# Storing rating 4.0 for movie 81591
# Storing rating 3.5 for movie 2640
# Storing rating 4.0 for movie 81845
# Storing rating 4.0 for movie 81847
# Storing rating 3.0 for movie 2641
# Storing rating 4.5 for movie 83803
# Storing rating 4.5 for movie 2672
# Storing rating 3.5 for movie 2683
# Storing rating 4.0 for movie 84152
# Storing rating 4.5 for movie 85342
# Storing rating 4.0 for movie 2688
# Storing rating 0.5 for movie 2700
# Storing rating 3.5 for movie 85736
# Storing rating 2.5 for movie 2701
# Storing rating 3.5 for movie 86298
# Storing rating 4.0 for movie 2706
# Storing rating 4.0 for movie 86504
# Storing rating 0.5 for movie 2710
# Storing rating 3.5 for movie 86880
# Storing rating 1.1 for movie 2712
# Storing rating 5.0 for movie 86882
# Storing rating 3.7 for movie 2716
# Storing rating 3.5 for movie 86911
# Storing rating 3.0 for movie 2717
# Storing rating 3.5 for movie 87485
# Storing rating 3.5 for movie 2718
# Storing rating 2.5 for movie 87520
# Storing rating 1.7 for movie 2720
# Storing rating 3.0 for movie 87869
# Storing rating 3.0 for movie 2722
# Storing rating 3.5 for movie 87876
# Storing rating 4.1 for movie 2723
# Storing rating 3.0 for movie 88405
# Storing rating 4.0 for movie 89745
# Storing rating 5.0 for movie 2762
# Storing rating 4.5 for movie 2763
# Storing rating 4.5 for movie 2764
# Storing rating 3.5 for movie 90647
# Storing rating 2.5 for movie 2770
# Storing rating 3.5 for movie 90746
# Storing rating 3.8 for movie 2791
# Storing rating 3.5 for movie 91126
# Storing rating 3.5 for movie 2792
# Storing rating 4.5 for movie 91529
# Storing rating 4.5 for movie 92259
# Storing rating 3.5 for movie 2794
# Storing rating 3.5 for movie 93831
# Storing rating 1.5 for movie 2797
# Storing rating 3.5 for movie 94777
# Storing rating 4.0 for movie 95167
# Storing rating 3.5 for movie 2803
# Storing rating 2.5 for movie 2805
# Storing rating 4.0 for movie 95201
# Storing rating 3.0 for movie 2808
# Storing rating 4.5 for movie 95311
# Storing rating 2.5 for movie 2816
# Storing rating 3.5 for movie 95313
# Storing rating 3.15 for movie 2840
# Storing rating 4.5 for movie 95377
# Storing rating 3.5 for movie 95441
# Storing rating 4.444444444444445 for movie 2858
# Storing rating 3.5 for movie 2860
# Storing rating 3.0 for movie 95510
# Storing rating 3.0 for movie 2881
# Storing rating 3.0 for movie 95543
# Storing rating 4.0 for movie 2889
# Storing rating 3.5 for movie 95654
# Storing rating 4.0 for movie 2890
# Storing rating 3.0 for movie 95720
# Storing rating 4.0 for movie 2916
# Storing rating 4.0 for movie 95858
# Storing rating 4.0 for movie 2918
# Storing rating 4.0 for movie 2947
# Storing rating 3.5 for movie 97304
# Storing rating 4.5 for movie 2948
# Storing rating 4.0 for movie 97913
# Storing rating 4.5 for movie 2949
# Storing rating 4.0 for movie 97921
# Storing rating 0.5 for movie 2953
# Storing rating 3.5 for movie 97938
# Storing rating 4.714285714285714 for movie 2959
# Storing rating 3.0 for movie 2985
# Storing rating 4.0 for movie 98491
# Storing rating 2.2 for movie 2986
# Storing rating 4.0 for movie 99114
# Storing rating 4.1 for movie 2987
# Storing rating 3.5 for movie 101142
# Storing rating 4.0 for movie 2989
# Storing rating 3.0 for movie 102686
# Storing rating 3.5 for movie 2990
# Storing rating 4.5 for movie 2991
# Storing rating 3.0 for movie 102716
# Storing rating 4.0 for movie 2993
# Storing rating 4.0 for movie 102903
# Storing rating 4.0 for movie 2997
# Storing rating 4.5 for movie 3000
# Storing rating 3.0 for movie 103042
# Storing rating 4.0 for movie 103141
# Storing rating 4.0 for movie 103249
# Storing rating 4.0 for movie 103335
# Storing rating 3.85 for movie 3020
# Storing rating 3.0 for movie 103384
# Storing rating 5.0 for movie 3033
# Storing rating 4.0 for movie 105844
# Storing rating 3.5 for movie 3039
# Storing rating 4.0 for movie 106487
# Storing rating 4.3 for movie 3052
# Storing rating 3.0 for movie 3063
# Storing rating 4.0 for movie 106696
# Storing rating 3.6 for movie 3082
# Storing rating 4.0 for movie 106782
# Storing rating 4.0 for movie 108932
# Storing rating 3.5 for movie 3087
# Storing rating 4.0 for movie 108983
# Storing rating 4.0 for movie 109374
# Storing rating 3.6 for movie 3107
# Storing rating 5.0 for movie 109487
# Storing rating 3.5 for movie 3113
# Storing rating 3.5 for movie 112175
# Storing rating 3.4 for movie 3114
# Storing rating 4.5 for movie 112552
# Storing rating 4.0 for movie 112852
# Storing rating 3.5 for movie 3146
# Storing rating 3.5 for movie 114935
# Storing rating 4.5 for movie 115617
# Storing rating 4.0 for movie 116797
# Storing rating 3.5 for movie 3156
# Storing rating 4.5 for movie 116897
# Storing rating 3.8 for movie 3173
# Storing rating 3.5 for movie 117529
# Storing rating 3.5 for movie 122882
# Storing rating 4.0 for movie 122904
# Storing rating 3.5 for movie 3190
# Storing rating 4.5 for movie 134853
# Storing rating 4.0 for movie 3208
# Storing rating 4.0 for movie 138702
# Storing rating 1.5 for movie 3247
# Storing rating 0.5 for movie 3248
# Storing rating 4.0 for movie 139385
# Storing rating 3.0 for movie 3249
# Storing rating 4.0 for movie 142488
# Storing rating 4.5 for movie 152081
# Storing rating 4.0 for movie 3250
# Storing rating 4.5 for movie 3252
# Storing rating 4.5 for movie 160718
# Storing rating 2.7 for movie 3253
# Storing rating 4.5 for movie 166024
# Storing rating 2.0 for movie 3254
# Storing rating 5.0 for movie 177765
# Storing rating 4.25 for movie 1
# Storing rating 4.0 for movie 3255
# Storing rating 2.857142857142857 for movie 70
# Storing rating 3.0 for movie 185
# Storing rating 5.0 for movie 3256
# Storing rating 4.636363636363637 for movie 296
# Storing rating 4.538461538461538 for movie 318
# Storing rating 2.0 for movie 3263
# Storing rating 3.857142857142857 for movie 356
# Storing rating 3.5 for movie 3264
# Storing rating 3.5 for movie 365
# Storing rating 4.142857142857143 for movie 480
# Storing rating 0.5 for movie 3268
# Storing rating 4.423076923076923 for movie 527
# Storing rating 4.090909090909091 for movie 593
# Storing rating 3.642857142857143 for movie 648
# Storing rating 4.5 for movie 3275
# Storing rating 4.0 for movie 673
# Storing rating 4.4 for movie 733
# Storing rating 4.5 for movie 3298
# Storing rating 4.333333333333333 for movie 745
# Storing rating 3.5 for movie 3300
# Storing rating 4.5 for movie 3301
# Storing rating 4.142857142857143 for movie 778
# Storing rating 3.0 for movie 3316
# Storing rating 3.7142857142857144 for movie 780
# Storing rating 3.5 for movie 3354
# Storing rating 4.166666666666667 for movie 858
# Storing rating 4.714285714285714 for movie 1089
# Storing rating 3.0 for movie 3388
# Storing rating 4.714285714285714 for movie 1136
# Storing rating 4.0 for movie 3448
# Storing rating 4.285714285714286 for movie 1193
# Storing rating 3.0 for movie 1194
# Storing rating 2.5 for movie 1197
# Storing rating 4.0 for movie 3452
# Storing rating 2.2 for movie 1203
# Storing rating 4.0 for movie 3479
# Storing rating 4.4 for movie 1206
# Storing rating 4.0 for movie 1208
# Storing rating 2.1 for movie 1214
# Storing rating 2.5 for movie 3481
# Storing rating 4.0 for movie 1221
# Storing rating 4.0 for movie 3489
# Storing rating 4.333333333333333 for movie 1225
# Storing rating 5.0 for movie 1267
# Storing rating 4.0 for movie 3513
# Storing rating 1.4 for movie 1405
# Storing rating 3.2857142857142856 for movie 1517
# Storing rating 4.5 for movie 3527
# Storing rating 3.8333333333333335 for movie 1704
# Storing rating 2.6 for movie 1921
# Storing rating 4.0 for movie 3552
# Storing rating 3.4 for movie 1961
# Storing rating 4.0 for movie 3555
# Storing rating 5.0 for movie 2023
# Storing rating 4.928571428571429 for movie 2028
# Storing rating 4.6 for movie 3578
# Storing rating 4.666666666666667 for movie 2329
# Storing rating 4.166666666666667 for movie 2396
# Storing rating 1.0 for movie 3593
# Storing rating 4.0 for movie 2431
# Storing rating 4.625 for movie 2571
# Storing rating 1.5 for movie 3608
# Storing rating 3.875 for movie 2683
# Storing rating 4.5 for movie 2762
# Storing rating 4.5 for movie 2858
# Storing rating 4.0 for movie 3617
# Storing rating 4.75 for movie 2959
# Storing rating 4.0 for movie 2997
# Storing rating 2.9 for movie 3623
# Storing rating 3.5 for movie 3006
# Storing rating 3.5 for movie 3114
# Storing rating 4.5 for movie 3147
# Storing rating 4.5 for movie 3635
# Storing rating 5.0 for movie 3267
# Storing rating 4.0 for movie 3638
# Storing rating 4.375 for movie 3275
# Storing rating 5.0 for movie 3556
# Storing rating 3.5 for movie 3639
# Storing rating 4.666666666666667 for movie 3578
# Storing rating 4.0 for movie 3723
# Storing rating 3.6666666666666665 for movie 3753
# Storing rating 3.5 for movie 3697
# Storing rating 4.0 for movie 3993
# Storing rating 3.65 for movie 3698
# Storing rating 3.6666666666666665 for movie 3996
# Storing rating 4.714285714285714 for movie 4226
# Storing rating 4.0 for movie 3702
# Storing rating 4.0 for movie 4776
# Storing rating 3.6666666666666665 for movie 4896
# Storing rating 4.4 for movie 3703
# Storing rating 4.0 for movie 4963
# Storing rating 3.0 for movie 3704
# Storing rating 4.6 for movie 4973
# Storing rating 3.6 for movie 4993
# Storing rating 4.5 for movie 3717
# Storing rating 4.0 for movie 5009
# Storing rating 4.666666666666667 for movie 5010
# Storing rating 4.5 for movie 3740
# Storing rating 5.0 for movie 5418
# Storing rating 4.166666666666667 for movie 5445
# Storing rating 4.5 for movie 3745
# Storing rating 3.5 for movie 5816
# Storing rating 4.0 for movie 3751
# Storing rating 4.25 for movie 5952
# Storing rating 3.75 for movie 3753
# Storing rating 3.0714285714285716 for movie 5954
# Storing rating 4.166666666666667 for movie 5989
# Storing rating 3.5 for movie 3755
# Storing rating 4.0 for movie 5991
# Storing rating 4.0 for movie 3763
# Storing rating 4.1 for movie 3793
# Storing rating 4.75 for movie 5995
# Storing rating 4.416666666666667 for movie 6016
# Storing rating 4.0 for movie 3809
# Storing rating 3.6666666666666665 for movie 6378
# Storing rating 3.0 for movie 6773
# Storing rating 2.5 for movie 3825
# Storing rating 2.0 for movie 6870
# Storing rating 2.3 for movie 3826
# Storing rating 4.166666666666667 for movie 6874
# Storing rating 4.166666666666667 for movie 7143
# Storing rating 2.5 for movie 3827
# Storing rating 4.333333333333333 for movie 7153
# Storing rating 3.0 for movie 3835
# Storing rating 4.8125 for movie 7361
# Storing rating 4.5 for movie 7371
# Storing rating 4.0 for movie 3841
# Storing rating 4.166666666666667 for movie 7438
# Storing rating 3.5 for movie 3868
# Storing rating 5.0 for movie 8132
# Storing rating 3.0 for movie 3869
# Storing rating 3.5 for movie 3879
# Storing rating 5.0 for movie 8368
# Storing rating 3.0 for movie 3889
# Storing rating 4.0 for movie 8622
# Storing rating 3.5 for movie 3916
# Storing rating 4.0 for movie 3948
# Storing rating 4.5 for movie 8636
# Storing rating 4.5 for movie 3952
# Storing rating 3.5 for movie 8645
# Storing rating 5.0 for movie 8665
# Storing rating 3.1 for movie 3977
# Storing rating 4.166666666666667 for movie 8873
# Storing rating 3.5 for movie 3980
# Storing rating 1.9 for movie 3981
#
# *** Profile stats marshalled to file '/tmp/tmpb954tt2c'.
# Embedding SnakeViz in this document...
# <iframe id='snakeviz-d7b01c74-5561-11ed-8e3b-0242ac150004' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-d7b01c74-5561-11ed-8e3b-0242ac150004").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/%2Ftmp%2Ftmpb954tt2c")</script>

# %% [markdown]
# ## Memory-Profiling

# %%
# %load_ext memory_profiler

# %%
# %%mprun -f read_ratings_file -f publish_ratings -f rating_message_producer.publish
# publish_ratings(read_ratings_file(), 100)
# Out:
# Publishing message 100
# Filename: /home/jovyan/rating_producer.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     10    125.5 MiB    125.5 MiB           1   def read_file():
#     11    125.5 MiB      0.0 MiB           2   	with open('./data/ratings.csv', 'r') as f:
#     12    125.5 MiB      0.0 MiB           1   		reader = csv.reader(f)
#     13    125.5 MiB      0.0 MiB         102   		for line in reader:
#     14    125.5 MiB  12804.6 MiB         204   			yield line
#
#
# Filename: /home/jovyan/rating_producer.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     16    125.5 MiB    125.5 MiB           1   def publish(lines, n = math.inf):
#     17    125.5 MiB  12804.6 MiB         102   	for i, line in enumerate(lines):
#     18    125.5 MiB      0.0 MiB         102   		if i == 0:
#     19    125.5 MiB      0.0 MiB           1   			continue
#     20
#     21    125.5 MiB      0.0 MiB         101   		if i > n:
#     22    125.5 MiB      0.0 MiB           1   			break
#     23
#     24    125.5 MiB      0.0 MiB         100   		rating = Rating()
#     25    125.5 MiB      0.0 MiB         100   		rating.userId = int(line[0])
#     26    125.5 MiB      0.0 MiB         100   		rating.movieId = int(line[1])
#     27    125.5 MiB      0.0 MiB         100   		rating.value = float(line[2])
#     28
#     29    125.5 MiB      0.0 MiB         100   		if i % 100 == 0:
#     30    125.5 MiB      0.0 MiB           1   			print(f'Publishing message {i}')
#     31
#     32    125.5 MiB    125.5 MiB         100   		producer.publish('ratings', rating)
#
#
# Filename: /home/jovyan/message_service.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     24    125.5 MiB    125.5 MiB         100   		def publish(self, topic, message, key=str(uuid.uuid4())):
#     25    125.5 MiB      0.0 MiB         100   			key_bytes = bytes(key, encoding='utf-8')
#     26    125.5 MiB      0.0 MiB         100   			value_bytes = message.SerializeToString()
#     27
#     28    125.5 MiB      0.0 MiB         100   			self.kafka_producer.send(topic, key=key_bytes, value=value_bytes)
#     29    125.5 MiB      0.0 MiB         100   			self.__report_publication()
#     30    125.5 MiB      0.0 MiB         100   			self.kafka_producer.flush()
#     31
#     32    125.5 MiB      0.0 MiB         100   			return key

# %%
# %%mprun -f read_movies_file -f publish_movies -f movie_data_message_producer.publish
# publish_movies(read_movies_file(), 100)
# Out:
# Publishing message 10
# Publishing message 20
# Publishing message 30
# Publishing message 40
# Publishing message 50
# Publishing message 60
# Publishing message 70
# Publishing message 80
# Publishing message 90
# Publishing message 100
# Filename: /home/jovyan/movie_data_producer.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     11    125.5 MiB    125.5 MiB           1   def read_file():
#     12    125.5 MiB      0.0 MiB           2   	with open('./data/movies.csv', 'r') as f:
#     13    125.5 MiB      0.0 MiB           1   		reader = csv.reader(f)
#     14    125.5 MiB      0.0 MiB         102   		for line in reader:
#     15    125.5 MiB  12804.6 MiB         204   			yield line
#
#
# Filename: /home/jovyan/movie_data_producer.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     17    125.5 MiB    125.5 MiB           1   def publish(lines, n = math.inf, wait_time = 0.1):
#     18    125.5 MiB  12804.6 MiB         102   	for i, line in enumerate(lines):
#     19    125.5 MiB      0.0 MiB         102   		if i == 0:
#     20    125.5 MiB      0.0 MiB           1   			continue
#     21
#     22    125.5 MiB      0.0 MiB         101   		if i > n:
#     23    125.5 MiB      0.0 MiB           1   			break
#     24
#     25    125.5 MiB      0.0 MiB         100   		movie = Movie()
#     26    125.5 MiB      0.0 MiB         100   		movie.id = int(line[0])
#     27    125.5 MiB      0.0 MiB         100   		movie.title = line[1]
#     28    125.5 MiB      0.0 MiB         100   		movie.genres.extend(line[2].split('|'))
#     29
#     30    125.5 MiB      0.0 MiB         100   		if i % 10 == 0:
#     31    125.5 MiB      0.0 MiB          10   			print(f'Publishing message {i}')
#     32
#     33    125.5 MiB  12553.5 MiB         100   		producer.publish('movies', movie)
#     34
#     35    125.5 MiB      0.0 MiB         100   		time.sleep(wait_time)
#
#
# Filename: /home/jovyan/message_service.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     24    125.5 MiB   1380.9 MiB         100   		def publish(self, topic, message, key=str(uuid.uuid4())):
#     25    125.5 MiB      0.0 MiB         100   			key_bytes = bytes(key, encoding='utf-8')
#     26    125.5 MiB      0.0 MiB         100   			value_bytes = message.SerializeToString()
#     27
#     28    125.5 MiB      0.0 MiB         100   			self.kafka_producer.send(topic, key=key_bytes, value=value_bytes)
#     29    125.5 MiB      0.0 MiB         100   			self.__report_publication()
#     30    125.5 MiB      0.0 MiB         100   			self.kafka_producer.flush()
#     31
#     32    125.5 MiB      0.0 MiB         100   			return key

# %%
# %%mprun -f mean_rating_producer.run -f mean_rating_producer.on_message -f mean_rating_producer.producer.publish -f mean_rating_producer.mean_ratings.to_csv
# mean_rating_producer.run(10)
# Out:
# Storing rating 4.0 for movie 31410
# Storing rating 4.8 for movie 32587
# Storing rating 4.5 for movie 3984
# Storing rating 2.5 for movie 34405
# Storing rating 0.5 for movie 3990
# Storing rating 4.0 for movie 36529
# Storing rating 2.0 for movie 40583
# Storing rating 5.0 for movie 40815
# Storing rating 4.5 for movie 3994
# Storing rating 2.0 for movie 41566
# Filename: /home/jovyan/message_service.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     68    125.5 MiB    125.5 MiB           1   		def run(self, n = math.inf):
#     69    126.1 MiB      0.0 MiB          10   			for i, message in enumerate(self.kafka_consumer):
#     70    126.1 MiB      0.0 MiB          10   				try:
#     71    126.1 MiB      0.0 MiB          10   					parsed_message = self.create_fnc(message.topic)
#     72    126.1 MiB      0.0 MiB          10   					parsed_message.ParseFromString(message.value)
#     73    126.1 MiB   1260.5 MiB          10   					self.on_message(parsed_message, message.topic)
#     74    126.1 MiB      0.0 MiB          10   					self.__report_consumption()
#     75                                         				except Exception as e:
#     76                                         					print('cannot process message for topic ' + message.topic, e)
#     77
#     78    126.1 MiB      0.0 MiB          10   				if i + 1 == n:
#     79    126.1 MiB      0.0 MiB           1   					break
#
#
# Filename: /home/jovyan/mean_rating_producer.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     16    126.1 MiB   1260.0 MiB          10   	def on_message(self, message, topic):
#     17    126.1 MiB      0.0 MiB          10   		if message.movieId in self.mean_ratings.index:
#     18    126.1 MiB      0.0 MiB           6   			movie = self.mean_ratings.loc[message.movieId]
#     19                                         		else:
#     20    126.1 MiB      0.0 MiB           4   			movie = pd.Series({'sum_ratings': 0, 'n': 0})
#     21
#     22    126.1 MiB      0.0 MiB          10   		n = movie.n + 1
#     23    126.1 MiB      0.0 MiB          10   		mean_rating = (message.value + movie.sum_ratings) / n
#     24
#     25    126.1 MiB      0.0 MiB          10   		self.mean_ratings.loc[message.movieId, 'n'] = n
#     26    126.1 MiB      0.0 MiB          10   		self.mean_ratings.loc[message.movieId, 'sum_ratings'] = movie.sum_ratings + message.value
#     27
#     28    126.1 MiB      0.0 MiB          10   		print(f'Storing rating {mean_rating} for movie {message.movieId}')
#     29
#     30    126.1 MiB   1260.5 MiB          10   		self.mean_ratings.to_csv('./data/mean-ratings.csv', sep = ';')
#     31
#     32    126.1 MiB      0.0 MiB          10   		msg = MeanRating()
#     33    126.1 MiB      0.0 MiB          10   		msg.value = mean_rating
#     34    126.1 MiB      0.0 MiB          10   		msg.movieId = message.movieId
#     35    126.1 MiB      0.0 MiB          10   		self.producer.publish('mean-ratings', msg, key = str(message.movieId))
#
#
# Filename: /home/jovyan/message_service.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     24    126.1 MiB   1260.5 MiB          10   		def publish(self, topic, message, key=str(uuid.uuid4())):
#     25    126.1 MiB      0.0 MiB          10   			key_bytes = bytes(key, encoding='utf-8')
#     26    126.1 MiB      0.0 MiB          10   			value_bytes = message.SerializeToString()
#     27
#     28    126.1 MiB      0.0 MiB          10   			self.kafka_producer.send(topic, key=key_bytes, value=value_bytes)
#     29    126.1 MiB      0.0 MiB          10   			self.__report_publication()
#     30    126.1 MiB      0.0 MiB          10   			self.kafka_producer.flush()
#     31
#     32    126.1 MiB      0.0 MiB          10   			return key
#
#
# Filename: /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    170    126.1 MiB   1260.0 MiB          20           @wraps(func)
#    171                                                 def wrapper(*args, **kwargs) -> Callable[..., Any]:
#    172    126.1 MiB      0.0 MiB          20               old_arg_value = kwargs.pop(old_arg_name, None)
#    173
#    174    126.1 MiB      0.0 MiB          20               if old_arg_value is not None:
#    175                                                         if new_arg_name is None:
#    176                                                             msg = (
#    177                                                                 f"the {repr(old_arg_name)} keyword is deprecated and "
#    178                                                                 "will be removed in a future version. Please take "
#    179                                                                 f"steps to stop the use of {repr(old_arg_name)}"
#    180                                                             )
#    181                                                             warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
#    182                                                             kwargs[old_arg_name] = old_arg_value
#    183                                                             return func(*args, **kwargs)
#    184
#    185                                                         elif mapping is not None:
#    186                                                             if callable(mapping):
#    187                                                                 new_arg_value = mapping(old_arg_value)
#    188                                                             else:
#    189                                                                 new_arg_value = mapping.get(old_arg_value, old_arg_value)
#    190                                                             msg = (
#    191                                                                 f"the {old_arg_name}={repr(old_arg_value)} keyword is "
#    192                                                                 "deprecated, use "
#    193                                                                 f"{new_arg_name}={repr(new_arg_value)} instead."
#    194                                                             )
#    195                                                         else:
#    196                                                             new_arg_value = old_arg_value
#    197                                                             msg = (
#    198                                                                 f"the {repr(old_arg_name)}' keyword is deprecated, "
#    199                                                                 f"use {repr(new_arg_name)} instead."
#    200                                                             )
#    201
#    202                                                         warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
#    203                                                         if kwargs.get(new_arg_name) is not None:
#    204                                                             msg = (
#    205                                                                 f"Can only specify {repr(old_arg_name)} "
#    206                                                                 f"or {repr(new_arg_name)}, not both."
#    207                                                             )
#    208                                                             raise TypeError(msg)
#    209                                                         else:
#    210                                                             kwargs[new_arg_name] = new_arg_value
#    211    126.1 MiB      0.5 MiB          20               return func(*args, **kwargs)

# %%
# %%mprun -f movie_data_processor.run -f movie_data_processor.on_message -f movie_data_processor.sink.save -f movie_data_processor.sink.data.to_csv
# movie_data_processor.run(10)
# Out:
# Storing properties title, genres for movie 2083
# Storing properties title, genres for movie 2084
# Storing properties title, genres for movie 2085
# Storing properties title, genres for movie 2086
# Storing properties title, genres for movie 2087
# Storing properties title, genres for movie 2088
# Storing properties title, genres for movie 2089
# Storing properties title, genres for movie 2090
# Storing properties title, genres for movie 2091
# Storing properties title, genres for movie 2092
# Filename: /home/jovyan/message_service.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     68    126.1 MiB    126.1 MiB           1   		def run(self, n = math.inf):
#     69    126.3 MiB      0.0 MiB          10   			for i, message in enumerate(self.kafka_consumer):
#     70    126.3 MiB      0.0 MiB          10   				try:
#     71    126.3 MiB      0.0 MiB          10   					parsed_message = self.create_fnc(message.topic)
#     72    126.3 MiB      0.0 MiB          10   					parsed_message.ParseFromString(message.value)
#     73    126.3 MiB   1263.1 MiB          10   					self.on_message(parsed_message, message.topic)
#     74    126.3 MiB      0.0 MiB          10   					self.__report_consumption()
#     75                                         				except Exception as e:
#     76                                         					print('cannot process message for topic ' + message.topic, e)
#     77
#     78    126.3 MiB      0.0 MiB          10   				if i + 1 == n:
#     79    126.3 MiB      0.0 MiB           1   					break
#
#
# Filename: /home/jovyan/movie_data_sink.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     32    126.3 MiB   1262.8 MiB          10   	def on_message(self, message, topic):
#     33    126.3 MiB      0.0 MiB          10   		if topic == 'mean-ratings':
#     34                                         			self.sink.save(message.movieId, {
#     35                                         				'mean_rating': message.value
#     36                                         			})
#     37    126.3 MiB      0.0 MiB          10   		elif topic == 'movies':
#     38    126.3 MiB   1263.1 MiB          20   			self.sink.save(message.id, {
#     39    126.3 MiB      0.0 MiB          10   				'title': message.title,
#     40    126.3 MiB      0.0 MiB          10   				'genres': ','.join(message.genres)
#     41                                         			})
#     42                                         		else:
#     43                                         			raise ValueError('unknown topic ' + topic)
#
#
# Filename: /home/jovyan/movie_data_sink.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     14    126.3 MiB   1262.8 MiB          10   	def save(self, id, data):
#     15    126.3 MiB      0.0 MiB          30   		for key, value in data.items():
#     16    126.3 MiB      0.0 MiB          20   			self.data.loc[id, key] = value
#     17
#     18    126.3 MiB      0.0 MiB          10   		keys = ', '.join(data.keys())
#     19    126.3 MiB      0.0 MiB          10   		print(f'Storing properties {keys} for movie {id}')
#     20
#     21    126.3 MiB   1263.1 MiB          10   		self.data.to_csv('./data/movie-data.csv', sep = ';')
#
#
# Filename: /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    170    126.3 MiB   1262.8 MiB          20           @wraps(func)
#    171                                                 def wrapper(*args, **kwargs) -> Callable[..., Any]:
#    172    126.3 MiB      0.0 MiB          20               old_arg_value = kwargs.pop(old_arg_name, None)
#    173
#    174    126.3 MiB      0.0 MiB          20               if old_arg_value is not None:
#    175                                                         if new_arg_name is None:
#    176                                                             msg = (
#    177                                                                 f"the {repr(old_arg_name)} keyword is deprecated and "
#    178                                                                 "will be removed in a future version. Please take "
#    179                                                                 f"steps to stop the use of {repr(old_arg_name)}"
#    180                                                             )
#    181                                                             warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
#    182                                                             kwargs[old_arg_name] = old_arg_value
#    183                                                             return func(*args, **kwargs)
#    184
#    185                                                         elif mapping is not None:
#    186                                                             if callable(mapping):
#    187                                                                 new_arg_value = mapping(old_arg_value)
#    188                                                             else:
#    189                                                                 new_arg_value = mapping.get(old_arg_value, old_arg_value)
#    190                                                             msg = (
#    191                                                                 f"the {old_arg_name}={repr(old_arg_value)} keyword is "
#    192                                                                 "deprecated, use "
#    193                                                                 f"{new_arg_name}={repr(new_arg_value)} instead."
#    194                                                             )
#    195                                                         else:
#    196                                                             new_arg_value = old_arg_value
#    197                                                             msg = (
#    198                                                                 f"the {repr(old_arg_name)}' keyword is deprecated, "
#    199                                                                 f"use {repr(new_arg_name)} instead."
#    200                                                             )
#    201
#    202                                                         warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
#    203                                                         if kwargs.get(new_arg_name) is not None:
#    204                                                             msg = (
#    205                                                                 f"Can only specify {repr(old_arg_name)} "
#    206                                                                 f"or {repr(new_arg_name)}, not both."
#    207                                                             )
#    208                                                             raise TypeError(msg)
#    209                                                         else:
#    210                                                             kwargs[new_arg_name] = new_arg_value
#    211    126.3 MiB      0.3 MiB          20               return func(*args, **kwargs)
